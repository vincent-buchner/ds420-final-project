# %% [markdown]
# # Amazon Sales Report Exploratory Data Analysis
# <hr>
#
# <!-- #### What is the distribution of the variables?
# #### Are there any missing or inconsistent data points?
# #### Are there outliers in the data?
# #### What relationships exist between variables?
# #### Are there any underlying patterns or trends in the data?
# #### Addtional Findings -->
#
# #### EDA Prep
# <i>You do not need to exhaustedly explore|transform the data set in this step. Instead, you need to make data in numbers and scale them.</i>
# <br><br>
# From what I understand, is that we are keeping the dataset similar, but dropping what we might not need and making items numeric.
#
# 1. Load Dataset
# 2.

# %%
# 0: Imports
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# 0.1: Helper Functions
def label_encoder_to_dict(label_encoder: LabelEncoder) -> dict:
    return dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# %%
# 1: Loaded Dataset
df_amazon = pd.read_csv("dataset/original_amazon_sales_report.csv")
#print(df_amazon.columns)
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB
# /var/folders/0s/r83z34657f316tyl6tlhslm80000gn/T/ipykernel_17038/1811533203.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_amazon = pd.read_csv("dataset/original_amazon_sales_report.csv")

# %%
# 2. Drop the columns we don't think we'll use
df_amazon.drop(columns=[
    "index",
    "Order ID",
    "Sales Channel ",
    "Style",
    "SKU",
    "ASIN",
    "ship-city",
    "ship-state",
    "ship-postal-code",
    "ship-country",
    "fulfilled-by",
    "Unnamed: 22"
], inplace=True)

print(df_amazon.columns)
print(len(df_amazon.columns))
# Out:
# Index(['Date', 'Status', 'Fulfilment', 'ship-service-level', 'Category',
#        'Size', 'Courier Status', 'Qty', 'currency', 'Amount', 'promotion-ids',
#        'B2B'],
#       dtype='object')
# 12

# %%
df_amazon.head()
# Out:
#        Date                        Status Fulfilment ship-service-level  \
# 0  04-30-22                     Cancelled   Merchant           Standard
# 1  04-30-22  Shipped - Delivered to Buyer   Merchant           Standard
# 2  04-30-22                       Shipped     Amazon          Expedited
# 3  04-30-22                     Cancelled   Merchant           Standard
# 4  04-30-22                       Shipped     Amazon          Expedited
#
#         Category Size Courier Status  Qty currency  Amount  \
# 0            Set    S            NaN    0      INR  647.62
# 1          kurta  3XL        Shipped    1      INR  406.00
# 2          kurta   XL        Shipped    1      INR  329.00
# 3  Western Dress    L            NaN    0      INR  753.33
# 4            Top  3XL        Shipped    1      INR  574.00
#
#                                        promotion-ids    B2B
# 0                                                NaN  False
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True
# 3                                                NaN  False
# 4                                                NaN  False

# %%
# 3. Status - Get the unique entries and key them with a number
value_counts = df_amazon['Status'].value_counts()
print(value_counts)

# These are the status' we want to keep
entries_to_keep = ["Shipped", "Shipped - Delivered to Buyer", "Cancelled"]

# Filter the DataFrame to keep only the rows where the 'Status' column has one of the desired entries
df_amazon = df_amazon[df_amazon['Status'].isin(entries_to_keep)]
df_amazon = df_amazon.reset_index(drop=True)

# One hot Encoding
df_amazon = pd.get_dummies(df_amazon, columns=["Status"])
df_amazon.head()
# Out:
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64
#        Date Fulfilment ship-service-level       Category Size Courier Status  \
# 0  04-30-22   Merchant           Standard            Set    S            NaN
# 1  04-30-22   Merchant           Standard          kurta  3XL        Shipped
# 2  04-30-22     Amazon          Expedited          kurta   XL        Shipped
# 3  04-30-22   Merchant           Standard  Western Dress    L            NaN
# 4  04-30-22     Amazon          Expedited            Top  3XL        Shipped
#
#    Qty currency  Amount                                      promotion-ids  \
# 0    0      INR  647.62                                                NaN
# 1    1      INR  406.00  Amazon PLCC Free-Financing Universal Merchant ...
# 2    1      INR  329.00       IN Core Free Shipping 2015/04/08 23-48-5-108
# 3    0      INR  753.33                                                NaN
# 4    1      INR  574.00                                                NaN
#
#      B2B  Status_Cancelled  Status_Shipped  \
# 0  False              True           False
# 1  False             False           False
# 2   True             False            True
# 3  False              True           False
# 4  False             False            True
#
#    Status_Shipped - Delivered to Buyer
# 0                                False
# 1                                 True
# 2                                False
# 3                                False
# 4                                False

# %%
# 4. Fulfillment - Label Encode

# Unique Values
unique_fulfillment = df_amazon["Fulfilment"].unique()
print(unique_fulfillment)

# Counts of values
fulfillment_counts = df_amazon['Fulfilment'].value_counts()
print(fulfillment_counts)

df_amazon = pd.get_dummies(df_amazon, columns=["Fulfilment"])
df_amazon.head()
# Out:
# ['Merchant' 'Amazon']
# Fulfilment
# Amazon      89275
# Merchant    35630
# Name: count, dtype: int64
#        Date ship-service-level       Category Size Courier Status  Qty  \
# 0  04-30-22           Standard            Set    S            NaN    0
# 1  04-30-22           Standard          kurta  3XL        Shipped    1
# 2  04-30-22          Expedited          kurta   XL        Shipped    1
# 3  04-30-22           Standard  Western Dress    L            NaN    0
# 4  04-30-22          Expedited            Top  3XL        Shipped    1
#
#   currency  Amount                                      promotion-ids    B2B  \
# 0      INR  647.62                                                NaN  False
# 1      INR  406.00  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2      INR  329.00       IN Core Free Shipping 2015/04/08 23-48-5-108   True
# 3      INR  753.33                                                NaN  False
# 4      INR  574.00                                                NaN  False
#
#    Status_Cancelled  Status_Shipped  Status_Shipped - Delivered to Buyer  \
# 0              True           False                                False
# 1             False           False                                 True
# 2             False            True                                False
# 3              True           False                                False
# 4             False            True                                False
#
#    Fulfilment_Amazon  Fulfilment_Merchant
# 0              False                 True
# 1              False                 True
# 2               True                False
# 3              False                 True
# 4               True                False

# %%
# 5. Ship-Service-Level: Label Encode

# Unique Values
unique_service = df_amazon["ship-service-level"].unique()
print(unique_service)

# Counts of values
service_counts = df_amazon["ship-service-level"].value_counts()
print(service_counts)

df_amazon = pd.get_dummies(df_amazon, columns=["ship-service-level"])
df_amazon.head()
# Out:
# ['Standard' 'Expedited']
# ship-service-level
# Expedited    88202
# Standard     36703
# Name: count, dtype: int64
#        Date       Category Size Courier Status  Qty currency  Amount  \
# 0  04-30-22            Set    S            NaN    0      INR  647.62
# 1  04-30-22          kurta  3XL        Shipped    1      INR  406.00
# 2  04-30-22          kurta   XL        Shipped    1      INR  329.00
# 3  04-30-22  Western Dress    L            NaN    0      INR  753.33
# 4  04-30-22            Top  3XL        Shipped    1      INR  574.00
#
#                                        promotion-ids    B2B  Status_Cancelled  \
# 0                                                NaN  False              True
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False             False
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True             False
# 3                                                NaN  False              True
# 4                                                NaN  False             False
#
#    Status_Shipped  Status_Shipped - Delivered to Buyer  Fulfilment_Amazon  \
# 0           False                                False              False
# 1           False                                 True              False
# 2            True                                False               True
# 3           False                                False              False
# 4            True                                False               True
#
#    Fulfilment_Merchant  ship-service-level_Expedited  \
# 0                 True                         False
# 1                 True                         False
# 2                False                          True
# 3                 True                         False
# 4                False                          True
#
#    ship-service-level_Standard
# 0                         True
# 1                         True
# 2                        False
# 3                         True
# 4                        False

# %%
# 6. Category - Label Encoding

# Unique Values
unique_categories = df_amazon["Category"].unique()
print(unique_categories)

# Counts of values
service_categories = df_amazon["Category"].value_counts()
print(service_categories)

# One hot encoding
df_amazon = pd.get_dummies(df_amazon, columns=["Category"])
df_amazon.head()
# Out:
# ['Set' 'kurta' 'Western Dress' 'Top' 'Ethnic Dress' 'Bottom' 'Saree'
#  'Blouse' 'Dupatta']
# Category
# Set              48646
# kurta            48500
# Western Dress    14792
# Top              10339
# Ethnic Dress      1134
# Blouse             908
# Bottom             421
# Saree              162
# Dupatta              3
# Name: count, dtype: int64
#        Date Size Courier Status  Qty currency  Amount  \
# 0  04-30-22    S            NaN    0      INR  647.62
# 1  04-30-22  3XL        Shipped    1      INR  406.00
# 2  04-30-22   XL        Shipped    1      INR  329.00
# 3  04-30-22    L            NaN    0      INR  753.33
# 4  04-30-22  3XL        Shipped    1      INR  574.00
#
#                                        promotion-ids    B2B  Status_Cancelled  \
# 0                                                NaN  False              True
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False             False
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True             False
# 3                                                NaN  False              True
# 4                                                NaN  False             False
#
#    Status_Shipped  ...  ship-service-level_Standard  Category_Blouse  \
# 0           False  ...                         True            False
# 1           False  ...                         True            False
# 2            True  ...                        False            False
# 3           False  ...                         True            False
# 4            True  ...                        False            False
#
#    Category_Bottom  Category_Dupatta  Category_Ethnic Dress  Category_Saree  \
# 0            False             False                  False           False
# 1            False             False                  False           False
# 2            False             False                  False           False
# 3            False             False                  False           False
# 4            False             False                  False           False
#
#    Category_Set  Category_Top  Category_Western Dress  Category_kurta
# 0          True         False                   False           False
# 1         False         False                   False            True
# 2         False         False                   False            True
# 3         False         False                    True           False
# 4         False          True                   False           False
#
# [5 rows x 24 columns]

# %%
# 7. Size - Label Encoding

# Unique Values
unique_sizes = df_amazon["Size"].unique()
print(unique_sizes)

# Counts of values
size_counts = df_amazon["Size"].value_counts()
print(size_counts)

# Map the sizes
size_mapping = {
    "XS": 1,
    "S": 2,
    "M": 3,
    "L": 4,
    "XL": 5,
    "XXL": 6,
    "3XL": 7,
    "4XL": 8,
    "5XL": 9,
    "6XL": 10,
    "Free": 11
}

# Encode it and head
df_amazon["Size"] = df_amazon["Size"].map(size_mapping)
df_amazon.head()
# Out:
# ['S' '3XL' 'XL' 'L' 'XXL' 'XS' '6XL' 'M' '4XL' '5XL' 'Free']
# Size
# M       21928
# L       21430
# XL      20186
# XXL     17529
# S       16576
# 3XL     14371
# XS      10849
# 6XL       722
# 5XL       532
# 4XL       411
# Free      371
# Name: count, dtype: int64
#        Date  Size Courier Status  Qty currency  Amount  \
# 0  04-30-22     2            NaN    0      INR  647.62
# 1  04-30-22     7        Shipped    1      INR  406.00
# 2  04-30-22     5        Shipped    1      INR  329.00
# 3  04-30-22     4            NaN    0      INR  753.33
# 4  04-30-22     7        Shipped    1      INR  574.00
#
#                                        promotion-ids    B2B  Status_Cancelled  \
# 0                                                NaN  False              True
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False             False
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True             False
# 3                                                NaN  False              True
# 4                                                NaN  False             False
#
#    Status_Shipped  ...  ship-service-level_Standard  Category_Blouse  \
# 0           False  ...                         True            False
# 1           False  ...                         True            False
# 2            True  ...                        False            False
# 3           False  ...                         True            False
# 4            True  ...                        False            False
#
#    Category_Bottom  Category_Dupatta  Category_Ethnic Dress  Category_Saree  \
# 0            False             False                  False           False
# 1            False             False                  False           False
# 2            False             False                  False           False
# 3            False             False                  False           False
# 4            False             False                  False           False
#
#    Category_Set  Category_Top  Category_Western Dress  Category_kurta
# 0          True         False                   False           False
# 1         False         False                   False            True
# 2         False         False                   False            True
# 3         False         False                    True           False
# 4         False          True                   False           False
#
# [5 rows x 24 columns]

# %%
# 8. Courier Status - Label Encoding

# Unique Values
unique_courier_status = df_amazon["Courier Status"].unique()
print(unique_courier_status)

# Counts of values
courier_status_counts = df_amazon["Courier Status"].value_counts()
print(courier_status_counts)

# Should drop? I will drop it as of now
df_amazon.drop(columns=["Courier Status"], inplace=True)
df_amazon
# Out:
# [nan 'Shipped' 'Cancelled' 'Unshipped']
# Courier Status
# Shipped      106357
# Cancelled      5933
# Unshipped      5746
# Name: count, dtype: int64
#             Date  Size  Qty currency   Amount  \
# 0       04-30-22     2    0      INR   647.62
# 1       04-30-22     7    1      INR   406.00
# 2       04-30-22     5    1      INR   329.00
# 3       04-30-22     4    0      INR   753.33
# 4       04-30-22     7    1      INR   574.00
# ...          ...   ...  ...      ...      ...
# 124900  05-31-22     5    1      INR   517.00
# 124901  05-31-22     3    1      INR   999.00
# 124902  05-31-22     6    1      INR   690.00
# 124903  05-31-22     1    1      INR  1199.00
# 124904  05-31-22     2    1      INR   696.00
#
#                                             promotion-ids    B2B  \
# 0                                                     NaN  False
# 1       Amazon PLCC Free-Financing Universal Merchant ...  False
# 2            IN Core Free Shipping 2015/04/08 23-48-5-108   True
# 3                                                     NaN  False
# 4                                                     NaN  False
# ...                                                   ...    ...
# 124900                                                NaN  False
# 124901       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 124902                                                NaN  False
# 124903       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 124904       IN Core Free Shipping 2015/04/08 23-48-5-108  False
#
#         Status_Cancelled  Status_Shipped  Status_Shipped - Delivered to Buyer  \
# 0                   True           False                                False
# 1                  False           False                                 True
# 2                  False            True                                False
# 3                   True           False                                False
# 4                  False            True                                False
# ...                  ...             ...                                  ...
# 124900             False            True                                False
# 124901             False            True                                False
# 124902             False            True                                False
# 124903             False            True                                False
# 124904             False            True                                False
#
#         ...  ship-service-level_Standard  Category_Blouse  Category_Bottom  \
# 0       ...                         True            False            False
# 1       ...                         True            False            False
# 2       ...                        False            False            False
# 3       ...                         True            False            False
# 4       ...                        False            False            False
# ...     ...                          ...              ...              ...
# 124900  ...                        False            False            False
# 124901  ...                        False            False            False
# 124902  ...                        False            False            False
# 124903  ...                        False            False            False
# 124904  ...                        False            False            False
#
#         Category_Dupatta  Category_Ethnic Dress  Category_Saree  Category_Set  \
# 0                  False                  False           False          True
# 1                  False                  False           False         False
# 2                  False                  False           False         False
# 3                  False                  False           False         False
# 4                  False                  False           False         False
# ...                  ...                    ...             ...           ...
# 124900             False                  False           False         False
# 124901             False                  False           False          True
# 124902             False                  False           False         False
# 124903             False                  False           False          True
# 124904             False                  False           False          True
#
#         Category_Top  Category_Western Dress  Category_kurta
# 0              False                   False           False
# 1              False                   False            True
# 2              False                   False            True
# 3              False                    True           False
# 4               True                   False           False
# ...              ...                     ...             ...
# 124900         False                   False            True
# 124901         False                   False           False
# 124902         False                    True           False
# 124903         False                   False           False
# 124904         False                   False           False
#
# [124905 rows x 23 columns]

# %%
# 9. Quantity - Exploring the different quantities bought

# Unique Values
unique_qty = df_amazon["Qty"].unique()
print(unique_qty)

# Counts of values
qty_counts = df_amazon["Qty"].value_counts()
print(qty_counts)
# Out:
# [ 0  1  2 15  3  9 13  5  4  8]
# Qty
# 1     111739
# 0      12802
# 2        324
# 3         26
# 4          8
# 5          2
# 15         1
# 9          1
# 13         1
# 8          1
# Name: count, dtype: int64

# %%
# 10: Currency Label - Viewing different types, dropping nan

unique_currency = df_amazon["currency"].unique()
print(unique_currency)

# Counts of values
currency_counts = df_amazon["currency"].value_counts()
print(currency_counts)

# Drop rows with nan
df_amazon.dropna(subset=['currency'], inplace=True)

# Drop currency column, all INR
df_amazon.drop(columns=['currency'], inplace=True)
df_amazon.head()
# Out:
# ['INR' nan]
# currency
# INR    117123
# Name: count, dtype: int64
#        Date  Size  Qty  Amount  \
# 0  04-30-22     2    0  647.62
# 1  04-30-22     7    1  406.00
# 2  04-30-22     5    1  329.00
# 3  04-30-22     4    0  753.33
# 4  04-30-22     7    1  574.00
#
#                                        promotion-ids    B2B  Status_Cancelled  \
# 0                                                NaN  False              True
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False             False
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True             False
# 3                                                NaN  False              True
# 4                                                NaN  False             False
#
#    Status_Shipped  Status_Shipped - Delivered to Buyer  Fulfilment_Amazon  \
# 0           False                                False              False
# 1           False                                 True              False
# 2            True                                False               True
# 3           False                                False              False
# 4            True                                False               True
#
#    ...  ship-service-level_Standard  Category_Blouse  Category_Bottom  \
# 0  ...                         True            False            False
# 1  ...                         True            False            False
# 2  ...                        False            False            False
# 3  ...                         True            False            False
# 4  ...                        False            False            False
#
#    Category_Dupatta  Category_Ethnic Dress  Category_Saree  Category_Set  \
# 0             False                  False           False          True
# 1             False                  False           False         False
# 2             False                  False           False         False
# 3             False                  False           False         False
# 4             False                  False           False         False
#
#    Category_Top  Category_Western Dress  Category_kurta
# 0         False                   False           False
# 1         False                   False            True
# 2         False                   False            True
# 3         False                    True           False
# 4          True                   False           False
#
# [5 rows x 22 columns]

# %%
# 11: Promotion IDs - Convert to boolean
df_amazon["promotion-ids"] = df_amazon["promotion-ids"].apply(lambda x: 0 if pd.isna(x) else 1)
df_amazon.head()
# Out:
#        Date  Size  Qty  Amount  promotion-ids    B2B  Status_Cancelled  \
# 0  04-30-22     2    0  647.62              0  False              True
# 1  04-30-22     7    1  406.00              1  False             False
# 2  04-30-22     5    1  329.00              1   True             False
# 3  04-30-22     4    0  753.33              0  False              True
# 4  04-30-22     7    1  574.00              0  False             False
#
#    Status_Shipped  Status_Shipped - Delivered to Buyer  Fulfilment_Amazon  \
# 0           False                                False              False
# 1           False                                 True              False
# 2            True                                False               True
# 3           False                                False              False
# 4            True                                False               True
#
#    ...  ship-service-level_Standard  Category_Blouse  Category_Bottom  \
# 0  ...                         True            False            False
# 1  ...                         True            False            False
# 2  ...                        False            False            False
# 3  ...                         True            False            False
# 4  ...                        False            False            False
#
#    Category_Dupatta  Category_Ethnic Dress  Category_Saree  Category_Set  \
# 0             False                  False           False          True
# 1             False                  False           False         False
# 2             False                  False           False         False
# 3             False                  False           False         False
# 4             False                  False           False         False
#
#    Category_Top  Category_Western Dress  Category_kurta
# 0         False                   False           False
# 1         False                   False            True
# 2         False                   False            True
# 3         False                    True           False
# 4          True                   False           False
#
# [5 rows x 22 columns]

# %%
# 12: B2B - Convert to boolean
df_amazon["B2B"] = df_amazon["B2B"].astype(int)
df_amazon.head()
# Out:
#        Date  Size  Qty  Amount  promotion-ids  B2B  Status_Cancelled  \
# 0  04-30-22     2    0  647.62              0    0              True
# 1  04-30-22     7    1  406.00              1    0             False
# 2  04-30-22     5    1  329.00              1    1             False
# 3  04-30-22     4    0  753.33              0    0              True
# 4  04-30-22     7    1  574.00              0    0             False
#
#    Status_Shipped  Status_Shipped - Delivered to Buyer  Fulfilment_Amazon  \
# 0           False                                False              False
# 1           False                                 True              False
# 2            True                                False               True
# 3           False                                False              False
# 4            True                                False               True
#
#    ...  ship-service-level_Standard  Category_Blouse  Category_Bottom  \
# 0  ...                         True            False            False
# 1  ...                         True            False            False
# 2  ...                        False            False            False
# 3  ...                         True            False            False
# 4  ...                        False            False            False
#
#    Category_Dupatta  Category_Ethnic Dress  Category_Saree  Category_Set  \
# 0             False                  False           False          True
# 1             False                  False           False         False
# 2             False                  False           False         False
# 3             False                  False           False         False
# 4             False                  False           False         False
#
#    Category_Top  Category_Western Dress  Category_kurta
# 0         False                   False           False
# 1         False                   False            True
# 2         False                   False            True
# 3         False                    True           False
# 4          True                   False           False
#
# [5 rows x 22 columns]

# %%
# Date: Convert Date to datetime and seperate into year, month, day
df_amazon["Date"] = pd.to_datetime(df_amazon['Date'], format='%m-%d-%y')

# df_amazon['Year'] = df_amazon['Date'].dt.year # Only one year: 2022
df_amazon['Month'] = df_amazon['Date'].dt.month
df_amazon['Day'] = df_amazon['Date'].dt.day

df_amazon.drop(columns=["Date"], inplace=True)

df_amazon
# Out:
#         Size  Qty   Amount  promotion-ids  B2B  Status_Cancelled  \
# 0          2    0   647.62              0    0              True
# 1          7    1   406.00              1    0             False
# 2          5    1   329.00              1    1             False
# 3          4    0   753.33              0    0              True
# 4          7    1   574.00              0    0             False
# ...      ...  ...      ...            ...  ...               ...
# 124900     5    1   517.00              0    0             False
# 124901     3    1   999.00              1    0             False
# 124902     6    1   690.00              0    0             False
# 124903     1    1  1199.00              1    0             False
# 124904     2    1   696.00              1    0             False
#
#         Status_Shipped  Status_Shipped - Delivered to Buyer  \
# 0                False                                False
# 1                False                                 True
# 2                 True                                False
# 3                False                                False
# 4                 True                                False
# ...                ...                                  ...
# 124900            True                                False
# 124901            True                                False
# 124902            True                                False
# 124903            True                                False
# 124904            True                                False
#
#         Fulfilment_Amazon  Fulfilment_Merchant  ...  Category_Bottom  \
# 0                   False                 True  ...            False
# 1                   False                 True  ...            False
# 2                    True                False  ...            False
# 3                   False                 True  ...            False
# 4                    True                False  ...            False
# ...                   ...                  ...  ...              ...
# 124900               True                False  ...            False
# 124901               True                False  ...            False
# 124902               True                False  ...            False
# 124903               True                False  ...            False
# 124904               True                False  ...            False
#
#         Category_Dupatta  Category_Ethnic Dress  Category_Saree  Category_Set  \
# 0                  False                  False           False          True
# 1                  False                  False           False         False
# 2                  False                  False           False         False
# 3                  False                  False           False         False
# 4                  False                  False           False         False
# ...                  ...                    ...             ...           ...
# 124900             False                  False           False         False
# 124901             False                  False           False          True
# 124902             False                  False           False         False
# 124903             False                  False           False          True
# 124904             False                  False           False          True
#
#         Category_Top  Category_Western Dress  Category_kurta  Month  Day
# 0              False                   False           False      4   30
# 1              False                   False            True      4   30
# 2              False                   False            True      4   30
# 3              False                    True           False      4   30
# 4               True                   False           False      4   30
# ...              ...                     ...             ...    ...  ...
# 124900         False                   False            True      5   31
# 124901         False                   False           False      5   31
# 124902         False                    True           False      5   31
# 124903         False                   False           False      5   31
# 124904         False                   False           False      5   31
#
# [117123 rows x 23 columns]

# %%
# Correlation matrix
df_amazon.corr(numeric_only=True)
# Out:
#                                          Size       Qty    Amount  \
# Size                                 1.000000  0.005153 -0.021174
# Qty                                  0.005153  1.000000  0.064085
# Amount                              -0.021174  0.064085  1.000000
# promotion-ids                       -0.031839  0.278905  0.127248
# B2B                                  0.004317  0.013801  0.015589
# Status_Cancelled                    -0.021816 -0.637055 -0.005996
# Status_Shipped                      -0.008581  0.282132  0.002762
# Status_Shipped - Delivered to Buyer  0.024070  0.117669  0.000991
# Fulfilment_Amazon                   -0.020830  0.316172  0.008308
# Fulfilment_Merchant                  0.020830 -0.316172 -0.008308
# ship-service-level_Expedited        -0.020028  0.310542  0.045197
# ship-service-level_Standard          0.020028 -0.310542 -0.045197
# Category_Blouse                      0.054281 -0.000989 -0.039258
# Category_Bottom                      0.002422 -0.004587 -0.059684
# Category_Dupatta                     0.017858  0.000942 -0.006184
# Category_Ethnic Dress                0.000863  0.001297  0.026024
# Category_Saree                       0.127616  0.003465  0.019399
# Category_Set                        -0.092610  0.000805  0.525655
# Category_Top                        -0.000153  0.018151 -0.131388
# Category_Western Dress              -0.020364 -0.024604  0.152365
# Category_kurta                       0.086648  0.005426 -0.544696
# Month                                0.012612  0.013795  0.052529
# Day                                  0.001168 -0.012846  0.010466
#
#                                      promotion-ids       B2B  \
# Size                                     -0.031839  0.004317
# Qty                                       0.278905  0.013801
# Amount                                    0.127248  0.015589
# promotion-ids                             1.000000 -0.000723
# B2B                                      -0.000723  1.000000
# Status_Cancelled                         -0.427550 -0.010542
# Status_Shipped                           -0.122639 -0.003579
# Status_Shipped - Delivered to Buyer       0.421715  0.011008
# Fulfilment_Amazon                        -0.269829 -0.006356
# Fulfilment_Merchant                       0.269829  0.006356
# ship-service-level_Expedited             -0.244862 -0.004869
# ship-service-level_Standard               0.244862  0.004869
# Category_Blouse                          -0.015841  0.002293
# Category_Bottom                           0.004346  0.002054
# Category_Dupatta                          0.003752 -0.000426
# Category_Ethnic Dress                    -0.012617  0.006957
# Category_Saree                            0.007543  0.002607
# Category_Set                              0.079984  0.000026
# Category_Top                             -0.046891 -0.004268
# Category_Western Dress                    0.074076  0.002331
# Category_kurta                           -0.098454 -0.001338
# Month                                    -0.040230 -0.002522
# Day                                       0.009064  0.006505
#
#                                      Status_Cancelled  Status_Shipped  \
# Size                                        -0.021816       -0.008581
# Qty                                         -0.637055        0.282132
# Amount                                      -0.005996        0.002762
# promotion-ids                               -0.427550       -0.122639
# B2B                                         -0.010542       -0.003579
# Status_Cancelled                             1.000000       -0.445776
# Status_Shipped                              -0.445776        1.000000
# Status_Shipped - Delivered to Buyer         -0.181515       -0.799359
# Fulfilment_Amazon                           -0.131647        0.894178
# Fulfilment_Merchant                          0.131647       -0.894178
# ship-service-level_Expedited                -0.125452        0.875218
# ship-service-level_Standard                  0.125452       -0.875218
# Category_Blouse                             -0.001495        0.009976
# Category_Bottom                              0.002094       -0.013808
# Category_Dupatta                            -0.001610        0.003612
# Category_Ethnic Dress                       -0.005649        0.008820
# Category_Saree                              -0.001689        0.008816
# Category_Set                                 0.001499        0.018002
# Category_Top                                -0.008456        0.038110
# Category_Western Dress                       0.004408       -0.100265
# Category_kurta                               0.001647        0.024509
# Month                                       -0.000612        0.061902
# Day                                         -0.003082       -0.016285
#
#                                      Status_Shipped - Delivered to Buyer  \
# Size                                                            0.024070
# Qty                                                             0.117669
# Amount                                                          0.000991
# promotion-ids                                                   0.421715
# B2B                                                             0.011008
# Status_Cancelled                                               -0.181515
# Status_Shipped                                                 -0.799359
# Status_Shipped - Delivered to Buyer                             1.000000
# Fulfilment_Amazon                                              -0.893960
# Fulfilment_Merchant                                             0.893960
# ship-service-level_Expedited                                   -0.877289
# ship-service-level_Standard                                     0.877289
# Category_Blouse                                                -0.009955
# Category_Bottom                                                 0.013764
# Category_Dupatta                                               -0.002887
# Category_Ethnic Dress                                          -0.005898
# Category_Saree                                                 -0.008551
# Category_Set                                                   -0.020783
# Category_Top                                                   -0.036190
# Category_Western Dress                                          0.107190
# Category_kurta                                                 -0.028030
# Month                                                          -0.067593
# Day                                                             0.019959
#
#                                      Fulfilment_Amazon  Fulfilment_Merchant  \
# Size                                         -0.020830             0.020830
# Qty                                           0.316172            -0.316172
# Amount                                        0.008308            -0.008308
# promotion-ids                                -0.269829             0.269829
# B2B                                          -0.006356             0.006356
# Status_Cancelled                             -0.131647             0.131647
# Status_Shipped                                0.894178            -0.894178
# Status_Shipped - Delivered to Buyer          -0.893960             0.893960
# Fulfilment_Amazon                             1.000000            -1.000000
# Fulfilment_Merchant                          -1.000000             1.000000
# ship-service-level_Expedited                  0.981351            -0.981351
# ship-service-level_Standard                  -0.981351             0.981351
# Category_Blouse                               0.008093            -0.008093
# Category_Bottom                              -0.016098             0.016098
# Category_Dupatta                              0.003230            -0.003230
# Category_Ethnic Dress                         0.006357            -0.006357
# Category_Saree                                0.007965            -0.007965
# Category_Set                                  0.021247            -0.021247
# Category_Top                                  0.043454            -0.043454
# Category_Western Dress                       -0.113125             0.113125
# Category_kurta                                0.027930            -0.027930
# Month                                         0.071140            -0.071140
# Day                                          -0.023914             0.023914
#
#                                      ...  Category_Bottom  Category_Dupatta  \
# Size                                 ...         0.002422          0.017858
# Qty                                  ...        -0.004587          0.000942
# Amount                               ...        -0.059684         -0.006184
# promotion-ids                        ...         0.004346          0.003752
# B2B                                  ...         0.002054         -0.000426
# Status_Cancelled                     ...         0.002094         -0.001610
# Status_Shipped                       ...        -0.013808          0.003612
# Status_Shipped - Delivered to Buyer  ...         0.013764         -0.002887
# Fulfilment_Amazon                    ...        -0.016098          0.003230
# Fulfilment_Merchant                  ...         0.016098         -0.003230
# ship-service-level_Expedited         ...        -0.016252          0.003291
# ship-service-level_Standard          ...         0.016252         -0.003291
# Category_Blouse                      ...        -0.005050         -0.000436
# Category_Bottom                      ...         1.000000         -0.000297
# Category_Dupatta                     ...        -0.000297          1.000000
# Category_Ethnic Dress                ...        -0.005623         -0.000486
# Category_Saree                       ...        -0.002120         -0.000183
# Category_Set                         ...        -0.046643         -0.004028
# Category_Top                         ...        -0.017795         -0.001537
# Category_Western Dress               ...        -0.021594         -0.001865
# Category_kurta                       ...        -0.046584         -0.004022
# Month                                ...        -0.005800          0.006886
# Day                                  ...         0.015278          0.006564
#
#                                      Category_Ethnic Dress  Category_Saree  \
# Size                                              0.000863        0.127616
# Qty                                               0.001297        0.003465
# Amount                                            0.026024        0.019399
# promotion-ids                                    -0.012617        0.007543
# B2B                                               0.006957        0.002607
# Status_Cancelled                                 -0.005649       -0.001689
# Status_Shipped                                    0.008820        0.008816
# Status_Shipped - Delivered to Buyer              -0.005898       -0.008551
# Fulfilment_Amazon                                 0.006357        0.007965
# Fulfilment_Merchant                              -0.006357       -0.007965
# ship-service-level_Expedited                      0.005391        0.008003
# ship-service-level_Standard                      -0.005391       -0.008003
# Category_Blouse                                  -0.008265       -0.003116
# Category_Bottom                                  -0.005623       -0.002120
# Category_Dupatta                                 -0.000486       -0.000183
# Category_Ethnic Dress                             1.000000       -0.003469
# Category_Saree                                   -0.003469        1.000000
# Category_Set                                     -0.076339       -0.028781
# Category_Top                                     -0.029124       -0.010980
# Category_Western Dress                           -0.035342       -0.013324
# Category_kurta                                   -0.076243       -0.028744
# Month                                             0.012679       -0.007759
# Day                                              -0.000246        0.003218
#
#                                      Category_Set  Category_Top  \
# Size                                    -0.092610     -0.000153
# Qty                                      0.000805      0.018151
# Amount                                   0.525655     -0.131388
# promotion-ids                            0.079984     -0.046891
# B2B                                      0.000026     -0.004268
# Status_Cancelled                         0.001499     -0.008456
# Status_Shipped                           0.018002      0.038110
# Status_Shipped - Delivered to Buyer     -0.020783     -0.036190
# Fulfilment_Amazon                        0.021247      0.043454
# Fulfilment_Merchant                     -0.021247     -0.043454
# ship-service-level_Expedited             0.019679      0.044336
# ship-service-level_Standard             -0.019679     -0.044336
# Category_Blouse                         -0.068562     -0.026157
# Category_Bottom                         -0.046643     -0.017795
# Category_Dupatta                        -0.004028     -0.001537
# Category_Ethnic Dress                   -0.076339     -0.029124
# Category_Saree                          -0.028781     -0.010980
# Category_Set                             1.000000     -0.241592
# Category_Top                            -0.241592      1.000000
# Category_Western Dress                  -0.293174     -0.111847
# Category_kurta                          -0.632467     -0.241288
# Month                                   -0.035618     -0.011965
# Day                                     -0.015752      0.015603
#
#                                      Category_Western Dress  Category_kurta  \
# Size                                              -0.020364        0.086648
# Qty                                               -0.024604        0.005426
# Amount                                             0.152365       -0.544696
# promotion-ids                                      0.074076       -0.098454
# B2B                                                0.002331       -0.001338
# Status_Cancelled                                   0.004408        0.001647
# Status_Shipped                                    -0.100265        0.024509
# Status_Shipped - Delivered to Buyer                0.107190       -0.028030
# Fulfilment_Amazon                                 -0.113125        0.027930
# Fulfilment_Merchant                                0.113125       -0.027930
# ship-service-level_Expedited                      -0.110104        0.027209
# ship-service-level_Standard                        0.110104       -0.027209
# Category_Blouse                                   -0.031741       -0.068476
# Category_Bottom                                   -0.021594       -0.046584
# Category_Dupatta                                  -0.001865       -0.004022
# Category_Ethnic Dress                             -0.035342       -0.076243
# Category_Saree                                    -0.013324       -0.028744
# Category_Set                                      -0.293174       -0.632467
# Category_Top                                      -0.111847       -0.241288
# Category_Western Dress                             1.000000       -0.292805
# Category_kurta                                    -0.292805        1.000000
# Month                                              0.069367       -0.002103
# Day                                                0.029649       -0.016111
#
#                                         Month       Day
# Size                                 0.012612  0.001168
# Qty                                  0.013795 -0.012846
# Amount                               0.052529  0.010466
# promotion-ids                       -0.040230  0.009064
# B2B                                 -0.002522  0.006505
# Status_Cancelled                    -0.000612 -0.003082
# Status_Shipped                       0.061902 -0.016285
# Status_Shipped - Delivered to Buyer -0.067593  0.019959
# Fulfilment_Amazon                    0.071140 -0.023914
# Fulfilment_Merchant                 -0.071140  0.023914
# ship-service-level_Expedited         0.069362 -0.024138
# ship-service-level_Standard         -0.069362  0.024138
# Category_Blouse                     -0.016577  0.006421
# Category_Bottom                     -0.005800  0.015278
# Category_Dupatta                     0.006886  0.006564
# Category_Ethnic Dress                0.012679 -0.000246
# Category_Saree                      -0.007759  0.003218
# Category_Set                        -0.035618 -0.015752
# Category_Top                        -0.011965  0.015603
# Category_Western Dress               0.069367  0.029649
# Category_kurta                      -0.002103 -0.016111
# Month                                1.000000 -0.109525
# Day                                 -0.109525  1.000000
#
# [23 rows x 23 columns]

# %%
# Export to csv
df_amazon.to_csv("dataset/eda_amazon_sales_report.csv")
