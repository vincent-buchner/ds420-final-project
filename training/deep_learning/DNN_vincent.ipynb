# %% [markdown]
# Not Transformed, includes dropout,  reg
# Author : Soren Basnet.

# %%
# Imports
###BEGIN library importing+
import tensorflow as tf
import matplotlib.pyplot as plt
###END library importing
from pathlib import Path
import tarfile
import urllib.request
import sys
import io
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import LocalOutlierFactor
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn import set_config
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.metrics import *
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import BaggingRegressor
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import (
    VotingRegressor,
    BaggingRegressor,
    RandomForestRegressor,
    AdaBoostRegressor,
    GradientBoostingRegressor,
    HistGradientBoostingRegressor,
    StackingRegressor)
from tensorflow.keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras import Sequential, layers
import keras_tuner as kt

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from sklearn.linear_model import LinearRegression, SGDRegressor, Ridge
from sklearn.model_selection import train_test_split
from code_files.train import train, train_in_batches, grid_search
from code_files.data_preperation import prepare_for_train
import pandas as pd
import numpy as np

# %%
# Load Dataset
df_amazon = pd.read_csv("../dataset/eda_amazon_sales_report.csv")
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117123 entries, 0 to 117122
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Unnamed: 0                           117123 non-null  int64
#  1   Size                                 117123 non-null  int64
#  2   Qty                                  117123 non-null  int64
#  3   Amount                               117123 non-null  float64
#  4   promotion-ids                        117123 non-null  int64
#  5   B2B                                  117123 non-null  int64
#  6   Status_Cancelled                     117123 non-null  bool
#  7   Status_Shipped                       117123 non-null  bool
#  8   Status_Shipped - Delivered to Buyer  117123 non-null  bool
#  9   Fulfilment_Amazon                    117123 non-null  bool
#  10  Fulfilment_Merchant                  117123 non-null  bool
#  11  ship-service-level_Expedited         117123 non-null  bool
#  12  ship-service-level_Standard          117123 non-null  bool
#  13  Category_Blouse                      117123 non-null  bool
#  14  Category_Bottom                      117123 non-null  bool
#  15  Category_Dupatta                     117123 non-null  bool
#  16  Category_Ethnic Dress                117123 non-null  bool
#  17  Category_Saree                       117123 non-null  bool
#  18  Category_Set                         117123 non-null  bool
#  19  Category_Top                         117123 non-null  bool
#  20  Category_Western Dress               117123 non-null  bool
#  21  Category_kurta                       117123 non-null  bool
#  22  Month                                117123 non-null  int64
#  23  Day                                  117123 non-null  int64
# dtypes: bool(16), float64(1), int64(7)
# memory usage: 8.9 MB

# %%
# Split and Prepare for train
dftrain, dftest = train_test_split(df_amazon, test_size=0.1, random_state=42)
Xtrain_prepared, ytrain_prepared, Xtest_prepared, ytest_prepared = prepare_for_train(dftrain, dftest)

Xtrain_prepared, Xdev_prepared, ytrain_prepared, ydev_prepared = train_test_split(Xtrain_prepared, ytrain_prepared,
                                                                                  test_size=0.2, random_state=42)


print("Train shape: ", Xtrain_prepared.shape, ytrain_prepared.shape)
print("Dev shape: ", Xdev_prepared.shape, ydev_prepared.shape)
print("Test shape: ", Xtest_prepared.shape, ytest_prepared.shape)
# Out:
# Train shape:  (83216, 7) (83216,)
# Dev shape:  (20804, 7) (20804,)
# Test shape:  (11713, 7) (11713,)

# %%
# # Helping function to build the model
# def build_model(hp):
#     # Hyperparameters to tune
#     n_hidden = hp.Int("n_hidden", min_value=2, max_value=32, default=4)  
#     n_neurons = hp.Int("n_neurons", min_value=100, max_value=1000, step=10)  
#     learning_rate = hp.Float("learning_rate", min_value=1e-4, max_value=0.1, sampling="log")  
#     optimizer_choice = hp.Choice("optimizer", values=["sgd", "RMSprop", "adam"]) 
#     activation_choice = hp.Choice("activation", values=["relu", "tanh", "selu","linear"])  
#     #batch_size = hp.Int("batch_size", min_value=16, max_value=128, step=16)  # Batch size range to tune

#     if optimizer_choice == "sgd":
#         optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
#     elif optimizer_choice == "RMSprop":
#         optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
#     else:
#         optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

#     model = Sequential()
#     model.add(layers.Input(shape=(7,)))  

#     for _ in range(n_hidden):
#         model.add(layers.Dense(units=n_neurons, activation=activation_choice))

#     model.add(layers.Dense(1, activation="linear"))

#     model.compile(loss="mse", optimizer=optimizer, metrics=[tf.keras.metrics.RootMeanSquaredError()])
    
#     return model

# out_folder = "amazon"
# rnd_search_folder = "rnd_search"

# random_search_tuner = kt.RandomSearch(
#     build_model,
#     objective="val_loss",
#     max_trials=5,
#     overwrite=True,
#     directory=out_folder,
#     project_name=rnd_search_folder,
#     seed=42,
# )

# random_search_tuner.search(
#     Xtrain_prepared, ytrain_prepared,
#     epochs=10,
#     batch_size=128, 
#     validation_data=(Xdev_prepared, ydev_prepared)
# )

# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras import layers
# import keras_tuner as kt

# def build_model(hp):
#     # Hyperparameters to tune
#     n_hidden = hp.Int("n_hidden", min_value=1, max_value=5, default=2)  
#     n_neurons = hp.Int("n_neurons", min_value=32, max_value=512, step=32)  
#     learning_rate = hp.Float("learning_rate", min_value=1e-4, max_value=0.1, sampling="log")  
    
#     # Dropout rate as a new hyperparameter
#     dropout_rate = hp.Float("dropout_rate", min_value=0.0, max_value=0.5, step=0.1)
    
#     optimizer_choice = hp.Choice("optimizer", values=["adam", "rmsprop", "sgd"]) 
#     activation_choice = hp.Choice("activation", values=["relu", "tanh", "selu"])  

#     # Optimizer selection
#     if optimizer_choice == "sgd":
#         optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
#     elif optimizer_choice == "rmsprop":
#         optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
#     else:
#         optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

#     # Model construction
#     model = keras.Sequential()
#     model.add(layers.Input(shape=(Xtrain_prepared.shape[1],)))  

#     # Hidden layers with dropout
#     for _ in range(n_hidden):
#         model.add(layers.Dense(units=n_neurons, activation=activation_choice))
#         model.add(layers.Dropout(rate=dropout_rate))

#     model.add(layers.Dense(1, activation="linear"))

#     model.compile(
#         loss="mse", 
#         optimizer=optimizer, 
#         metrics=[tf.keras.metrics.RootMeanSquaredError()]
#     )
    
#     return model

# # Tuner setup
# tuner = kt.RandomSearch(
#     build_model,
#     objective="val_loss",
#     max_trials=50,  # Increased number of trials
#     overwrite=True,
#     directory="hyperparameter_tuning",
#     project_name="laptop_model",
#     seed=42
# )

# # Search for best hyperparameters
# tuner.search(
#     Xtrain_prepared, ytrain_prepared,
#     epochs=50,
#     batch_size=32, 
#     validation_split=0.2,
#     callbacks=[
#         tf.keras.callbacks.EarlyStopping(patience=5)
#     ]
# )

# # Get and print best hyperparameters
# best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
# print("Best Hyperparameters:")
# print(f"Number of hidden layers: {best_hps.get('n_hidden')}")
# print(f"Number of neurons: {best_hps.get('n_neurons')}")
# print(f"Learning rate: {best_hps.get('learning_rate')}")
# print(f"Dropout rate: {best_hps.get('dropout_rate')}")
# print(f"Optimizer: {best_hps.get('optimizer')}")
# print(f"Activation: {best_hps.get('activation')}")

# # Train the best model
# best_model = tuner.hypermodel.build(best_hps)
# history = best_model.fit(
#     Xtrain_prepared, ytrain_prepared,
#     validation_split=0.2,
#     epochs=100,
#     batch_size=32,
#     callbacks=[
#         tf.keras.callbacks.EarlyStopping(patience=10)
#     ]
# )

# %%
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras import layers, regularizers

# Helping functions
def build_model(hp):

    n_hidden = hp.Int("n_hidden", min_value=2, max_value=10, default=2)
    learning_rate = hp.Float("learning_rate", min_value=1e-4, max_value=0.9,
                                      sampling="log")
    optimizer = hp.Choice("optimizer", values=["sgd", "adam", "adagrad", "rms", "adadelta", 
                                               "adamax", "nadam"])

    if optimizer == "sgd":
        optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
    elif optimizer == "adam":
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == "adagrad":
        optimizer = tf.keras.optimizers.Adagrad(learning_rate=learning_rate)
    elif optimizer == "rms": 
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
    elif optimizer == "adadelta":
        optimizer = tf.keras.optimizers.Adadelta(learning_rate=learning_rate)
    elif optimizer == "adamax":
        optimizer = tf.keras.optimizers.Adamax(learning_rate=learning_rate)
    elif optimizer == "ftrl":
        optimizer = tf.keras.optimizers.Ftrl(learning_rate=learning_rate)
    elif optimizer == "nadam": 
        optimizer = tf.keras.optimizers.Nadam(learning_rate=learning_rate)

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten())

    for _ in range(n_hidden):
        # Adding L2 regularization to Dense layers
        model.add(tf.keras.layers.Dense(
            units = hp.Int("n_neurons", min_value=100, max_value=900, step=50, sampling="log"),
            activation=hp.Choice("activation", values=["relu", "tanh", "selu", "linear", "swish", "softplus", "exponential"]),
            kernel_regularizer=regularizers.l2(hp.Float("l2_reg", min_value=1e-5, max_value=1e-1, sampling="log"))  # Regularization added
        ))
        model.add(layers.Dropout(rate=hp.Float("dropout_rate", min_value=0.01, max_value=0.9, step=0.05)))

    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        loss='mse',
        optimizer=optimizer,
        metrics=[tf.keras.metrics.RootMeanSquaredError()]
    )
    return model

########################

# Define parameter grid
out_folder = "amazon"
rnd_search_folder = "rnd_search"
random_search_tuner = kt.RandomSearch(
    build_model, objective="loss", max_trials=25, overwrite=True,
    directory=out_folder, project_name=rnd_search_folder, seed=42
)

random_search_tuner.search(Xtrain_prepared, ytrain_prepared, epochs=5, batch_size=64,
                           validation_data=(Xdev_prepared, ydev_prepared))

random_search_tuner.search_space_summary()

random_search_tuner.results_summary()

# Build the best model and retrain it
top3_models = random_search_tuner.get_best_models(num_models=3)

top3_params = random_search_tuner.get_best_hyperparameters(num_trials=3)

for i in range(len(top3_params)):
    print(top3_params[i].values)
# Out:
# Trial 25 Complete [00h 00m 07s]
# loss: 114704.9453125
#
# Best loss So Far: 76160.625
# Total elapsed time: 00h 04m 02s
# Search space summary
# Default search space size: 7
# n_hidden (Int)
# {'default': 2, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.9, 'step': None, 'sampling': 'log'}
# optimizer (Choice)
# {'default': 'sgd', 'conditions': [], 'values': ['sgd', 'adam', 'adagrad', 'rms', 'adadelta', 'adamax', 'nadam'], 'ordered': False}
# n_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 100, 'max_value': 900, 'step': 50, 'sampling': 'log'}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh', 'selu', 'linear', 'swish', 'softplus', 'exponential'], 'ordered': False}
# l2_reg (Float)
# {'default': 1e-05, 'conditions': [], 'min_value': 1e-05, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# dropout_rate (Float)
# {'default': 0.01, 'conditions': [], 'min_value': 0.01, 'max_value': 0.9, 'step': 0.05, 'sampling': 'linear'}
# Results summary
# Results in amazon/rnd_search
# Showing 10 best trials
# Objective(name="loss", direction="min")
#
# Trial 13 summary
# Hyperparameters:
# n_hidden: 6
# learning_rate: 0.008209618290737282
# optimizer: adadelta
# n_neurons: 100
# activation: relu
# l2_reg: 5.939437813279243e-05
# dropout_rate: 0.01
# Score: 76160.625
#
# Trial 01 summary
# Hyperparameters:
# n_hidden: 2
# learning_rate: 0.009276416723841687
# optimizer: adam
# n_neurons: 100
# activation: swish
# l2_reg: 0.04514107426881946
# dropout_rate: 0.060000000000000005
# Score: 76435.4140625
#
# Trial 07 summary
# Hyperparameters:
# n_hidden: 2
# learning_rate: 0.00462287884982147
# optimizer: nadam
# n_neurons: 100
# activation: softplus
# l2_reg: 0.0003036527652974287
# dropout_rate: 0.16000000000000003
# Score: 77256.5703125
#
# Trial 06 summary
# Hyperparameters:
# n_hidden: 8
# learning_rate: 0.0006154916238814045
# optimizer: adamax
# n_neurons: 100
# activation: selu
# l2_reg: 2.1103896995739087e-05
# dropout_rate: 0.16000000000000003
# Score: 79280.0
#
# Trial 16 summary
# Hyperparameters:
# n_hidden: 3
# learning_rate: 0.019813685892326818
# optimizer: rms
# n_neurons: 100
# activation: swish
# l2_reg: 0.00037851189036649857
# dropout_rate: 0.11
# Score: 79506.671875
#
# Trial 17 summary
# Hyperparameters:
# n_hidden: 6
# learning_rate: 0.00016306445834756255
# optimizer: rms
# n_neurons: 100
# activation: relu
# l2_reg: 5.186297414751111e-05
# dropout_rate: 0.21000000000000002
# Score: 82642.84375
#
# Trial 23 summary
# Hyperparameters:
# n_hidden: 2
# learning_rate: 0.003710773970922463
# optimizer: rms
# n_neurons: 100
# activation: linear
# l2_reg: 0.000130692163429327
# dropout_rate: 0.51
# Score: 83511.8828125
#
# Trial 14 summary
# Hyperparameters:
# n_hidden: 8
# learning_rate: 0.011107396927757099
# optimizer: adadelta
# n_neurons: 100
# activation: linear
# l2_reg: 0.030332128706208862
# dropout_rate: 0.11
# Score: 85354.3203125
#
# Trial 12 summary
# Hyperparameters:
# n_hidden: 7
# learning_rate: 0.00015005950274957962
# optimizer: nadam
# n_neurons: 100
# activation: linear
# l2_reg: 0.00018270092881049886
# dropout_rate: 0.36000000000000004
# Score: 88093.8125
#
# Trial 08 summary
# Hyperparameters:
# n_hidden: 5
# learning_rate: 0.003957557894648519
# optimizer: adam
# n_neurons: 100
# activation: tanh
# l2_reg: 0.08245186438878183
# dropout_rate: 0.8600000000000001
# Score: 102689.1953125
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adadelta', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# {'n_hidden': 6, 'learning_rate': 0.008209618290737282, 'optimizer': 'adadelta', 'n_neurons': 100, 'activation': 'relu', 'l2_reg': 5.939437813279243e-05, 'dropout_rate': 0.01}
# {'n_hidden': 2, 'learning_rate': 0.009276416723841687, 'optimizer': 'adam', 'n_neurons': 100, 'activation': 'swish', 'l2_reg': 0.04514107426881946, 'dropout_rate': 0.060000000000000005}
# {'n_hidden': 2, 'learning_rate': 0.00462287884982147, 'optimizer': 'nadam', 'n_neurons': 100, 'activation': 'softplus', 'l2_reg': 0.0003036527652974287, 'dropout_rate': 0.16000000000000003}
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'nadam', because it has 2 variables whereas the saved optimizer has 15 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
#{'n_hidden': 12, 'n_neurons': 600, 'learning_rate': 0.00015872740971656704, 'optimizer': 'RMSprop', 'activation': 'relu'}

# Best Hyperparameters:
# Number of hidden layers: 1
# Number of neurons: 26
# Learning rate: 0.000017
# Dropout rate: 0.00
# Optimizer: sgd
# Activation: relu

# {'n_hidden': 6, 'learning_rate': 0.008209618290737282, 'optimizer': 'adadelta', 
# 'n_neurons': 100, 'activation': 'relu', 'l2_reg': 5.939437813279243e-05, 'dropout_rate': 0.01}


from tensorflow.keras import regularizers



optimizer1 = tf.keras.optimizers.Adadelta(learning_rate=0.008209618290737282)

model1 = tf.keras.Sequential()

model1.add(tf.keras.layers.Input(shape=(7,)))  

model1.add(tf.keras.layers.Dense(100, activation="relu", kernel_regularizer=regularizers.l2(5.939437813279243e-05)))
model1.add(tf.keras.layers.Dropout(0.01))
model1.add(tf.keras.layers.Dense(100, activation="relu", kernel_regularizer=regularizers.l2(5.939437813279243e-05)))
model1.add(tf.keras.layers.Dropout(0.01))
model1.add(tf.keras.layers.Dense(100, activation="relu", kernel_regularizer=regularizers.l2(5.939437813279243e-05)))
model1.add(tf.keras.layers.Dropout(0.01))
model1.add(tf.keras.layers.Dense(100, activation="relu", kernel_regularizer=regularizers.l2(5.939437813279243e-05)))
model1.add(tf.keras.layers.Dropout(0.01))
model1.add(tf.keras.layers.Dense(100, activation="relu", kernel_regularizer=regularizers.l2(5.939437813279243e-05)))
model1.add(tf.keras.layers.Dropout(0.01))
model1.add(tf.keras.layers.Dense(100, activation="relu", kernel_regularizer=regularizers.l2(5.939437813279243e-05)))
model1.add(tf.keras.layers.Dropout(0.01))


model1.add(tf.keras.layers.Dense(1, activation="linear", kernel_regularizer=regularizers.l2(5.939437813279243e-05)))

model1.compile(loss="mse", optimizer=optimizer1, metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Print the model summary
model1.summary()

# Train the model
history = model1.fit(
    Xtrain_prepared, ytrain_prepared,
    epochs=500,     
    batch_size=64,      
    validation_data=(Xdev_prepared, ydev_prepared)
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 100)            │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,401 (200.79 KB)
#  Trainable params: 51,401 (200.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 279153.2812 - root_mean_squared_error: 516.6036 - val_loss: 79605.7344 - val_root_mean_squared_error: 282.1448
# Epoch 2/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 77066.8281 - root_mean_squared_error: 277.5861 - val_loss: 78007.0391 - val_root_mean_squared_error: 279.2973
# Epoch 3/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75452.9922 - root_mean_squared_error: 274.6790 - val_loss: 77771.9766 - val_root_mean_squared_error: 278.8762
# Epoch 4/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76114.0312 - root_mean_squared_error: 275.8838 - val_loss: 77812.5391 - val_root_mean_squared_error: 278.9489
# Epoch 5/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75920.5938 - root_mean_squared_error: 275.5338 - val_loss: 77762.7734 - val_root_mean_squared_error: 278.8597
# Epoch 6/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76172.8750 - root_mean_squared_error: 275.9897 - val_loss: 77754.2500 - val_root_mean_squared_error: 278.8444
# Epoch 7/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76130.6953 - root_mean_squared_error: 275.8918 - val_loss: 77704.5000 - val_root_mean_squared_error: 278.7552
# Epoch 8/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76371.1875 - root_mean_squared_error: 276.3427 - val_loss: 77704.2344 - val_root_mean_squared_error: 278.7547
# Epoch 9/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76048.8047 - root_mean_squared_error: 275.7654 - val_loss: 77677.0547 - val_root_mean_squared_error: 278.7060
# Epoch 10/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 76018.9688 - root_mean_squared_error: 275.7118 - val_loss: 77710.7422 - val_root_mean_squared_error: 278.7664
# Epoch 11/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 77128.9219 - root_mean_squared_error: 277.6991 - val_loss: 77687.0938 - val_root_mean_squared_error: 278.7239
# Epoch 12/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75926.7734 - root_mean_squared_error: 275.5457 - val_loss: 77693.9453 - val_root_mean_squared_error: 278.7363
# Epoch 13/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75922.1562 - root_mean_squared_error: 275.5360 - val_loss: 77613.7109 - val_root_mean_squared_error: 278.5923
# Epoch 14/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75691.8750 - root_mean_squared_error: 275.1102 - val_loss: 77611.8125 - val_root_mean_squared_error: 278.5889
# Epoch 15/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76074.1719 - root_mean_squared_error: 275.8095 - val_loss: 77613.5547 - val_root_mean_squared_error: 278.5920
# Epoch 16/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74870.9922 - root_mean_squared_error: 273.6182 - val_loss: 77609.4297 - val_root_mean_squared_error: 278.5846
# Epoch 17/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75314.5703 - root_mean_squared_error: 274.4320 - val_loss: 77644.5156 - val_root_mean_squared_error: 278.6476
# Epoch 18/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75022.2812 - root_mean_squared_error: 273.8997 - val_loss: 77590.7734 - val_root_mean_squared_error: 278.5511
# Epoch 19/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76358.2422 - root_mean_squared_error: 276.3174 - val_loss: 77585.5312 - val_root_mean_squared_error: 278.5417
# Epoch 20/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76069.7812 - root_mean_squared_error: 275.8055 - val_loss: 77609.3203 - val_root_mean_squared_error: 278.5844
# Epoch 21/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75919.5234 - root_mean_squared_error: 275.5298 - val_loss: 77587.7266 - val_root_mean_squared_error: 278.5457
# Epoch 22/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75845.6094 - root_mean_squared_error: 275.3936 - val_loss: 77629.8438 - val_root_mean_squared_error: 278.6212
# Epoch 23/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75802.6094 - root_mean_squared_error: 275.3207 - val_loss: 77586.9453 - val_root_mean_squared_error: 278.5443
# Epoch 24/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75748.7188 - root_mean_squared_error: 275.2236 - val_loss: 77572.4453 - val_root_mean_squared_error: 278.5182
# Epoch 25/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76289.5000 - root_mean_squared_error: 276.1996 - val_loss: 77557.2109 - val_root_mean_squared_error: 278.4909
# Epoch 26/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76060.7656 - root_mean_squared_error: 275.7756 - val_loss: 77527.9922 - val_root_mean_squared_error: 278.4384
# Epoch 27/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75325.5781 - root_mean_squared_error: 274.4517 - val_loss: 77528.7109 - val_root_mean_squared_error: 278.4397
# Epoch 28/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76032.3125 - root_mean_squared_error: 275.7355 - val_loss: 77553.2188 - val_root_mean_squared_error: 278.4837
# Epoch 29/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76063.5625 - root_mean_squared_error: 275.7827 - val_loss: 77516.5312 - val_root_mean_squared_error: 278.4178
# Epoch 30/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75708.3359 - root_mean_squared_error: 275.1464 - val_loss: 77526.6875 - val_root_mean_squared_error: 278.4361
# Epoch 31/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75440.2656 - root_mean_squared_error: 274.6396 - val_loss: 77526.5156 - val_root_mean_squared_error: 278.4358
# Epoch 32/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75269.2969 - root_mean_squared_error: 274.3448 - val_loss: 77500.3750 - val_root_mean_squared_error: 278.3888
# Epoch 33/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75364.9844 - root_mean_squared_error: 274.5189 - val_loss: 77532.7422 - val_root_mean_squared_error: 278.4469
# Epoch 34/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75663.3906 - root_mean_squared_error: 275.0602 - val_loss: 77490.7031 - val_root_mean_squared_error: 278.3715
# Epoch 35/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75527.7031 - root_mean_squared_error: 274.8144 - val_loss: 77515.3984 - val_root_mean_squared_error: 278.4158
# Epoch 36/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75568.1094 - root_mean_squared_error: 274.8897 - val_loss: 77574.8047 - val_root_mean_squared_error: 278.5225
# Epoch 37/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75403.4766 - root_mean_squared_error: 274.5879 - val_loss: 77599.6094 - val_root_mean_squared_error: 278.5670
# Epoch 38/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75714.6016 - root_mean_squared_error: 275.1601 - val_loss: 77485.7109 - val_root_mean_squared_error: 278.3625
# Epoch 39/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75750.4922 - root_mean_squared_error: 275.2213 - val_loss: 77492.1406 - val_root_mean_squared_error: 278.3740
# Epoch 40/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75411.6406 - root_mean_squared_error: 274.6051 - val_loss: 77504.9219 - val_root_mean_squared_error: 278.3970
# Epoch 41/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74999.5078 - root_mean_squared_error: 273.8570 - val_loss: 77461.3359 - val_root_mean_squared_error: 278.3187
# Epoch 42/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75651.0938 - root_mean_squared_error: 275.0347 - val_loss: 77517.7734 - val_root_mean_squared_error: 278.4201
# Epoch 43/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75402.7344 - root_mean_squared_error: 274.5910 - val_loss: 77461.1562 - val_root_mean_squared_error: 278.3183
# Epoch 44/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75978.0703 - root_mean_squared_error: 275.6231 - val_loss: 77454.6094 - val_root_mean_squared_error: 278.3066
# Epoch 45/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75245.8281 - root_mean_squared_error: 274.2968 - val_loss: 77460.1797 - val_root_mean_squared_error: 278.3166
# Epoch 46/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75583.5547 - root_mean_squared_error: 274.8846 - val_loss: 77448.7734 - val_root_mean_squared_error: 278.2961
# Epoch 47/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74632.2812 - root_mean_squared_error: 273.1781 - val_loss: 77474.6406 - val_root_mean_squared_error: 278.3426
# Epoch 48/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75199.5859 - root_mean_squared_error: 274.2226 - val_loss: 77423.4922 - val_root_mean_squared_error: 278.2507
# Epoch 49/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76025.4688 - root_mean_squared_error: 275.7238 - val_loss: 77426.7500 - val_root_mean_squared_error: 278.2566
# Epoch 50/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74788.7422 - root_mean_squared_error: 273.4630 - val_loss: 77453.0547 - val_root_mean_squared_error: 278.3039
# Epoch 51/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74955.5156 - root_mean_squared_error: 273.7764 - val_loss: 77423.4141 - val_root_mean_squared_error: 278.2505
# Epoch 52/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75119.1875 - root_mean_squared_error: 274.0504 - val_loss: 77460.3281 - val_root_mean_squared_error: 278.3169
# Epoch 53/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76050.4453 - root_mean_squared_error: 275.7621 - val_loss: 77550.6875 - val_root_mean_squared_error: 278.4792
# Epoch 54/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76039.2656 - root_mean_squared_error: 275.7456 - val_loss: 77451.8672 - val_root_mean_squared_error: 278.3017
# Epoch 55/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75401.0938 - root_mean_squared_error: 274.5858 - val_loss: 77435.5938 - val_root_mean_squared_error: 278.2724
# Epoch 56/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74957.8594 - root_mean_squared_error: 273.7807 - val_loss: 77463.4219 - val_root_mean_squared_error: 278.3224
# Epoch 57/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74833.0938 - root_mean_squared_error: 273.5361 - val_loss: 77511.5078 - val_root_mean_squared_error: 278.4088
# Epoch 58/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75990.9531 - root_mean_squared_error: 275.6576 - val_loss: 77418.6172 - val_root_mean_squared_error: 278.2419
# Epoch 59/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75036.2344 - root_mean_squared_error: 273.9224 - val_loss: 77553.2891 - val_root_mean_squared_error: 278.4838
# Epoch 60/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75661.2734 - root_mean_squared_error: 275.0634 - val_loss: 77416.7891 - val_root_mean_squared_error: 278.2387
# Epoch 61/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76180.1953 - root_mean_squared_error: 275.9961 - val_loss: 77469.6172 - val_root_mean_squared_error: 278.3336
# Epoch 62/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74839.8281 - root_mean_squared_error: 273.5647 - val_loss: 77416.0625 - val_root_mean_squared_error: 278.2373
# Epoch 63/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75215.6719 - root_mean_squared_error: 274.2514 - val_loss: 77437.8984 - val_root_mean_squared_error: 278.2766
# Epoch 64/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75835.7812 - root_mean_squared_error: 275.3780 - val_loss: 77408.0547 - val_root_mean_squared_error: 278.2230
# Epoch 65/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 76086.7812 - root_mean_squared_error: 275.8264 - val_loss: 77393.0703 - val_root_mean_squared_error: 278.1960
# Epoch 66/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75289.8359 - root_mean_squared_error: 274.3889 - val_loss: 77453.3672 - val_root_mean_squared_error: 278.3044
# Epoch 67/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74681.8125 - root_mean_squared_error: 273.2718 - val_loss: 77463.1562 - val_root_mean_squared_error: 278.3220
# Epoch 68/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74925.5234 - root_mean_squared_error: 273.7190 - val_loss: 77400.7734 - val_root_mean_squared_error: 278.2099
# Epoch 69/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75976.1719 - root_mean_squared_error: 275.6299 - val_loss: 77440.6250 - val_root_mean_squared_error: 278.2815
# Epoch 70/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75107.6484 - root_mean_squared_error: 274.0490 - val_loss: 77385.1406 - val_root_mean_squared_error: 278.1818
# Epoch 71/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75212.4297 - root_mean_squared_error: 274.2393 - val_loss: 77433.9375 - val_root_mean_squared_error: 278.2695
# Epoch 72/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75565.2969 - root_mean_squared_error: 274.8424 - val_loss: 77417.6641 - val_root_mean_squared_error: 278.2402
# Epoch 73/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75360.4922 - root_mean_squared_error: 274.5085 - val_loss: 77409.9766 - val_root_mean_squared_error: 278.2264
# Epoch 74/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75250.1875 - root_mean_squared_error: 274.3118 - val_loss: 77413.7734 - val_root_mean_squared_error: 278.2332
# Epoch 75/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74660.0859 - root_mean_squared_error: 273.2314 - val_loss: 77386.3672 - val_root_mean_squared_error: 278.1840
# Epoch 76/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75274.7188 - root_mean_squared_error: 274.3596 - val_loss: 77401.8438 - val_root_mean_squared_error: 278.2118
# Epoch 77/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75593.5078 - root_mean_squared_error: 274.9359 - val_loss: 77366.9688 - val_root_mean_squared_error: 278.1491
# Epoch 78/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75222.5000 - root_mean_squared_error: 274.2620 - val_loss: 77478.7344 - val_root_mean_squared_error: 278.3500
# Epoch 79/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74761.6250 - root_mean_squared_error: 273.4213 - val_loss: 77355.7734 - val_root_mean_squared_error: 278.1290
# Epoch 80/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75659.1953 - root_mean_squared_error: 275.0457 - val_loss: 77357.2109 - val_root_mean_squared_error: 278.1316
# Epoch 81/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75748.5000 - root_mean_squared_error: 275.2176 - val_loss: 77394.8984 - val_root_mean_squared_error: 278.1993
# Epoch 82/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75555.6953 - root_mean_squared_error: 274.8676 - val_loss: 77365.3594 - val_root_mean_squared_error: 278.1462
# Epoch 83/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75003.1016 - root_mean_squared_error: 273.8634 - val_loss: 77359.6484 - val_root_mean_squared_error: 278.1360
# Epoch 84/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75254.1875 - root_mean_squared_error: 274.3177 - val_loss: 77488.4766 - val_root_mean_squared_error: 278.3675
# Epoch 85/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76363.5938 - root_mean_squared_error: 276.2977 - val_loss: 77392.8359 - val_root_mean_squared_error: 278.1956
# Epoch 86/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74836.4766 - root_mean_squared_error: 273.5555 - val_loss: 77387.6875 - val_root_mean_squared_error: 278.1864
# Epoch 87/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75618.1016 - root_mean_squared_error: 274.9825 - val_loss: 77518.4688 - val_root_mean_squared_error: 278.4213
# Epoch 88/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75685.8359 - root_mean_squared_error: 275.1024 - val_loss: 77480.8125 - val_root_mean_squared_error: 278.3537
# Epoch 89/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75471.9844 - root_mean_squared_error: 274.7163 - val_loss: 77436.6641 - val_root_mean_squared_error: 278.2744
# Epoch 90/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74528.6797 - root_mean_squared_error: 272.9943 - val_loss: 77424.1172 - val_root_mean_squared_error: 278.2518
# Epoch 91/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75472.5078 - root_mean_squared_error: 274.7172 - val_loss: 77337.0078 - val_root_mean_squared_error: 278.0952
# Epoch 92/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74920.2422 - root_mean_squared_error: 273.7082 - val_loss: 77376.1484 - val_root_mean_squared_error: 278.1656
# Epoch 93/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75022.5234 - root_mean_squared_error: 273.9012 - val_loss: 77364.7734 - val_root_mean_squared_error: 278.1452
# Epoch 94/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75150.3984 - root_mean_squared_error: 274.1328 - val_loss: 77363.7109 - val_root_mean_squared_error: 278.1432
# Epoch 95/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74965.0625 - root_mean_squared_error: 273.7921 - val_loss: 77388.5625 - val_root_mean_squared_error: 278.1879
# Epoch 96/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75428.8047 - root_mean_squared_error: 274.6323 - val_loss: 77400.5156 - val_root_mean_squared_error: 278.2094
# Epoch 97/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75257.3281 - root_mean_squared_error: 274.3189 - val_loss: 77339.5156 - val_root_mean_squared_error: 278.0998
# Epoch 98/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75121.2891 - root_mean_squared_error: 274.0797 - val_loss: 77350.0781 - val_root_mean_squared_error: 278.1187
# Epoch 99/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75259.4219 - root_mean_squared_error: 274.3201 - val_loss: 77348.4531 - val_root_mean_squared_error: 278.1158
# Epoch 100/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74870.3984 - root_mean_squared_error: 273.6186 - val_loss: 77361.3516 - val_root_mean_squared_error: 278.1390
# Epoch 101/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74668.6562 - root_mean_squared_error: 273.2530 - val_loss: 77339.9844 - val_root_mean_squared_error: 278.1006
# Epoch 102/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75535.0469 - root_mean_squared_error: 274.8206 - val_loss: 77401.2109 - val_root_mean_squared_error: 278.2106
# Epoch 103/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75305.4766 - root_mean_squared_error: 274.4138 - val_loss: 77385.1016 - val_root_mean_squared_error: 278.1817
# Epoch 104/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75273.5703 - root_mean_squared_error: 274.3551 - val_loss: 77369.4062 - val_root_mean_squared_error: 278.1535
# Epoch 105/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74120.7578 - root_mean_squared_error: 272.2437 - val_loss: 77383.6250 - val_root_mean_squared_error: 278.1791
# Epoch 106/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75300.8438 - root_mean_squared_error: 274.3914 - val_loss: 77401.1953 - val_root_mean_squared_error: 278.2106
# Epoch 107/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76005.3438 - root_mean_squared_error: 275.6828 - val_loss: 77369.4922 - val_root_mean_squared_error: 278.1537
# Epoch 108/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74394.5625 - root_mean_squared_error: 272.7462 - val_loss: 77396.5781 - val_root_mean_squared_error: 278.2023
# Epoch 109/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74737.1562 - root_mean_squared_error: 273.3677 - val_loss: 77398.3359 - val_root_mean_squared_error: 278.2055
# Epoch 110/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74890.4688 - root_mean_squared_error: 273.6536 - val_loss: 77334.7500 - val_root_mean_squared_error: 278.0912
# Epoch 111/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75592.3516 - root_mean_squared_error: 274.9380 - val_loss: 77358.2578 - val_root_mean_squared_error: 278.1335
# Epoch 112/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75150.8828 - root_mean_squared_error: 274.1355 - val_loss: 77365.0547 - val_root_mean_squared_error: 278.1457
# Epoch 113/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76026.2266 - root_mean_squared_error: 275.7184 - val_loss: 77416.8359 - val_root_mean_squared_error: 278.2387
# Epoch 114/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75599.6016 - root_mean_squared_error: 274.9507 - val_loss: 77366.7969 - val_root_mean_squared_error: 278.1488
# Epoch 115/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74752.7188 - root_mean_squared_error: 273.4063 - val_loss: 77438.1719 - val_root_mean_squared_error: 278.2771
# Epoch 116/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75008.0859 - root_mean_squared_error: 273.8677 - val_loss: 77383.1641 - val_root_mean_squared_error: 278.1782
# Epoch 117/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74506.2344 - root_mean_squared_error: 272.9493 - val_loss: 77418.1484 - val_root_mean_squared_error: 278.2411
# Epoch 118/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74098.9609 - root_mean_squared_error: 272.1959 - val_loss: 77329.6641 - val_root_mean_squared_error: 278.0821
# Epoch 119/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74441.1719 - root_mean_squared_error: 272.8275 - val_loss: 77344.9375 - val_root_mean_squared_error: 278.1095
# Epoch 120/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75124.2812 - root_mean_squared_error: 274.0827 - val_loss: 77316.4922 - val_root_mean_squared_error: 278.0584
# Epoch 121/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75317.9609 - root_mean_squared_error: 274.4391 - val_loss: 77321.4844 - val_root_mean_squared_error: 278.0674
# Epoch 122/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73779.8516 - root_mean_squared_error: 271.6159 - val_loss: 77351.2578 - val_root_mean_squared_error: 278.1209
# Epoch 123/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74679.0234 - root_mean_squared_error: 273.2666 - val_loss: 77311.3047 - val_root_mean_squared_error: 278.0490
# Epoch 124/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74630.4531 - root_mean_squared_error: 273.1717 - val_loss: 77320.6406 - val_root_mean_squared_error: 278.0658
# Epoch 125/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74123.7891 - root_mean_squared_error: 272.2473 - val_loss: 77345.9453 - val_root_mean_squared_error: 278.1113
# Epoch 126/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75623.8984 - root_mean_squared_error: 274.9916 - val_loss: 77504.9688 - val_root_mean_squared_error: 278.3970
# Epoch 127/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74789.5234 - root_mean_squared_error: 273.4730 - val_loss: 77326.4062 - val_root_mean_squared_error: 278.0762
# Epoch 128/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74303.5938 - root_mean_squared_error: 272.5786 - val_loss: 77380.5312 - val_root_mean_squared_error: 278.1735
# Epoch 129/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74397.7422 - root_mean_squared_error: 272.7443 - val_loss: 77389.7578 - val_root_mean_squared_error: 278.1901
# Epoch 130/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74676.4453 - root_mean_squared_error: 273.2657 - val_loss: 77371.8906 - val_root_mean_squared_error: 278.1580
# Epoch 131/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75909.6016 - root_mean_squared_error: 275.5009 - val_loss: 77325.4531 - val_root_mean_squared_error: 278.0745
# Epoch 132/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75361.3281 - root_mean_squared_error: 274.5100 - val_loss: 77319.7891 - val_root_mean_squared_error: 278.0643
# Epoch 133/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74956.5547 - root_mean_squared_error: 273.7761 - val_loss: 77338.4766 - val_root_mean_squared_error: 278.0979
# Epoch 134/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74464.7891 - root_mean_squared_error: 272.8661 - val_loss: 77351.8047 - val_root_mean_squared_error: 278.1219
# Epoch 135/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74765.8672 - root_mean_squared_error: 273.4308 - val_loss: 77317.2969 - val_root_mean_squared_error: 278.0598
# Epoch 136/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74726.6562 - root_mean_squared_error: 273.3503 - val_loss: 77305.3438 - val_root_mean_squared_error: 278.0383
# Epoch 137/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75241.7031 - root_mean_squared_error: 274.2957 - val_loss: 77370.4219 - val_root_mean_squared_error: 278.1553
# Epoch 138/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74952.3203 - root_mean_squared_error: 273.7706 - val_loss: 77337.2969 - val_root_mean_squared_error: 278.0957
# Epoch 139/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75213.3906 - root_mean_squared_error: 274.2465 - val_loss: 77381.3125 - val_root_mean_squared_error: 278.1748
# Epoch 140/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75418.2109 - root_mean_squared_error: 274.6170 - val_loss: 77291.6562 - val_root_mean_squared_error: 278.0137
# Epoch 141/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74669.1562 - root_mean_squared_error: 273.2544 - val_loss: 77332.5859 - val_root_mean_squared_error: 278.0873
# Epoch 142/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74508.3516 - root_mean_squared_error: 272.9570 - val_loss: 77331.9375 - val_root_mean_squared_error: 278.0861
# Epoch 143/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74665.6328 - root_mean_squared_error: 273.2446 - val_loss: 77329.3906 - val_root_mean_squared_error: 278.0816
# Epoch 144/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74428.9141 - root_mean_squared_error: 272.8115 - val_loss: 77300.4766 - val_root_mean_squared_error: 278.0296
# Epoch 145/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75248.2578 - root_mean_squared_error: 274.3065 - val_loss: 77285.1328 - val_root_mean_squared_error: 278.0020
# Epoch 146/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75217.5234 - root_mean_squared_error: 274.2545 - val_loss: 77408.0469 - val_root_mean_squared_error: 278.2230
# Epoch 147/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74478.9609 - root_mean_squared_error: 272.9048 - val_loss: 77309.1797 - val_root_mean_squared_error: 278.0452
# Epoch 148/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74401.5703 - root_mean_squared_error: 272.7338 - val_loss: 77350.0625 - val_root_mean_squared_error: 278.1187
# Epoch 149/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75615.4375 - root_mean_squared_error: 274.9711 - val_loss: 77379.0547 - val_root_mean_squared_error: 278.1709
# Epoch 150/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75145.8438 - root_mean_squared_error: 274.1184 - val_loss: 77334.1797 - val_root_mean_squared_error: 278.0902
# Epoch 151/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74974.5547 - root_mean_squared_error: 273.8093 - val_loss: 77323.4141 - val_root_mean_squared_error: 278.0708
# Epoch 152/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74944.8281 - root_mean_squared_error: 273.7470 - val_loss: 77348.6406 - val_root_mean_squared_error: 278.1162
# Epoch 153/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73862.7812 - root_mean_squared_error: 271.7663 - val_loss: 77368.5547 - val_root_mean_squared_error: 278.1519
# Epoch 154/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75205.3516 - root_mean_squared_error: 274.2337 - val_loss: 77330.3672 - val_root_mean_squared_error: 278.0833
# Epoch 155/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74976.2969 - root_mean_squared_error: 273.8145 - val_loss: 77435.3047 - val_root_mean_squared_error: 278.2719
# Epoch 156/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74312.1719 - root_mean_squared_error: 272.5989 - val_loss: 77351.6172 - val_root_mean_squared_error: 278.1215
# Epoch 157/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75480.5234 - root_mean_squared_error: 274.7106 - val_loss: 77310.1641 - val_root_mean_squared_error: 278.0470
# Epoch 158/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75082.8203 - root_mean_squared_error: 274.0046 - val_loss: 77321.3047 - val_root_mean_squared_error: 278.0670
# Epoch 159/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75149.0547 - root_mean_squared_error: 274.1266 - val_loss: 77296.8516 - val_root_mean_squared_error: 278.0231
# Epoch 160/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74657.0625 - root_mean_squared_error: 273.2183 - val_loss: 77284.1016 - val_root_mean_squared_error: 278.0001
# Epoch 161/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75257.3359 - root_mean_squared_error: 274.3273 - val_loss: 77321.5078 - val_root_mean_squared_error: 278.0674
# Epoch 162/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75538.6484 - root_mean_squared_error: 274.8316 - val_loss: 77381.8672 - val_root_mean_squared_error: 278.1759
# Epoch 163/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75407.7109 - root_mean_squared_error: 274.6026 - val_loss: 77443.0234 - val_root_mean_squared_error: 278.2858
# Epoch 164/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75409.4453 - root_mean_squared_error: 274.5945 - val_loss: 77321.5156 - val_root_mean_squared_error: 278.0674
# Epoch 165/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75070.3281 - root_mean_squared_error: 273.9846 - val_loss: 77402.7109 - val_root_mean_squared_error: 278.2134
# Epoch 166/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73287.9844 - root_mean_squared_error: 270.6983 - val_loss: 77278.5859 - val_root_mean_squared_error: 277.9902
# Epoch 167/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75710.2812 - root_mean_squared_error: 275.1371 - val_loss: 77367.3438 - val_root_mean_squared_error: 278.1498
# Epoch 168/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74279.0547 - root_mean_squared_error: 272.5372 - val_loss: 77311.5000 - val_root_mean_squared_error: 278.0494
# Epoch 169/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74991.9062 - root_mean_squared_error: 273.8420 - val_loss: 77303.3438 - val_root_mean_squared_error: 278.0348
# Epoch 170/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75096.2656 - root_mean_squared_error: 274.0316 - val_loss: 77380.0938 - val_root_mean_squared_error: 278.1727
# Epoch 171/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75591.4766 - root_mean_squared_error: 274.9362 - val_loss: 77303.7969 - val_root_mean_squared_error: 278.0356
# Epoch 172/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75148.2656 - root_mean_squared_error: 274.1275 - val_loss: 77391.1406 - val_root_mean_squared_error: 278.1926
# Epoch 173/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75372.6953 - root_mean_squared_error: 274.5386 - val_loss: 77380.9688 - val_root_mean_squared_error: 278.1742
# Epoch 174/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74155.1328 - root_mean_squared_error: 272.3090 - val_loss: 77368.1406 - val_root_mean_squared_error: 278.1512
# Epoch 175/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75757.2812 - root_mean_squared_error: 275.2354 - val_loss: 77380.4766 - val_root_mean_squared_error: 278.1734
# Epoch 176/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74851.1250 - root_mean_squared_error: 273.5853 - val_loss: 77309.8359 - val_root_mean_squared_error: 278.0464
# Epoch 177/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74949.4375 - root_mean_squared_error: 273.7588 - val_loss: 77352.6094 - val_root_mean_squared_error: 278.1233
# Epoch 178/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74902.4922 - root_mean_squared_error: 273.6803 - val_loss: 77417.1875 - val_root_mean_squared_error: 278.2393
# Epoch 179/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74078.9453 - root_mean_squared_error: 272.1624 - val_loss: 77291.0078 - val_root_mean_squared_error: 278.0126
# Epoch 180/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75278.9844 - root_mean_squared_error: 274.3610 - val_loss: 77308.8906 - val_root_mean_squared_error: 278.0447
# Epoch 181/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74998.5391 - root_mean_squared_error: 273.8548 - val_loss: 77388.7188 - val_root_mean_squared_error: 278.1882
# Epoch 182/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75322.3984 - root_mean_squared_error: 274.4432 - val_loss: 77299.8438 - val_root_mean_squared_error: 278.0284
# Epoch 183/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75124.6016 - root_mean_squared_error: 274.0773 - val_loss: 77264.3359 - val_root_mean_squared_error: 277.9646
# Epoch 184/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74908.1094 - root_mean_squared_error: 273.6908 - val_loss: 77341.0234 - val_root_mean_squared_error: 278.1024
# Epoch 185/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74747.0000 - root_mean_squared_error: 273.3931 - val_loss: 77362.1016 - val_root_mean_squared_error: 278.1404
# Epoch 186/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74207.3828 - root_mean_squared_error: 272.4051 - val_loss: 77270.5000 - val_root_mean_squared_error: 277.9756
# Epoch 187/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75260.3984 - root_mean_squared_error: 274.3315 - val_loss: 77390.0391 - val_root_mean_squared_error: 278.1906
# Epoch 188/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74793.8828 - root_mean_squared_error: 273.4766 - val_loss: 77278.7891 - val_root_mean_squared_error: 277.9906
# Epoch 189/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75267.6562 - root_mean_squared_error: 274.3444 - val_loss: 77313.5000 - val_root_mean_squared_error: 278.0530
# Epoch 190/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75159.8594 - root_mean_squared_error: 274.1420 - val_loss: 77326.2656 - val_root_mean_squared_error: 278.0759
# Epoch 191/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74517.7891 - root_mean_squared_error: 272.9751 - val_loss: 77274.8203 - val_root_mean_squared_error: 277.9834
# Epoch 192/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74845.0859 - root_mean_squared_error: 273.5754 - val_loss: 77441.3672 - val_root_mean_squared_error: 278.2828
# Epoch 193/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75178.0625 - root_mean_squared_error: 274.1757 - val_loss: 77369.8984 - val_root_mean_squared_error: 278.1544
# Epoch 194/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75280.3828 - root_mean_squared_error: 274.3699 - val_loss: 77309.1719 - val_root_mean_squared_error: 278.0452
# Epoch 195/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75302.6094 - root_mean_squared_error: 274.4052 - val_loss: 77331.8750 - val_root_mean_squared_error: 278.0860
# Epoch 196/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75051.0703 - root_mean_squared_error: 273.9492 - val_loss: 77334.6953 - val_root_mean_squared_error: 278.0911
# Epoch 197/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73847.4141 - root_mean_squared_error: 271.7409 - val_loss: 77315.3438 - val_root_mean_squared_error: 278.0562
# Epoch 198/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74585.5859 - root_mean_squared_error: 273.1014 - val_loss: 77372.8594 - val_root_mean_squared_error: 278.1597
# Epoch 199/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74718.3594 - root_mean_squared_error: 273.3383 - val_loss: 77305.9219 - val_root_mean_squared_error: 278.0393
# Epoch 200/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74736.3984 - root_mean_squared_error: 273.3767 - val_loss: 77281.8594 - val_root_mean_squared_error: 277.9961
# Epoch 201/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74575.8281 - root_mean_squared_error: 273.0810 - val_loss: 77307.5781 - val_root_mean_squared_error: 278.0423
# Epoch 202/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74519.0547 - root_mean_squared_error: 272.9681 - val_loss: 77264.7031 - val_root_mean_squared_error: 277.9652
# Epoch 203/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75466.5547 - root_mean_squared_error: 274.7082 - val_loss: 77265.2734 - val_root_mean_squared_error: 277.9662
# Epoch 204/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74334.9688 - root_mean_squared_error: 272.6303 - val_loss: 77420.9219 - val_root_mean_squared_error: 278.2461
# Epoch 205/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74904.8438 - root_mean_squared_error: 273.6846 - val_loss: 77261.0156 - val_root_mean_squared_error: 277.9586
# Epoch 206/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75035.7344 - root_mean_squared_error: 273.9225 - val_loss: 77292.2031 - val_root_mean_squared_error: 278.0146
# Epoch 207/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74930.2656 - root_mean_squared_error: 273.7280 - val_loss: 77258.0156 - val_root_mean_squared_error: 277.9532
# Epoch 208/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75002.7109 - root_mean_squared_error: 273.8613 - val_loss: 77373.4375 - val_root_mean_squared_error: 278.1608
# Epoch 209/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74613.8516 - root_mean_squared_error: 273.1519 - val_loss: 77354.3672 - val_root_mean_squared_error: 278.1264
# Epoch 210/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74803.7422 - root_mean_squared_error: 273.4948 - val_loss: 77266.3125 - val_root_mean_squared_error: 277.9681
# Epoch 211/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75217.3984 - root_mean_squared_error: 274.2480 - val_loss: 77432.5078 - val_root_mean_squared_error: 278.2669
# Epoch 212/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75299.1094 - root_mean_squared_error: 274.4021 - val_loss: 77403.8281 - val_root_mean_squared_error: 278.2154
# Epoch 213/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74293.4688 - root_mean_squared_error: 272.5649 - val_loss: 77301.9609 - val_root_mean_squared_error: 278.0323
# Epoch 214/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74864.9766 - root_mean_squared_error: 273.6065 - val_loss: 77276.5703 - val_root_mean_squared_error: 277.9866
# Epoch 215/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74550.3594 - root_mean_squared_error: 273.0367 - val_loss: 77295.6797 - val_root_mean_squared_error: 278.0209
# Epoch 216/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74760.2344 - root_mean_squared_error: 273.4156 - val_loss: 77250.7812 - val_root_mean_squared_error: 277.9402
# Epoch 217/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74564.6797 - root_mean_squared_error: 273.0614 - val_loss: 77383.1484 - val_root_mean_squared_error: 278.1782
# Epoch 218/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75212.7969 - root_mean_squared_error: 274.2441 - val_loss: 77239.7734 - val_root_mean_squared_error: 277.9204
# Epoch 219/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75060.3672 - root_mean_squared_error: 273.9621 - val_loss: 77394.3281 - val_root_mean_squared_error: 278.1983
# Epoch 220/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75402.5547 - root_mean_squared_error: 274.5906 - val_loss: 77344.4375 - val_root_mean_squared_error: 278.1086
# Epoch 221/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74960.0391 - root_mean_squared_error: 273.7853 - val_loss: 77286.6328 - val_root_mean_squared_error: 278.0046
# Epoch 222/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75363.1328 - root_mean_squared_error: 274.5061 - val_loss: 77353.8047 - val_root_mean_squared_error: 278.1254
# Epoch 223/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74637.3984 - root_mean_squared_error: 273.1911 - val_loss: 77311.5859 - val_root_mean_squared_error: 278.0496
# Epoch 224/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73834.0234 - root_mean_squared_error: 271.7174 - val_loss: 77295.2734 - val_root_mean_squared_error: 278.0202
# Epoch 225/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74621.6016 - root_mean_squared_error: 273.1669 - val_loss: 77286.4688 - val_root_mean_squared_error: 278.0043
# Epoch 226/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74202.8516 - root_mean_squared_error: 272.3960 - val_loss: 77305.1875 - val_root_mean_squared_error: 278.0380
# Epoch 227/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74017.8906 - root_mean_squared_error: 272.0558 - val_loss: 77270.3906 - val_root_mean_squared_error: 277.9755
# Epoch 228/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74533.9688 - root_mean_squared_error: 273.0015 - val_loss: 77375.0000 - val_root_mean_squared_error: 278.1636
# Epoch 229/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74934.8516 - root_mean_squared_error: 273.7390 - val_loss: 77312.3359 - val_root_mean_squared_error: 278.0509
# Epoch 230/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74348.3047 - root_mean_squared_error: 272.6664 - val_loss: 77319.2578 - val_root_mean_squared_error: 278.0634
# Epoch 231/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74387.3984 - root_mean_squared_error: 272.7351 - val_loss: 77313.9453 - val_root_mean_squared_error: 278.0537
# Epoch 232/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74575.6953 - root_mean_squared_error: 273.0813 - val_loss: 77238.0391 - val_root_mean_squared_error: 277.9172
# Epoch 233/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74904.5703 - root_mean_squared_error: 273.6822 - val_loss: 77347.4922 - val_root_mean_squared_error: 278.1141
# Epoch 234/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75201.0547 - root_mean_squared_error: 274.2246 - val_loss: 77366.5469 - val_root_mean_squared_error: 278.1484
# Epoch 235/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74239.7422 - root_mean_squared_error: 272.4655 - val_loss: 77237.2500 - val_root_mean_squared_error: 277.9158
# Epoch 236/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74979.7656 - root_mean_squared_error: 273.7941 - val_loss: 77261.1797 - val_root_mean_squared_error: 277.9589
# Epoch 237/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74527.1719 - root_mean_squared_error: 272.9868 - val_loss: 77308.8906 - val_root_mean_squared_error: 278.0446
# Epoch 238/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75028.3906 - root_mean_squared_error: 273.9088 - val_loss: 77316.8672 - val_root_mean_squared_error: 278.0591
# Epoch 239/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74686.4453 - root_mean_squared_error: 273.2836 - val_loss: 77394.4609 - val_root_mean_squared_error: 278.1985
# Epoch 240/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75310.6328 - root_mean_squared_error: 274.4214 - val_loss: 77328.7031 - val_root_mean_squared_error: 278.0803
# Epoch 241/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74491.0156 - root_mean_squared_error: 272.9240 - val_loss: 77309.7812 - val_root_mean_squared_error: 278.0463
# Epoch 242/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75016.7578 - root_mean_squared_error: 273.8899 - val_loss: 77445.6328 - val_root_mean_squared_error: 278.2905
# Epoch 243/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73881.7422 - root_mean_squared_error: 271.7995 - val_loss: 77398.9141 - val_root_mean_squared_error: 278.2065
# Epoch 244/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74310.3516 - root_mean_squared_error: 272.5933 - val_loss: 77328.1484 - val_root_mean_squared_error: 278.0793
# Epoch 245/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74172.6172 - root_mean_squared_error: 272.3380 - val_loss: 77232.7500 - val_root_mean_squared_error: 277.9077
# Epoch 246/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75295.4219 - root_mean_squared_error: 274.3806 - val_loss: 77230.5234 - val_root_mean_squared_error: 277.9037
# Epoch 247/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73558.4375 - root_mean_squared_error: 271.2104 - val_loss: 77404.8984 - val_root_mean_squared_error: 278.2173
# Epoch 248/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74209.3438 - root_mean_squared_error: 272.3937 - val_loss: 77325.0000 - val_root_mean_squared_error: 278.0737
# Epoch 249/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74518.0469 - root_mean_squared_error: 272.9750 - val_loss: 77304.5703 - val_root_mean_squared_error: 278.0369
# Epoch 250/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74654.3594 - root_mean_squared_error: 273.2267 - val_loss: 77298.6328 - val_root_mean_squared_error: 278.0262
# Epoch 251/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73993.3516 - root_mean_squared_error: 272.0089 - val_loss: 77280.5156 - val_root_mean_squared_error: 277.9937
# Epoch 252/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74688.4531 - root_mean_squared_error: 273.2865 - val_loss: 77316.6562 - val_root_mean_squared_error: 278.0587
# Epoch 253/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74323.2266 - root_mean_squared_error: 272.6210 - val_loss: 77325.4062 - val_root_mean_squared_error: 278.0744
# Epoch 254/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74798.8672 - root_mean_squared_error: 273.4903 - val_loss: 77225.7734 - val_root_mean_squared_error: 277.8952
# Epoch 255/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75060.8125 - root_mean_squared_error: 273.9629 - val_loss: 77322.1094 - val_root_mean_squared_error: 278.0685
# Epoch 256/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75303.3984 - root_mean_squared_error: 274.4082 - val_loss: 77302.9141 - val_root_mean_squared_error: 278.0339
# Epoch 257/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75824.4766 - root_mean_squared_error: 275.3532 - val_loss: 77408.2812 - val_root_mean_squared_error: 278.2234
# Epoch 258/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73940.7969 - root_mean_squared_error: 271.9139 - val_loss: 77342.2656 - val_root_mean_squared_error: 278.1047
# Epoch 259/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74456.5469 - root_mean_squared_error: 272.8656 - val_loss: 77324.0938 - val_root_mean_squared_error: 278.0721
# Epoch 260/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74281.3828 - root_mean_squared_error: 272.5415 - val_loss: 77380.6406 - val_root_mean_squared_error: 278.1737
# Epoch 261/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 75030.6797 - root_mean_squared_error: 273.8962 - val_loss: 77225.1406 - val_root_mean_squared_error: 277.8940
# Epoch 262/500
# ...
# Epoch 410/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74435.6875 - root_mean_squared_error: 272.8196 - val_loss: 77364.5391 - val_root_mean_squared_error: 278.1447
# Epoch 411/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73871.5859 - root_mean_squared_error: 271.7820 - val_loss: 77366.1562 - val_root_mean_squared_error: 278.1476
# Epoch 412/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74256.1484 - root_mean_squared_error: 272.4948 - val_loss: 77254.3828 - val_root_mean_squared_error: 277.9467
# Epoch 413/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74156.5000 - root_mean_squared_error: 272.3118 - val_loss: 77216.7734 - val_root_mean_squared_error: 277.8790
# Epoch 414/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74235.3203 - root_mean_squared_error: 272.4555 - val_loss: 77374.0859 - val_root_mean_squared_error: 278.1619
# Epoch 415/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74009.3906 - root_mean_squared_error: 272.0409 - val_loss: 77399.0391 - val_root_mean_squared_error: 278.2067
# Epoch 416/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74482.7891 - root_mean_squared_error: 272.9030 - val_loss: 77255.9922 - val_root_mean_squared_error: 277.9496
# Epoch 417/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74337.3594 - root_mean_squared_error: 272.6419 - val_loss: 77317.1016 - val_root_mean_squared_error: 278.0594
# Epoch 418/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74188.7891 - root_mean_squared_error: 272.3717 - val_loss: 77456.2266 - val_root_mean_squared_error: 278.3095
# Epoch 419/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74436.3359 - root_mean_squared_error: 272.8238 - val_loss: 77456.5859 - val_root_mean_squared_error: 278.3102
# Epoch 420/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73869.5547 - root_mean_squared_error: 271.7803 - val_loss: 77385.0469 - val_root_mean_squared_error: 278.1816
# Epoch 421/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74864.8203 - root_mean_squared_error: 273.6114 - val_loss: 77328.4062 - val_root_mean_squared_error: 278.0798
# Epoch 422/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73954.0391 - root_mean_squared_error: 271.9392 - val_loss: 77228.1406 - val_root_mean_squared_error: 277.8994
# Epoch 423/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74335.7031 - root_mean_squared_error: 272.6409 - val_loss: 77336.4766 - val_root_mean_squared_error: 278.0943
# Epoch 424/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73636.1250 - root_mean_squared_error: 271.3552 - val_loss: 77217.2578 - val_root_mean_squared_error: 277.8798
# Epoch 425/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74159.5469 - root_mean_squared_error: 272.3210 - val_loss: 77200.4922 - val_root_mean_squared_error: 277.8497
# Epoch 426/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73864.4062 - root_mean_squared_error: 271.7737 - val_loss: 77347.2344 - val_root_mean_squared_error: 278.1136
# Epoch 427/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74700.6094 - root_mean_squared_error: 273.3071 - val_loss: 77332.1953 - val_root_mean_squared_error: 278.0866
# Epoch 428/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73891.3750 - root_mean_squared_error: 271.8201 - val_loss: 77275.8125 - val_root_mean_squared_error: 277.9852
# Epoch 429/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73464.7578 - root_mean_squared_error: 271.0270 - val_loss: 77405.8438 - val_root_mean_squared_error: 278.2190
# Epoch 430/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73624.7109 - root_mean_squared_error: 271.3204 - val_loss: 77228.2891 - val_root_mean_squared_error: 277.8997
# Epoch 431/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74434.8281 - root_mean_squared_error: 272.8249 - val_loss: 77372.4766 - val_root_mean_squared_error: 278.1590
# Epoch 432/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73920.5000 - root_mean_squared_error: 271.8751 - val_loss: 77205.8047 - val_root_mean_squared_error: 277.8593
# Epoch 433/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74012.3047 - root_mean_squared_error: 272.0423 - val_loss: 77221.3984 - val_root_mean_squared_error: 277.8873
# Epoch 434/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73599.8594 - root_mean_squared_error: 271.2889 - val_loss: 77307.2578 - val_root_mean_squared_error: 278.0417
# Epoch 435/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74534.0547 - root_mean_squared_error: 273.0045 - val_loss: 77180.4062 - val_root_mean_squared_error: 277.8135
# Epoch 436/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74023.5156 - root_mean_squared_error: 272.0652 - val_loss: 77315.0547 - val_root_mean_squared_error: 278.0558
# Epoch 437/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73815.9297 - root_mean_squared_error: 271.6866 - val_loss: 77295.3359 - val_root_mean_squared_error: 278.0204
# Epoch 438/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74357.3516 - root_mean_squared_error: 272.6838 - val_loss: 77335.5000 - val_root_mean_squared_error: 278.0925
# Epoch 439/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73182.9922 - root_mean_squared_error: 270.5057 - val_loss: 77360.4062 - val_root_mean_squared_error: 278.1373
# Epoch 440/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74083.8438 - root_mean_squared_error: 272.1687 - val_loss: 77305.6172 - val_root_mean_squared_error: 278.0388
# Epoch 441/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74438.4453 - root_mean_squared_error: 272.8207 - val_loss: 77223.5781 - val_root_mean_squared_error: 277.8912
# Epoch 442/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74466.5938 - root_mean_squared_error: 272.8730 - val_loss: 77182.5859 - val_root_mean_squared_error: 277.8175
# Epoch 443/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73549.1016 - root_mean_squared_error: 271.1921 - val_loss: 77213.8984 - val_root_mean_squared_error: 277.8738
# Epoch 444/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74894.2891 - root_mean_squared_error: 273.6614 - val_loss: 77345.6094 - val_root_mean_squared_error: 278.1107
# Epoch 445/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74037.6953 - root_mean_squared_error: 272.0935 - val_loss: 77309.6328 - val_root_mean_squared_error: 278.0460
# Epoch 446/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74923.2500 - root_mean_squared_error: 273.7177 - val_loss: 77383.7969 - val_root_mean_squared_error: 278.1793
# Epoch 447/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74492.1016 - root_mean_squared_error: 272.9291 - val_loss: 77264.6953 - val_root_mean_squared_error: 277.9651
# Epoch 448/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74190.8672 - root_mean_squared_error: 272.3751 - val_loss: 77260.6562 - val_root_mean_squared_error: 277.9579
# Epoch 449/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73890.9922 - root_mean_squared_error: 271.8237 - val_loss: 77277.5391 - val_root_mean_squared_error: 277.9883
# Epoch 450/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73179.0859 - root_mean_squared_error: 270.4969 - val_loss: 77228.3047 - val_root_mean_squared_error: 277.8997
# Epoch 451/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74777.2578 - root_mean_squared_error: 273.4334 - val_loss: 77262.1875 - val_root_mean_squared_error: 277.9607
# Epoch 452/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74236.4688 - root_mean_squared_error: 272.4573 - val_loss: 77478.3281 - val_root_mean_squared_error: 278.3492
# Epoch 453/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74698.1562 - root_mean_squared_error: 273.3035 - val_loss: 77266.3203 - val_root_mean_squared_error: 277.9681
# Epoch 454/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74660.2812 - root_mean_squared_error: 273.2277 - val_loss: 77358.2266 - val_root_mean_squared_error: 278.1334
# Epoch 455/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73345.5781 - root_mean_squared_error: 270.8163 - val_loss: 77218.0859 - val_root_mean_squared_error: 277.8813
# Epoch 456/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74818.7031 - root_mean_squared_error: 273.5273 - val_loss: 77374.4375 - val_root_mean_squared_error: 278.1625
# Epoch 457/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73120.6484 - root_mean_squared_error: 270.4012 - val_loss: 77271.5000 - val_root_mean_squared_error: 277.9774
# Epoch 458/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 74193.6797 - root_mean_squared_error: 272.3786 - val_loss: 77389.9141 - val_root_mean_squared_error: 278.1903
# Epoch 459/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73539.5859 - root_mean_squared_error: 271.1750 - val_loss: 77222.7656 - val_root_mean_squared_error: 277.8898
# Epoch 460/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73617.5547 - root_mean_squared_error: 271.3175 - val_loss: 77427.4922 - val_root_mean_squared_error: 278.2578
# Epoch 461/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73730.1328 - root_mean_squared_error: 271.5240 - val_loss: 77237.8672 - val_root_mean_squared_error: 277.9169
# Epoch 462/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74756.5312 - root_mean_squared_error: 273.4109 - val_loss: 77307.7891 - val_root_mean_squared_error: 278.0427
# Epoch 463/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74008.2656 - root_mean_squared_error: 272.0417 - val_loss: 77239.2500 - val_root_mean_squared_error: 277.9194
# Epoch 464/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73655.3203 - root_mean_squared_error: 271.3891 - val_loss: 77194.1562 - val_root_mean_squared_error: 277.8383
# Epoch 465/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74204.0000 - root_mean_squared_error: 272.3953 - val_loss: 77342.5078 - val_root_mean_squared_error: 278.1051
# Epoch 466/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73954.6562 - root_mean_squared_error: 271.9429 - val_loss: 77291.0547 - val_root_mean_squared_error: 278.0126
# Epoch 467/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74032.6953 - root_mean_squared_error: 272.0866 - val_loss: 77231.9297 - val_root_mean_squared_error: 277.9062
# Epoch 468/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74427.7734 - root_mean_squared_error: 272.8066 - val_loss: 77254.9922 - val_root_mean_squared_error: 277.9478
# Epoch 469/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74320.3516 - root_mean_squared_error: 272.6118 - val_loss: 77244.1953 - val_root_mean_squared_error: 277.9283
# Epoch 470/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73565.7031 - root_mean_squared_error: 271.2252 - val_loss: 77183.6094 - val_root_mean_squared_error: 277.8193
# Epoch 471/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74322.5391 - root_mean_squared_error: 272.6135 - val_loss: 77334.0234 - val_root_mean_squared_error: 278.0899
# Epoch 472/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73814.6250 - root_mean_squared_error: 271.6823 - val_loss: 77260.6016 - val_root_mean_squared_error: 277.9578
# Epoch 473/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74467.1562 - root_mean_squared_error: 272.8762 - val_loss: 77212.8516 - val_root_mean_squared_error: 277.8719
# Epoch 474/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74653.0234 - root_mean_squared_error: 273.2218 - val_loss: 77284.4688 - val_root_mean_squared_error: 278.0007
# Epoch 475/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74059.7031 - root_mean_squared_error: 272.1278 - val_loss: 77309.0703 - val_root_mean_squared_error: 278.0450
# Epoch 476/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74301.3203 - root_mean_squared_error: 272.5787 - val_loss: 77324.0938 - val_root_mean_squared_error: 278.0720
# Epoch 477/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73904.3359 - root_mean_squared_error: 271.8499 - val_loss: 77221.8359 - val_root_mean_squared_error: 277.8880
# Epoch 478/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74491.7734 - root_mean_squared_error: 272.9250 - val_loss: 77274.5703 - val_root_mean_squared_error: 277.9830
# Epoch 479/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73435.9375 - root_mean_squared_error: 270.9846 - val_loss: 77184.3125 - val_root_mean_squared_error: 277.8206
# Epoch 480/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74753.7031 - root_mean_squared_error: 273.4032 - val_loss: 77372.5625 - val_root_mean_squared_error: 278.1591
# Epoch 481/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73880.9141 - root_mean_squared_error: 271.7987 - val_loss: 77286.7734 - val_root_mean_squared_error: 278.0049
# Epoch 482/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74000.2891 - root_mean_squared_error: 272.0270 - val_loss: 77233.6953 - val_root_mean_squared_error: 277.9094
# Epoch 483/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74128.9375 - root_mean_squared_error: 272.2604 - val_loss: 77353.5859 - val_root_mean_squared_error: 278.1250
# Epoch 484/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74350.0703 - root_mean_squared_error: 272.6577 - val_loss: 77229.8672 - val_root_mean_squared_error: 277.9026
# Epoch 485/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75484.1875 - root_mean_squared_error: 274.7300 - val_loss: 77324.5547 - val_root_mean_squared_error: 278.0728
# Epoch 486/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74566.7500 - root_mean_squared_error: 273.0657 - val_loss: 77336.1250 - val_root_mean_squared_error: 278.0937
# Epoch 487/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74240.0703 - root_mean_squared_error: 272.4625 - val_loss: 77385.9531 - val_root_mean_squared_error: 278.1832
# Epoch 488/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73696.9297 - root_mean_squared_error: 271.4684 - val_loss: 77179.7734 - val_root_mean_squared_error: 277.8124
# Epoch 489/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75528.3125 - root_mean_squared_error: 274.7675 - val_loss: 77191.2266 - val_root_mean_squared_error: 277.8330
# Epoch 490/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73878.1953 - root_mean_squared_error: 271.7993 - val_loss: 77308.9453 - val_root_mean_squared_error: 278.0448
# Epoch 491/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 73634.5938 - root_mean_squared_error: 271.3521 - val_loss: 77257.3281 - val_root_mean_squared_error: 277.9519
# Epoch 492/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74385.7734 - root_mean_squared_error: 272.7357 - val_loss: 77234.0078 - val_root_mean_squared_error: 277.9100
# Epoch 493/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74194.0391 - root_mean_squared_error: 272.3790 - val_loss: 77374.3359 - val_root_mean_squared_error: 278.1624
# Epoch 494/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73979.2891 - root_mean_squared_error: 271.9827 - val_loss: 77257.5703 - val_root_mean_squared_error: 277.9524
# Epoch 495/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74303.4453 - root_mean_squared_error: 272.5785 - val_loss: 77255.5078 - val_root_mean_squared_error: 277.9487
# Epoch 496/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73411.6172 - root_mean_squared_error: 270.9250 - val_loss: 77257.9609 - val_root_mean_squared_error: 277.9531
# Epoch 497/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73776.5000 - root_mean_squared_error: 271.6093 - val_loss: 77396.2891 - val_root_mean_squared_error: 278.2018
# Epoch 498/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74553.0938 - root_mean_squared_error: 273.0338 - val_loss: 77424.9297 - val_root_mean_squared_error: 278.2533
# Epoch 499/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 73783.2344 - root_mean_squared_error: 271.6241 - val_loss: 77302.5469 - val_root_mean_squared_error: 278.0333
# Epoch 500/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 74357.0391 - root_mean_squared_error: 272.6808 - val_loss: 77336.4375 - val_root_mean_squared_error: 278.0942

# %%
epochs = list(range(800, 2000))
plt.figure(figsize=(10, 6))
plt.plot(history.history['root_mean_squared_error'],label='Train MAPE',color='blue')
plt.plot(history.history['val_root_mean_squared_error'],label='Validation MAPE',color='red')
plt.title(f'Mean Absolute Percentage Error (MAPE) from Epoch')
plt.xlabel('Epochs')
plt.ylabel('MAPE (%)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 5 evaluation the final model
#--- we will call the method evaluate() of model on the test set
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
import tensorflow as tf

# Assuming you have test data
# X_test: the test input data
# y_test: the true target values for test data
y_pred = model1.predict(Xtest_prepared)

# MAE (Mean Absolute Error)
mae = mean_absolute_error(ytest_prepared, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(ytest_prepared, y_pred))

# R² (R-squared)
r2 = r2_score(ytest_prepared, y_pred)

# Print the results
print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# MAE: 209.894930382195
# RMSE: 274.3141468885644
# R²: 0.06006951871907118
