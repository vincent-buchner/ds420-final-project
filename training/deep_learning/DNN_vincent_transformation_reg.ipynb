# %% [markdown]
# - Transformation of Amount
# - Fine tuning including dropout and regularization

# %%
# Imports
import tensorflow as tf
import matplotlib.pyplot as plt
###END library importing
from pathlib import Path
import tarfile
import urllib.request
import sys
import io
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import LocalOutlierFactor
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn import set_config
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.metrics import *
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import BaggingRegressor
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import (
    VotingRegressor,
    BaggingRegressor,
    RandomForestRegressor,
    AdaBoostRegressor,
    GradientBoostingRegressor,
    HistGradientBoostingRegressor,
    StackingRegressor)
from tensorflow.keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras import Sequential, layers
import keras_tuner as kt

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from sklearn.linear_model import LinearRegression, SGDRegressor, Ridge
from sklearn.model_selection import train_test_split
from code_files.train import train, train_in_batches, grid_search
from code_files.data_preperation import prepare_for_train
import pandas as pd
import numpy as np

# %%
# Load Dataset
df_amazon = pd.read_csv("../dataset/eda_amazon_sales_report.csv")
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117123 entries, 0 to 117122
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Unnamed: 0                           117123 non-null  int64
#  1   Size                                 117123 non-null  int64
#  2   Qty                                  117123 non-null  int64
#  3   Amount                               117123 non-null  float64
#  4   promotion-ids                        117123 non-null  int64
#  5   B2B                                  117123 non-null  int64
#  6   Status_Cancelled                     117123 non-null  bool
#  7   Status_Shipped                       117123 non-null  bool
#  8   Status_Shipped - Delivered to Buyer  117123 non-null  bool
#  9   Fulfilment_Amazon                    117123 non-null  bool
#  10  Fulfilment_Merchant                  117123 non-null  bool
#  11  ship-service-level_Expedited         117123 non-null  bool
#  12  ship-service-level_Standard          117123 non-null  bool
#  13  Category_Blouse                      117123 non-null  bool
#  14  Category_Bottom                      117123 non-null  bool
#  15  Category_Dupatta                     117123 non-null  bool
#  16  Category_Ethnic Dress                117123 non-null  bool
#  17  Category_Saree                       117123 non-null  bool
#  18  Category_Set                         117123 non-null  bool
#  19  Category_Top                         117123 non-null  bool
#  20  Category_Western Dress               117123 non-null  bool
#  21  Category_kurta                       117123 non-null  bool
#  22  Month                                117123 non-null  int64
#  23  Day                                  117123 non-null  int64
# dtypes: bool(16), float64(1), int64(7)
# memory usage: 8.9 MB

# %%
# Transformation using yeo johnson 
from scipy import stats
df_amazon['Amount'], _ = stats.yeojohnson(df_amazon['Amount'])

# %%
# Split and Prepare for train
dftrain, dftest = train_test_split(df_amazon, test_size=0.1, random_state=42)
Xtrain_prepared, ytrain_prepared, Xtest_prepared, ytest_prepared = prepare_for_train(dftrain, dftest)

Xtrain_prepared, Xdev_prepared, ytrain_prepared, ydev_prepared = train_test_split(Xtrain_prepared, ytrain_prepared,
                                                                                  test_size=0.2, random_state=42)


print("Train shape: ", Xtrain_prepared.shape, ytrain_prepared.shape)
print("Dev shape: ", Xdev_prepared.shape, ydev_prepared.shape)
print("Test shape: ", Xtest_prepared.shape, ytest_prepared.shape)
# Out:
# Train shape:  (83216, 7) (83216,)
# Dev shape:  (20804, 7) (20804,)
# Test shape:  (11713, 7) (11713,)

# %%
# Random Search Hypertuning 

import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras import layers, regularizers

def build_model(hp):

    n_hidden = hp.Int("n_hidden", min_value=2, max_value=10, default=2)
    learning_rate = hp.Float("learning_rate", min_value=1e-4, max_value=0.9,
                                      sampling="log")
    optimizer = hp.Choice("optimizer", values=["sgd", "adam", "adagrad", "rms", "adadelta", 
                                               "adamax", "nadam"])

    if optimizer == "sgd":
        optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
    elif optimizer == "adam":
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == "adagrad":
        optimizer = tf.keras.optimizers.Adagrad(learning_rate=learning_rate)
    elif optimizer == "rms": 
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
    elif optimizer == "adadelta":
        optimizer = tf.keras.optimizers.Adadelta(learning_rate=learning_rate)
    elif optimizer == "adamax":
        optimizer = tf.keras.optimizers.Adamax(learning_rate=learning_rate)
    elif optimizer == "ftrl":
        optimizer = tf.keras.optimizers.Ftrl(learning_rate=learning_rate)
    elif optimizer == "nadam": 
        optimizer = tf.keras.optimizers.Nadam(learning_rate=learning_rate)

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten())

    for _ in range(n_hidden):
        # Adding L2 regularization to Dense layers
        model.add(tf.keras.layers.Dense(
            units = hp.Int("n_neurons", min_value=100, max_value=900, step=50, sampling="log"),
            activation=hp.Choice("activation", values=["relu", "tanh", "selu", "linear", "swish", "softplus", "exponential"]),
            kernel_regularizer=regularizers.l2(hp.Float("l2_reg", min_value=1e-5, max_value=1e-1, sampling="log"))  # Regularization added
        ))
        model.add(layers.Dropout(rate=hp.Float("dropout_rate", min_value=0.1, max_value=0.9, step=0.1)))

    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        loss='mse',
        optimizer=optimizer,
        metrics=[tf.keras.metrics.RootMeanSquaredError()]
    )
    return model

########################

# Define parameter grid
out_folder = "amazon"
rnd_search_folder = "rnd_search"
random_search_tuner = kt.RandomSearch(
    build_model, objective="loss", max_trials=25, overwrite=True,
    directory=out_folder, project_name=rnd_search_folder, seed=42
)

random_search_tuner.search(Xtrain_prepared, ytrain_prepared, epochs=5, batch_size=64,
                           validation_data=(Xdev_prepared, ydev_prepared))

random_search_tuner.search_space_summary()

random_search_tuner.results_summary()

# Build the best model and retrain it
top3_models = random_search_tuner.get_best_models(num_models=3)

top3_params = random_search_tuner.get_best_hyperparameters(num_trials=3)

for i in range(len(top3_params)):
    print(top3_params[i].values)
# Out:
# Trial 25 Complete [00h 00m 08s]
# loss: 3020.85205078125
#
# Best loss So Far: 1495.6165771484375
# Total elapsed time: 00h 04m 27s
# Search space summary
# Default search space size: 7
# n_hidden (Int)
# {'default': 2, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.9, 'step': None, 'sampling': 'log'}
# optimizer (Choice)
# {'default': 'sgd', 'conditions': [], 'values': ['sgd', 'adam', 'adagrad', 'rms', 'adadelta', 'adamax', 'nadam'], 'ordered': False}
# n_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 100, 'max_value': 900, 'step': 50, 'sampling': 'log'}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh', 'selu', 'linear', 'swish', 'softplus', 'exponential'], 'ordered': False}
# l2_reg (Float)
# {'default': 1e-05, 'conditions': [], 'min_value': 1e-05, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# dropout_rate (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.9, 'step': 0.1, 'sampling': 'linear'}
# Results summary
# Results in amazon/rnd_search
# Showing 10 best trials
# Objective(name="loss", direction="min")
#
# Trial 01 summary
# Hyperparameters:
# n_hidden: 2
# learning_rate: 0.009276416723841687
# optimizer: adam
# n_neurons: 100
# activation: swish
# l2_reg: 0.04514107426881946
# dropout_rate: 0.1
# Score: 1495.6165771484375
#
# Trial 07 summary
# Hyperparameters:
# n_hidden: 2
# learning_rate: 0.00462287884982147
# optimizer: nadam
# n_neurons: 100
# activation: softplus
# l2_reg: 0.0003036527652974287
# dropout_rate: 0.2
# Score: 1542.3817138671875
#
# Trial 06 summary
# Hyperparameters:
# n_hidden: 8
# learning_rate: 0.0006154916238814045
# optimizer: adamax
# n_neurons: 100
# activation: selu
# l2_reg: 2.1103896995739087e-05
# dropout_rate: 0.2
# Score: 1555.5567626953125
#
# Trial 23 summary
# Hyperparameters:
# n_hidden: 2
# learning_rate: 0.003710773970922463
# optimizer: rms
# n_neurons: 100
# activation: linear
# l2_reg: 0.000130692163429327
# dropout_rate: 0.6
# Score: 1691.71142578125
#
# Trial 13 summary
# Hyperparameters:
# n_hidden: 6
# learning_rate: 0.008209618290737282
# optimizer: adadelta
# n_neurons: 100
# activation: relu
# l2_reg: 5.939437813279243e-05
# dropout_rate: 0.1
# Score: 1777.134765625
#
# Trial 17 summary
# Hyperparameters:
# n_hidden: 6
# learning_rate: 0.00016306445834756255
# optimizer: rms
# n_neurons: 100
# activation: relu
# l2_reg: 5.186297414751111e-05
# dropout_rate: 0.30000000000000004
# Score: 1779.203369140625
#
# Trial 12 summary
# Hyperparameters:
# n_hidden: 7
# learning_rate: 0.00015005950274957962
# optimizer: nadam
# n_neurons: 100
# activation: linear
# l2_reg: 0.00018270092881049886
# dropout_rate: 0.4
# Score: 1890.2618408203125
#
# Trial 14 summary
# Hyperparameters:
# n_hidden: 8
# learning_rate: 0.011107396927757099
# optimizer: adadelta
# n_neurons: 100
# activation: linear
# l2_reg: 0.030332128706208862
# dropout_rate: 0.2
# Score: 2158.804931640625
#
# Trial 16 summary
# Hyperparameters:
# n_hidden: 3
# learning_rate: 0.019813685892326818
# optimizer: rms
# n_neurons: 100
# activation: swish
# l2_reg: 0.00037851189036649857
# dropout_rate: 0.2
# Score: 2306.343994140625
#
# Trial 10 summary
# Hyperparameters:
# n_hidden: 6
# learning_rate: 0.00013207576838118471
# optimizer: adam
# n_neurons: 100
# activation: softplus
# l2_reg: 9.128766954851047e-05
# dropout_rate: 0.7000000000000001
# Score: 2681.17529296875
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'nadam', because it has 2 variables whereas the saved optimizer has 15 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# {'n_hidden': 2, 'learning_rate': 0.009276416723841687, 'optimizer': 'adam', 'n_neurons': 100, 'activation': 'swish', 'l2_reg': 0.04514107426881946, 'dropout_rate': 0.1}
# {'n_hidden': 2, 'learning_rate': 0.00462287884982147, 'optimizer': 'nadam', 'n_neurons': 100, 'activation': 'softplus', 'l2_reg': 0.0003036527652974287, 'dropout_rate': 0.2}
# {'n_hidden': 8, 'learning_rate': 0.0006154916238814045, 'optimizer': 'adamax', 'n_neurons': 100, 'activation': 'selu', 'l2_reg': 2.1103896995739087e-05, 'dropout_rate': 0.2}
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adamax', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
from tensorflow.keras import regularizers

optimizer1 = tf.keras.optimizers.Adam(learning_rate=0.009276416723841687)

model1 = tf.keras.Sequential()

model1.add(tf.keras.layers.Input(shape=(7,)))  

model1.add(tf.keras.layers.Dense(100, activation="swish"))
model1.add(tf.keras.layers.Dropout(0.1))
model1.add(tf.keras.layers.Dense(100, activation="swish"))
model1.add(tf.keras.layers.Dropout(0.1))


model1.add(tf.keras.layers.Dense(1, activation="linear", kernel_regularizer=regularizers.l2(0.04514107426881946)))

model1.compile(loss="mse", optimizer=optimizer1, metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Print the model summary
model1.summary()

# Train the model
history = model1.fit(
    Xtrain_prepared, ytrain_prepared,
    epochs=500,     
    batch_size=64,      
    validation_data=(Xdev_prepared, ydev_prepared)
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 100)            │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,001 (42.97 KB)
#  Trainable params: 11,001 (42.97 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 759us/step - loss: 2783.9448 - root_mean_squared_error: 50.6844 - val_loss: 1529.5647 - val_root_mean_squared_error: 39.0815
# Epoch 2/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 872us/step - loss: 1530.6805 - root_mean_squared_error: 39.0896 - val_loss: 1529.3778 - val_root_mean_squared_error: 39.0510
# Epoch 3/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 794us/step - loss: 1529.1252 - root_mean_squared_error: 39.0383 - val_loss: 1528.8102 - val_root_mean_squared_error: 39.0031
# Epoch 4/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 811us/step - loss: 1509.4924 - root_mean_squared_error: 38.7433 - val_loss: 1516.4263 - val_root_mean_squared_error: 38.8036
# Epoch 5/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step - loss: 1510.9906 - root_mean_squared_error: 38.7285 - val_loss: 1511.5479 - val_root_mean_squared_error: 38.7270
# Epoch 6/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step - loss: 1514.8464 - root_mean_squared_error: 38.7698 - val_loss: 1525.8680 - val_root_mean_squared_error: 38.9277
# Epoch 7/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - loss: 1493.5192 - root_mean_squared_error: 38.5135 - val_loss: 1507.3529 - val_root_mean_squared_error: 38.7104
# Epoch 8/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - loss: 1498.6085 - root_mean_squared_error: 38.6008 - val_loss: 1505.1844 - val_root_mean_squared_error: 38.7009
# Epoch 9/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1503.8459 - root_mean_squared_error: 38.6838 - val_loss: 1507.1522 - val_root_mean_squared_error: 38.7404
# Epoch 10/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 1496.0208 - root_mean_squared_error: 38.5976 - val_loss: 1511.3982 - val_root_mean_squared_error: 38.8027
# Epoch 11/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step - loss: 1495.0924 - root_mean_squared_error: 38.5948 - val_loss: 1515.1180 - val_root_mean_squared_error: 38.8618
# Epoch 12/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - loss: 1502.6434 - root_mean_squared_error: 38.6997 - val_loss: 1503.2059 - val_root_mean_squared_error: 38.7135
# Epoch 13/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step - loss: 1485.9143 - root_mean_squared_error: 38.4900 - val_loss: 1515.5890 - val_root_mean_squared_error: 38.8732
# Epoch 14/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1474.4971 - root_mean_squared_error: 38.3401 - val_loss: 1495.7231 - val_root_mean_squared_error: 38.6184
# Epoch 15/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1478.0599 - root_mean_squared_error: 38.3895 - val_loss: 1497.8269 - val_root_mean_squared_error: 38.6476
# Epoch 16/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - loss: 1481.0796 - root_mean_squared_error: 38.4296 - val_loss: 1497.3223 - val_root_mean_squared_error: 38.6384
# Epoch 17/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 696us/step - loss: 1482.1194 - root_mean_squared_error: 38.4406 - val_loss: 1515.7667 - val_root_mean_squared_error: 38.8759
# Epoch 18/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - loss: 1485.3729 - root_mean_squared_error: 38.4841 - val_loss: 1499.0718 - val_root_mean_squared_error: 38.6618
# Epoch 19/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1500.9120 - root_mean_squared_error: 38.6860 - val_loss: 1499.6301 - val_root_mean_squared_error: 38.6727
# Epoch 20/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1478.4722 - root_mean_squared_error: 38.3961 - val_loss: 1498.9807 - val_root_mean_squared_error: 38.6642
# Epoch 21/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1487.2308 - root_mean_squared_error: 38.5129 - val_loss: 1495.7640 - val_root_mean_squared_error: 38.6244
# Epoch 22/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 695us/step - loss: 1471.2672 - root_mean_squared_error: 38.3041 - val_loss: 1511.2977 - val_root_mean_squared_error: 38.8255
# Epoch 23/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1476.8376 - root_mean_squared_error: 38.3774 - val_loss: 1511.6998 - val_root_mean_squared_error: 38.8305
# Epoch 24/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1490.8350 - root_mean_squared_error: 38.5615 - val_loss: 1500.6287 - val_root_mean_squared_error: 38.6900
# Epoch 25/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step - loss: 1470.5276 - root_mean_squared_error: 38.2986 - val_loss: 1511.0862 - val_root_mean_squared_error: 38.8246
# Epoch 26/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - loss: 1477.9666 - root_mean_squared_error: 38.3950 - val_loss: 1503.9229 - val_root_mean_squared_error: 38.7327
# Epoch 27/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 701us/step - loss: 1472.5920 - root_mean_squared_error: 38.3258 - val_loss: 1494.7433 - val_root_mean_squared_error: 38.6143
# Epoch 28/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1471.4329 - root_mean_squared_error: 38.3105 - val_loss: 1505.1635 - val_root_mean_squared_error: 38.7501
# Epoch 29/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - loss: 1485.4500 - root_mean_squared_error: 38.4941 - val_loss: 1503.2229 - val_root_mean_squared_error: 38.7265
# Epoch 30/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1493.2239 - root_mean_squared_error: 38.5953 - val_loss: 1501.9080 - val_root_mean_squared_error: 38.7113
# Epoch 31/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - loss: 1478.8896 - root_mean_squared_error: 38.4142 - val_loss: 1497.3319 - val_root_mean_squared_error: 38.6528
# Epoch 32/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1488.4950 - root_mean_squared_error: 38.5391 - val_loss: 1494.7346 - val_root_mean_squared_error: 38.6229
# Epoch 33/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1461.4628 - root_mean_squared_error: 38.1886 - val_loss: 1508.4337 - val_root_mean_squared_error: 38.8005
# Epoch 34/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - loss: 1499.2076 - root_mean_squared_error: 38.6790 - val_loss: 1492.8481 - val_root_mean_squared_error: 38.6004
# Epoch 35/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1477.7614 - root_mean_squared_error: 38.4021 - val_loss: 1502.5369 - val_root_mean_squared_error: 38.7237
# Epoch 36/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1478.4163 - root_mean_squared_error: 38.4097 - val_loss: 1495.4868 - val_root_mean_squared_error: 38.6345
# Epoch 37/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1464.2762 - root_mean_squared_error: 38.2292 - val_loss: 1494.1686 - val_root_mean_squared_error: 38.6201
# Epoch 38/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1484.4106 - root_mean_squared_error: 38.4927 - val_loss: 1493.1542 - val_root_mean_squared_error: 38.6092
# Epoch 39/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 1475.6462 - root_mean_squared_error: 38.3810 - val_loss: 1493.2454 - val_root_mean_squared_error: 38.6125
# Epoch 40/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1454.8263 - root_mean_squared_error: 38.1103 - val_loss: 1493.0558 - val_root_mean_squared_error: 38.6076
# Epoch 41/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 1478.0972 - root_mean_squared_error: 38.4136 - val_loss: 1516.2883 - val_root_mean_squared_error: 38.9081
# Epoch 42/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step - loss: 1472.3037 - root_mean_squared_error: 38.3379 - val_loss: 1490.3152 - val_root_mean_squared_error: 38.5739
# Epoch 43/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - loss: 1471.9138 - root_mean_squared_error: 38.3341 - val_loss: 1551.6582 - val_root_mean_squared_error: 39.3599
# Epoch 44/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1466.9779 - root_mean_squared_error: 38.2681 - val_loss: 1489.6210 - val_root_mean_squared_error: 38.5654
# Epoch 45/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1450.7537 - root_mean_squared_error: 38.0584 - val_loss: 1504.2173 - val_root_mean_squared_error: 38.7571
# Epoch 46/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - loss: 1469.6262 - root_mean_squared_error: 38.3069 - val_loss: 1494.3083 - val_root_mean_squared_error: 38.6279
# Epoch 47/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1463.8197 - root_mean_squared_error: 38.2310 - val_loss: 1496.0405 - val_root_mean_squared_error: 38.6504
# Epoch 48/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1474.7799 - root_mean_squared_error: 38.3741 - val_loss: 1515.3849 - val_root_mean_squared_error: 38.8997
# Epoch 49/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1461.0287 - root_mean_squared_error: 38.1952 - val_loss: 1495.2373 - val_root_mean_squared_error: 38.6423
# Epoch 50/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - loss: 1451.2982 - root_mean_squared_error: 38.0675 - val_loss: 1500.6459 - val_root_mean_squared_error: 38.7127
# Epoch 51/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1483.0568 - root_mean_squared_error: 38.4851 - val_loss: 1505.3202 - val_root_mean_squared_error: 38.7747
# Epoch 52/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1478.4135 - root_mean_squared_error: 38.4266 - val_loss: 1493.5317 - val_root_mean_squared_error: 38.6236
# Epoch 53/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1473.3412 - root_mean_squared_error: 38.3599 - val_loss: 1516.1504 - val_root_mean_squared_error: 38.9173
# Epoch 54/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1489.5570 - root_mean_squared_error: 38.5731 - val_loss: 1508.3604 - val_root_mean_squared_error: 38.8154
# Epoch 55/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1484.7648 - root_mean_squared_error: 38.5104 - val_loss: 1495.7047 - val_root_mean_squared_error: 38.6546
# Epoch 56/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 701us/step - loss: 1463.8837 - root_mean_squared_error: 38.2397 - val_loss: 1508.5126 - val_root_mean_squared_error: 38.8194
# Epoch 57/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - loss: 1466.7582 - root_mean_squared_error: 38.2759 - val_loss: 1499.1837 - val_root_mean_squared_error: 38.6999
# Epoch 58/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - loss: 1461.0703 - root_mean_squared_error: 38.2026 - val_loss: 1521.4192 - val_root_mean_squared_error: 38.9846
# Epoch 59/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1490.9224 - root_mean_squared_error: 38.5899 - val_loss: 1491.4010 - val_root_mean_squared_error: 38.5975
# Epoch 60/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 1457.8551 - root_mean_squared_error: 38.1596 - val_loss: 1491.7657 - val_root_mean_squared_error: 38.6031
# Epoch 61/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1473.2242 - root_mean_squared_error: 38.3622 - val_loss: 1491.2717 - val_root_mean_squared_error: 38.5963
# Epoch 62/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1460.1222 - root_mean_squared_error: 38.1899 - val_loss: 1490.3740 - val_root_mean_squared_error: 38.5847
# Epoch 63/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1474.3495 - root_mean_squared_error: 38.3750 - val_loss: 1523.9961 - val_root_mean_squared_error: 39.0192
# Epoch 64/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - loss: 1462.4000 - root_mean_squared_error: 38.2187 - val_loss: 1491.6530 - val_root_mean_squared_error: 38.6039
# Epoch 65/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step - loss: 1457.6270 - root_mean_squared_error: 38.1591 - val_loss: 1529.4224 - val_root_mean_squared_error: 39.0927
# Epoch 66/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 702us/step - loss: 1458.6333 - root_mean_squared_error: 38.1755 - val_loss: 1493.4342 - val_root_mean_squared_error: 38.6291
# Epoch 67/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 746us/step - loss: 1467.3461 - root_mean_squared_error: 38.2889 - val_loss: 1491.4265 - val_root_mean_squared_error: 38.6018
# Epoch 68/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1471.3149 - root_mean_squared_error: 38.3397 - val_loss: 1494.6604 - val_root_mean_squared_error: 38.6435
# Epoch 69/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - loss: 1459.5576 - root_mean_squared_error: 38.1853 - val_loss: 1500.4241 - val_root_mean_squared_error: 38.7194
# Epoch 70/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 1473.8987 - root_mean_squared_error: 38.3743 - val_loss: 1493.2576 - val_root_mean_squared_error: 38.6259
# Epoch 71/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1471.5789 - root_mean_squared_error: 38.3439 - val_loss: 1502.4137 - val_root_mean_squared_error: 38.7460
# Epoch 72/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1464.5293 - root_mean_squared_error: 38.2519 - val_loss: 1493.4313 - val_root_mean_squared_error: 38.6285
# Epoch 73/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 747us/step - loss: 1471.2852 - root_mean_squared_error: 38.3403 - val_loss: 1493.0894 - val_root_mean_squared_error: 38.6247
# Epoch 74/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 702us/step - loss: 1448.1831 - root_mean_squared_error: 38.0364 - val_loss: 1491.8065 - val_root_mean_squared_error: 38.6083
# Epoch 75/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 747us/step - loss: 1440.2069 - root_mean_squared_error: 37.9332 - val_loss: 1504.7235 - val_root_mean_squared_error: 38.7753
# Epoch 76/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1479.3152 - root_mean_squared_error: 38.4448 - val_loss: 1503.6421 - val_root_mean_squared_error: 38.7615
# Epoch 77/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1440.4005 - root_mean_squared_error: 37.9352 - val_loss: 1495.0631 - val_root_mean_squared_error: 38.6517
# Epoch 78/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1477.0670 - root_mean_squared_error: 38.4172 - val_loss: 1488.7771 - val_root_mean_squared_error: 38.5702
# Epoch 79/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - loss: 1458.8354 - root_mean_squared_error: 38.1782 - val_loss: 1488.3411 - val_root_mean_squared_error: 38.5641
# Epoch 80/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 692us/step - loss: 1454.8529 - root_mean_squared_error: 38.1266 - val_loss: 1507.3019 - val_root_mean_squared_error: 38.8102
# Epoch 81/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1460.1427 - root_mean_squared_error: 38.1967 - val_loss: 1504.9161 - val_root_mean_squared_error: 38.7797
# Epoch 82/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - loss: 1456.0670 - root_mean_squared_error: 38.1430 - val_loss: 1492.1564 - val_root_mean_squared_error: 38.6148
# Epoch 83/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1479.8438 - root_mean_squared_error: 38.4544 - val_loss: 1495.2499 - val_root_mean_squared_error: 38.6549
# Epoch 84/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 675us/step - loss: 1462.1815 - root_mean_squared_error: 38.2239 - val_loss: 1492.2998 - val_root_mean_squared_error: 38.6160
# Epoch 85/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1477.6329 - root_mean_squared_error: 38.4254 - val_loss: 1491.1825 - val_root_mean_squared_error: 38.6032
# Epoch 86/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 723us/step - loss: 1442.9363 - root_mean_squared_error: 37.9719 - val_loss: 1509.1741 - val_root_mean_squared_error: 38.8353
# Epoch 87/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1463.4468 - root_mean_squared_error: 38.2415 - val_loss: 1491.0356 - val_root_mean_squared_error: 38.6005
# Epoch 88/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1447.0182 - root_mean_squared_error: 38.0254 - val_loss: 1491.2971 - val_root_mean_squared_error: 38.6046
# Epoch 89/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step - loss: 1460.4991 - root_mean_squared_error: 38.2022 - val_loss: 1488.1744 - val_root_mean_squared_error: 38.5630
# Epoch 90/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1464.7749 - root_mean_squared_error: 38.2571 - val_loss: 1493.6555 - val_root_mean_squared_error: 38.6348
# Epoch 91/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step - loss: 1460.4791 - root_mean_squared_error: 38.2008 - val_loss: 1497.4301 - val_root_mean_squared_error: 38.6841
# Epoch 92/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1446.1427 - root_mean_squared_error: 38.0132 - val_loss: 1495.5647 - val_root_mean_squared_error: 38.6599
# Epoch 93/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 1450.6606 - root_mean_squared_error: 38.0739 - val_loss: 1510.8441 - val_root_mean_squared_error: 38.8560
# Epoch 94/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 1459.2791 - root_mean_squared_error: 38.1878 - val_loss: 1493.5419 - val_root_mean_squared_error: 38.6349
# Epoch 95/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1466.0366 - root_mean_squared_error: 38.2767 - val_loss: 1494.4528 - val_root_mean_squared_error: 38.6474
# Epoch 96/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - loss: 1457.1847 - root_mean_squared_error: 38.1615 - val_loss: 1516.3323 - val_root_mean_squared_error: 38.9293
# Epoch 97/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1461.1006 - root_mean_squared_error: 38.2135 - val_loss: 1491.2390 - val_root_mean_squared_error: 38.6062
# Epoch 98/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step - loss: 1462.5204 - root_mean_squared_error: 38.2319 - val_loss: 1498.6238 - val_root_mean_squared_error: 38.7002
# Epoch 99/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 723us/step - loss: 1467.0952 - root_mean_squared_error: 38.2896 - val_loss: 1489.7169 - val_root_mean_squared_error: 38.5864
# Epoch 100/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1435.9185 - root_mean_squared_error: 37.8815 - val_loss: 1521.1691 - val_root_mean_squared_error: 38.9918
# Epoch 101/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1441.0764 - root_mean_squared_error: 37.9502 - val_loss: 1504.7321 - val_root_mean_squared_error: 38.7816
# Epoch 102/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 747us/step - loss: 1466.0688 - root_mean_squared_error: 38.2777 - val_loss: 1491.1721 - val_root_mean_squared_error: 38.6040
# Epoch 103/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 1464.6625 - root_mean_squared_error: 38.2562 - val_loss: 1500.5924 - val_root_mean_squared_error: 38.7266
# Epoch 104/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1450.1638 - root_mean_squared_error: 38.0690 - val_loss: 1526.0695 - val_root_mean_squared_error: 39.0536
# Epoch 105/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step - loss: 1452.2257 - root_mean_squared_error: 38.0958 - val_loss: 1490.9323 - val_root_mean_squared_error: 38.6025
# Epoch 106/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - loss: 1458.0455 - root_mean_squared_error: 38.1729 - val_loss: 1496.8307 - val_root_mean_squared_error: 38.6793
# Epoch 107/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - loss: 1467.6238 - root_mean_squared_error: 38.2986 - val_loss: 1493.7455 - val_root_mean_squared_error: 38.6402
# Epoch 108/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 697us/step - loss: 1464.2928 - root_mean_squared_error: 38.2556 - val_loss: 1492.6821 - val_root_mean_squared_error: 38.6251
# Epoch 109/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1466.8197 - root_mean_squared_error: 38.2882 - val_loss: 1492.1862 - val_root_mean_squared_error: 38.6194
# Epoch 110/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - loss: 1454.9645 - root_mean_squared_error: 38.1341 - val_loss: 1491.7156 - val_root_mean_squared_error: 38.6148
# Epoch 111/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1454.8286 - root_mean_squared_error: 38.1328 - val_loss: 1526.1731 - val_root_mean_squared_error: 39.0586
# Epoch 112/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 1446.3717 - root_mean_squared_error: 38.0235 - val_loss: 1495.4854 - val_root_mean_squared_error: 38.6635
# Epoch 113/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - loss: 1447.2788 - root_mean_squared_error: 38.0344 - val_loss: 1495.9034 - val_root_mean_squared_error: 38.6691
# Epoch 114/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 741us/step - loss: 1449.7252 - root_mean_squared_error: 38.0657 - val_loss: 1488.7448 - val_root_mean_squared_error: 38.5766
# Epoch 115/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1451.4803 - root_mean_squared_error: 38.0899 - val_loss: 1511.3287 - val_root_mean_squared_error: 38.8670
# Epoch 116/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 1452.8607 - root_mean_squared_error: 38.1063 - val_loss: 1499.5311 - val_root_mean_squared_error: 38.7158
# Epoch 117/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - loss: 1456.0632 - root_mean_squared_error: 38.1503 - val_loss: 1494.0459 - val_root_mean_squared_error: 38.6458
# Epoch 118/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 1445.4480 - root_mean_squared_error: 38.0109 - val_loss: 1489.6321 - val_root_mean_squared_error: 38.5890
# Epoch 119/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 706us/step - loss: 1438.7212 - root_mean_squared_error: 37.9226 - val_loss: 1492.9474 - val_root_mean_squared_error: 38.6325
# Epoch 120/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step - loss: 1461.7125 - root_mean_squared_error: 38.2236 - val_loss: 1520.1736 - val_root_mean_squared_error: 38.9810
# Epoch 121/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1453.7375 - root_mean_squared_error: 38.1188 - val_loss: 1496.3838 - val_root_mean_squared_error: 38.6758
# Epoch 122/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1443.9507 - root_mean_squared_error: 37.9910 - val_loss: 1496.9965 - val_root_mean_squared_error: 38.6846
# Epoch 123/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1453.8116 - root_mean_squared_error: 38.1219 - val_loss: 1490.8212 - val_root_mean_squared_error: 38.6047
# Epoch 124/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1458.2344 - root_mean_squared_error: 38.1802 - val_loss: 1489.3866 - val_root_mean_squared_error: 38.5858
# Epoch 125/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step - loss: 1459.2872 - root_mean_squared_error: 38.1927 - val_loss: 1487.2072 - val_root_mean_squared_error: 38.5577
# Epoch 126/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 1467.5453 - root_mean_squared_error: 38.3013 - val_loss: 1496.2200 - val_root_mean_squared_error: 38.6744
# Epoch 127/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step - loss: 1459.4384 - root_mean_squared_error: 38.1961 - val_loss: 1490.6686 - val_root_mean_squared_error: 38.6028
# Epoch 128/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 736us/step - loss: 1479.9913 - root_mean_squared_error: 38.4629 - val_loss: 1500.1396 - val_root_mean_squared_error: 38.7258
# Epoch 129/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step - loss: 1462.5610 - root_mean_squared_error: 38.2369 - val_loss: 1491.9720 - val_root_mean_squared_error: 38.6204
# Epoch 130/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 742us/step - loss: 1450.6670 - root_mean_squared_error: 38.0815 - val_loss: 1505.4012 - val_root_mean_squared_error: 38.7934
# Epoch 131/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 1458.1644 - root_mean_squared_error: 38.1772 - val_loss: 1494.5970 - val_root_mean_squared_error: 38.6549
# Epoch 132/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step - loss: 1448.6716 - root_mean_squared_error: 38.0550 - val_loss: 1489.2413 - val_root_mean_squared_error: 38.5854
# Epoch 133/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - loss: 1453.5023 - root_mean_squared_error: 38.1184 - val_loss: 1490.1941 - val_root_mean_squared_error: 38.5973
# Epoch 134/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1448.1075 - root_mean_squared_error: 38.0482 - val_loss: 1490.7549 - val_root_mean_squared_error: 38.6052
# Epoch 135/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1453.5034 - root_mean_squared_error: 38.1192 - val_loss: 1495.8315 - val_root_mean_squared_error: 38.6708
# Epoch 136/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step - loss: 1442.3048 - root_mean_squared_error: 37.9717 - val_loss: 1495.6807 - val_root_mean_squared_error: 38.6692
# Epoch 137/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - loss: 1445.5533 - root_mean_squared_error: 38.0150 - val_loss: 1489.1979 - val_root_mean_squared_error: 38.5855
# Epoch 138/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step - loss: 1461.5293 - root_mean_squared_error: 38.2233 - val_loss: 1491.8937 - val_root_mean_squared_error: 38.6191
# Epoch 139/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 708us/step - loss: 1470.7134 - root_mean_squared_error: 38.3433 - val_loss: 1493.0311 - val_root_mean_squared_error: 38.6350
# Epoch 140/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - loss: 1459.1052 - root_mean_squared_error: 38.1926 - val_loss: 1490.3412 - val_root_mean_squared_error: 38.6000
# Epoch 141/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 708us/step - loss: 1446.8623 - root_mean_squared_error: 38.0308 - val_loss: 1495.5439 - val_root_mean_squared_error: 38.6678
# Epoch 142/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - loss: 1451.6677 - root_mean_squared_error: 38.0955 - val_loss: 1490.2079 - val_root_mean_squared_error: 38.5984
# Epoch 143/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 743us/step - loss: 1436.3195 - root_mean_squared_error: 37.8929 - val_loss: 1487.7169 - val_root_mean_squared_error: 38.5666
# Epoch 144/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1453.0828 - root_mean_squared_error: 38.1143 - val_loss: 1490.2565 - val_root_mean_squared_error: 38.5991
# Epoch 145/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step - loss: 1457.2455 - root_mean_squared_error: 38.1686 - val_loss: 1491.9119 - val_root_mean_squared_error: 38.6207
# Epoch 146/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - loss: 1452.7799 - root_mean_squared_error: 38.1100 - val_loss: 1490.9939 - val_root_mean_squared_error: 38.6086
# Epoch 147/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1440.4286 - root_mean_squared_error: 37.9477 - val_loss: 1484.9767 - val_root_mean_squared_error: 38.5318
# Epoch 148/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - loss: 1465.1323 - root_mean_squared_error: 38.2720 - val_loss: 1494.8883 - val_root_mean_squared_error: 38.6600
# Epoch 149/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 711us/step - loss: 1449.3616 - root_mean_squared_error: 38.0662 - val_loss: 1490.4971 - val_root_mean_squared_error: 38.6031
# Epoch 150/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1447.6302 - root_mean_squared_error: 38.0427 - val_loss: 1492.9867 - val_root_mean_squared_error: 38.6351
# Epoch 151/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1463.8168 - root_mean_squared_error: 38.2511 - val_loss: 1489.9713 - val_root_mean_squared_error: 38.5961
# Epoch 152/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step - loss: 1450.2817 - root_mean_squared_error: 38.0771 - val_loss: 1498.2891 - val_root_mean_squared_error: 38.7032
# Epoch 153/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1441.9963 - root_mean_squared_error: 37.9679 - val_loss: 1496.6243 - val_root_mean_squared_error: 38.6825
# Epoch 154/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step - loss: 1455.2943 - root_mean_squared_error: 38.1439 - val_loss: 1489.8052 - val_root_mean_squared_error: 38.5935
# Epoch 155/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - loss: 1466.9579 - root_mean_squared_error: 38.2953 - val_loss: 1500.8145 - val_root_mean_squared_error: 38.7360
# Epoch 156/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1445.5892 - root_mean_squared_error: 38.0156 - val_loss: 1488.1718 - val_root_mean_squared_error: 38.5726
# Epoch 157/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 706us/step - loss: 1471.8149 - root_mean_squared_error: 38.3574 - val_loss: 1496.2129 - val_root_mean_squared_error: 38.6766
# Epoch 158/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - loss: 1458.9530 - root_mean_squared_error: 38.1911 - val_loss: 1489.2189 - val_root_mean_squared_error: 38.5873
# Epoch 159/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step - loss: 1450.4174 - root_mean_squared_error: 38.0802 - val_loss: 1502.3002 - val_root_mean_squared_error: 38.7561
# Epoch 160/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - loss: 1447.9214 - root_mean_squared_error: 38.0469 - val_loss: 1489.0840 - val_root_mean_squared_error: 38.5848
# Epoch 161/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1445.8953 - root_mean_squared_error: 38.0204 - val_loss: 1492.5439 - val_root_mean_squared_error: 38.6292
# Epoch 162/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1442.3984 - root_mean_squared_error: 37.9741 - val_loss: 1492.0568 - val_root_mean_squared_error: 38.6238
# Epoch 163/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - loss: 1445.3500 - root_mean_squared_error: 38.0135 - val_loss: 1487.0300 - val_root_mean_squared_error: 38.5588
# Epoch 164/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1452.5542 - root_mean_squared_error: 38.1079 - val_loss: 1503.5964 - val_root_mean_squared_error: 38.7725
# Epoch 165/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1449.8060 - root_mean_squared_error: 38.0717 - val_loss: 1518.7966 - val_root_mean_squared_error: 38.9684
# Epoch 166/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - loss: 1451.4059 - root_mean_squared_error: 38.0935 - val_loss: 1496.2892 - val_root_mean_squared_error: 38.6782
# Epoch 167/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step - loss: 1479.5906 - root_mean_squared_error: 38.4564 - val_loss: 1492.7306 - val_root_mean_squared_error: 38.6330
# Epoch 168/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1450.2736 - root_mean_squared_error: 38.0774 - val_loss: 1497.5962 - val_root_mean_squared_error: 38.6955
# Epoch 169/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1428.7478 - root_mean_squared_error: 37.7948 - val_loss: 1517.3192 - val_root_mean_squared_error: 38.9495
# Epoch 170/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step - loss: 1466.4591 - root_mean_squared_error: 38.2885 - val_loss: 1488.7477 - val_root_mean_squared_error: 38.5809
# Epoch 171/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - loss: 1455.3488 - root_mean_squared_error: 38.1452 - val_loss: 1491.0558 - val_root_mean_squared_error: 38.6114
# Epoch 172/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1426.8391 - root_mean_squared_error: 37.7667 - val_loss: 1491.1355 - val_root_mean_squared_error: 38.6111
# Epoch 173/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 711us/step - loss: 1462.8341 - root_mean_squared_error: 38.2424 - val_loss: 1492.8616 - val_root_mean_squared_error: 38.6348
# Epoch 174/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 708us/step - loss: 1456.6399 - root_mean_squared_error: 38.1619 - val_loss: 1488.0492 - val_root_mean_squared_error: 38.5720
# Epoch 175/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 742us/step - loss: 1447.4094 - root_mean_squared_error: 38.0413 - val_loss: 1489.3079 - val_root_mean_squared_error: 38.5882
# Epoch 176/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - loss: 1453.6174 - root_mean_squared_error: 38.1211 - val_loss: 1505.6890 - val_root_mean_squared_error: 38.8004
# Epoch 177/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1458.0709 - root_mean_squared_error: 38.1795 - val_loss: 1488.4996 - val_root_mean_squared_error: 38.5780
# Epoch 178/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1449.4911 - root_mean_squared_error: 38.0677 - val_loss: 1492.1451 - val_root_mean_squared_error: 38.6253
# Epoch 179/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1452.8446 - root_mean_squared_error: 38.1130 - val_loss: 1488.3070 - val_root_mean_squared_error: 38.5757
# Epoch 180/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1437.1017 - root_mean_squared_error: 37.9050 - val_loss: 1486.8975 - val_root_mean_squared_error: 38.5578
# Epoch 181/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 1455.2212 - root_mean_squared_error: 38.1440 - val_loss: 1491.6265 - val_root_mean_squared_error: 38.6185
# Epoch 182/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1441.1238 - root_mean_squared_error: 37.9585 - val_loss: 1486.3671 - val_root_mean_squared_error: 38.5503
# Epoch 183/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1434.1221 - root_mean_squared_error: 37.8651 - val_loss: 1496.4211 - val_root_mean_squared_error: 38.6809
# Epoch 184/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1429.2930 - root_mean_squared_error: 37.8015 - val_loss: 1490.8708 - val_root_mean_squared_error: 38.6089
# Epoch 185/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1441.3394 - root_mean_squared_error: 37.9614 - val_loss: 1498.0559 - val_root_mean_squared_error: 38.7020
# Epoch 186/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 1452.3411 - root_mean_squared_error: 38.1060 - val_loss: 1489.7755 - val_root_mean_squared_error: 38.5950
# Epoch 187/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step - loss: 1440.4690 - root_mean_squared_error: 37.9494 - val_loss: 1492.9691 - val_root_mean_squared_error: 38.6363
# Epoch 188/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1436.0804 - root_mean_squared_error: 37.8917 - val_loss: 1505.9028 - val_root_mean_squared_error: 38.8037
# Epoch 189/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - loss: 1440.0781 - root_mean_squared_error: 37.9454 - val_loss: 1517.6848 - val_root_mean_squared_error: 38.9546
# Epoch 190/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step - loss: 1434.6890 - root_mean_squared_error: 37.8742 - val_loss: 1488.9236 - val_root_mean_squared_error: 38.5843
# Epoch 191/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 697us/step - loss: 1421.1396 - root_mean_squared_error: 37.6929 - val_loss: 1485.8986 - val_root_mean_squared_error: 38.5449
# Epoch 192/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 708us/step - loss: 1447.6537 - root_mean_squared_error: 38.0452 - val_loss: 1488.6404 - val_root_mean_squared_error: 38.5807
# Epoch 193/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - loss: 1439.5669 - root_mean_squared_error: 37.9377 - val_loss: 1488.6405 - val_root_mean_squared_error: 38.5798
# Epoch 194/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - loss: 1446.0283 - root_mean_squared_error: 38.0228 - val_loss: 1491.1016 - val_root_mean_squared_error: 38.6127
# Epoch 195/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step - loss: 1433.9722 - root_mean_squared_error: 37.8646 - val_loss: 1489.9437 - val_root_mean_squared_error: 38.5972
# Epoch 196/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1440.5374 - root_mean_squared_error: 37.9508 - val_loss: 1489.7800 - val_root_mean_squared_error: 38.5954
# Epoch 197/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - loss: 1440.2048 - root_mean_squared_error: 37.9466 - val_loss: 1486.3975 - val_root_mean_squared_error: 38.5511
# Epoch 198/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1439.4055 - root_mean_squared_error: 37.9361 - val_loss: 1487.0261 - val_root_mean_squared_error: 38.5592
# Epoch 199/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 786us/step - loss: 1445.6626 - root_mean_squared_error: 38.0182 - val_loss: 1488.7338 - val_root_mean_squared_error: 38.5813
# Epoch 200/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 695us/step - loss: 1447.5635 - root_mean_squared_error: 38.0431 - val_loss: 1493.3521 - val_root_mean_squared_error: 38.6409
# Epoch 201/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 730us/step - loss: 1447.2745 - root_mean_squared_error: 38.0398 - val_loss: 1489.0853 - val_root_mean_squared_error: 38.5863
# Epoch 202/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - loss: 1440.9204 - root_mean_squared_error: 37.9563 - val_loss: 1487.9645 - val_root_mean_squared_error: 38.5720
# Epoch 203/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1474.7325 - root_mean_squared_error: 38.3983 - val_loss: 1499.2853 - val_root_mean_squared_error: 38.7182
# Epoch 204/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - loss: 1452.9425 - root_mean_squared_error: 38.1148 - val_loss: 1501.9968 - val_root_mean_squared_error: 38.7537
# Epoch 205/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - loss: 1449.2297 - root_mean_squared_error: 38.0653 - val_loss: 1487.2423 - val_root_mean_squared_error: 38.5623
# Epoch 206/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1434.9186 - root_mean_squared_error: 37.8775 - val_loss: 1491.0127 - val_root_mean_squared_error: 38.6114
# Epoch 207/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - loss: 1439.3229 - root_mean_squared_error: 37.9358 - val_loss: 1498.1183 - val_root_mean_squared_error: 38.7035
# Epoch 208/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 727us/step - loss: 1442.1683 - root_mean_squared_error: 37.9723 - val_loss: 1492.3792 - val_root_mean_squared_error: 38.6294
# Epoch 209/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1459.4084 - root_mean_squared_error: 38.1979 - val_loss: 1486.6525 - val_root_mean_squared_error: 38.5544
# Epoch 210/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1440.6771 - root_mean_squared_error: 37.9522 - val_loss: 1486.3212 - val_root_mean_squared_error: 38.5508
# Epoch 211/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1449.9359 - root_mean_squared_error: 38.0736 - val_loss: 1487.7897 - val_root_mean_squared_error: 38.5693
# Epoch 212/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - loss: 1440.6868 - root_mean_squared_error: 37.9533 - val_loss: 1491.0131 - val_root_mean_squared_error: 38.6110
# Epoch 213/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1451.7260 - root_mean_squared_error: 38.0975 - val_loss: 1489.8807 - val_root_mean_squared_error: 38.5969
# Epoch 214/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1446.8862 - root_mean_squared_error: 38.0352 - val_loss: 1488.2163 - val_root_mean_squared_error: 38.5753
# Epoch 215/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1439.6511 - root_mean_squared_error: 37.9400 - val_loss: 1491.7152 - val_root_mean_squared_error: 38.6205
# Epoch 216/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1428.6625 - root_mean_squared_error: 37.7944 - val_loss: 1487.9542 - val_root_mean_squared_error: 38.5719
# Epoch 217/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1455.5094 - root_mean_squared_error: 38.1473 - val_loss: 1490.3083 - val_root_mean_squared_error: 38.6024
# Epoch 218/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 737us/step - loss: 1455.3114 - root_mean_squared_error: 38.1459 - val_loss: 1489.5873 - val_root_mean_squared_error: 38.5933
# Epoch 219/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1428.6539 - root_mean_squared_error: 37.7945 - val_loss: 1489.0862 - val_root_mean_squared_error: 38.5862
# Epoch 220/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - loss: 1428.2037 - root_mean_squared_error: 37.7885 - val_loss: 1490.9099 - val_root_mean_squared_error: 38.6103
# Epoch 221/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1446.6163 - root_mean_squared_error: 38.0315 - val_loss: 1489.7238 - val_root_mean_squared_error: 38.5949
# Epoch 222/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1426.8191 - root_mean_squared_error: 37.7703 - val_loss: 1489.0269 - val_root_mean_squared_error: 38.5854
# Epoch 223/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1438.7054 - root_mean_squared_error: 37.9266 - val_loss: 1487.3237 - val_root_mean_squared_error: 38.5631
# Epoch 224/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step - loss: 1446.2828 - root_mean_squared_error: 38.0267 - val_loss: 1490.5164 - val_root_mean_squared_error: 38.6048
# Epoch 225/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1442.0502 - root_mean_squared_error: 37.9713 - val_loss: 1487.9338 - val_root_mean_squared_error: 38.5712
# Epoch 226/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1434.7507 - root_mean_squared_error: 37.8752 - val_loss: 1488.1213 - val_root_mean_squared_error: 38.5735
# Epoch 227/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - loss: 1429.9187 - root_mean_squared_error: 37.8094 - val_loss: 1488.0691 - val_root_mean_squared_error: 38.5728
# Epoch 228/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 1441.5154 - root_mean_squared_error: 37.9635 - val_loss: 1490.1643 - val_root_mean_squared_error: 38.6000
# Epoch 229/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1468.6748 - root_mean_squared_error: 38.3189 - val_loss: 1488.8341 - val_root_mean_squared_error: 38.5832
# Epoch 230/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 1436.3708 - root_mean_squared_error: 37.8968 - val_loss: 1490.5985 - val_root_mean_squared_error: 38.6059
# Epoch 231/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - loss: 1434.6139 - root_mean_squared_error: 37.8728 - val_loss: 1486.7545 - val_root_mean_squared_error: 38.5551
# Epoch 232/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step - loss: 1426.6016 - root_mean_squared_error: 37.7666 - val_loss: 1486.6617 - val_root_mean_squared_error: 38.5552
# Epoch 233/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - loss: 1445.6036 - root_mean_squared_error: 38.0175 - val_loss: 1489.7777 - val_root_mean_squared_error: 38.5949
# Epoch 234/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1432.4723 - root_mean_squared_error: 37.8442 - val_loss: 1487.8676 - val_root_mean_squared_error: 38.5706
# Epoch 235/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1440.3176 - root_mean_squared_error: 37.9484 - val_loss: 1488.7477 - val_root_mean_squared_error: 38.5820
# Epoch 236/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step - loss: 1440.9828 - root_mean_squared_error: 37.9568 - val_loss: 1489.3916 - val_root_mean_squared_error: 38.5894
# Epoch 237/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1438.1693 - root_mean_squared_error: 37.9192 - val_loss: 1486.6523 - val_root_mean_squared_error: 38.5550
# Epoch 238/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1438.6456 - root_mean_squared_error: 37.9265 - val_loss: 1496.9052 - val_root_mean_squared_error: 38.6874
# Epoch 239/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1443.9181 - root_mean_squared_error: 37.9936 - val_loss: 1485.9927 - val_root_mean_squared_error: 38.5464
# Epoch 240/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1445.9166 - root_mean_squared_error: 38.0221 - val_loss: 1486.5885 - val_root_mean_squared_error: 38.5534
# Epoch 241/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step - loss: 1427.4974 - root_mean_squared_error: 37.7789 - val_loss: 1490.9749 - val_root_mean_squared_error: 38.6109
# Epoch 242/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1439.4623 - root_mean_squared_error: 37.9372 - val_loss: 1488.9083 - val_root_mean_squared_error: 38.5841
# Epoch 243/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - loss: 1434.2070 - root_mean_squared_error: 37.8680 - val_loss: 1488.1930 - val_root_mean_squared_error: 38.5750
# Epoch 244/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1449.4866 - root_mean_squared_error: 38.0694 - val_loss: 1485.3065 - val_root_mean_squared_error: 38.5372
# Epoch 245/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1446.0824 - root_mean_squared_error: 38.0228 - val_loss: 1490.1624 - val_root_mean_squared_error: 38.6007
# Epoch 246/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step - loss: 1423.0214 - root_mean_squared_error: 37.7186 - val_loss: 1487.9104 - val_root_mean_squared_error: 38.5713
# Epoch 247/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1429.6003 - root_mean_squared_error: 37.8042 - val_loss: 1487.1989 - val_root_mean_squared_error: 38.5622
# Epoch 248/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - loss: 1440.4673 - root_mean_squared_error: 37.9505 - val_loss: 1488.1034 - val_root_mean_squared_error: 38.5729
# Epoch 249/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 695us/step - loss: 1438.4532 - root_mean_squared_error: 37.9234 - val_loss: 1485.9314 - val_root_mean_squared_error: 38.5444
# Epoch 250/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - loss: 1451.2084 - root_mean_squared_error: 38.0910 - val_loss: 1491.5139 - val_root_mean_squared_error: 38.6172
# Epoch 251/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - loss: 1451.0834 - root_mean_squared_error: 38.0896 - val_loss: 1487.6093 - val_root_mean_squared_error: 38.5668
# Epoch 252/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step - loss: 1460.5680 - root_mean_squared_error: 38.2119 - val_loss: 1488.3287 - val_root_mean_squared_error: 38.5765
# Epoch 253/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step - loss: 1436.9880 - root_mean_squared_error: 37.9048 - val_loss: 1488.3984 - val_root_mean_squared_error: 38.5758
# Epoch 254/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - loss: 1417.9431 - root_mean_squared_error: 37.6500 - val_loss: 1488.6499 - val_root_mean_squared_error: 38.5795
# Epoch 255/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 711us/step - loss: 1440.5613 - root_mean_squared_error: 37.9506 - val_loss: 1491.2322 - val_root_mean_squared_error: 38.6134
# Epoch 256/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1437.2111 - root_mean_squared_error: 37.9068 - val_loss: 1487.6465 - val_root_mean_squared_error: 38.5672
# Epoch 257/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - loss: 1441.4183 - root_mean_squared_error: 37.9620 - val_loss: 1491.2355 - val_root_mean_squared_error: 38.6139
# Epoch 258/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - loss: 1428.1267 - root_mean_squared_error: 37.7868 - val_loss: 1486.5599 - val_root_mean_squared_error: 38.5535
# Epoch 259/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1426.9274 - root_mean_squared_error: 37.7708 - val_loss: 1487.6063 - val_root_mean_squared_error: 38.5667
# Epoch 260/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 1432.2736 - root_mean_squared_error: 37.8419 - val_loss: 1488.0543 - val_root_mean_squared_error: 38.5725
# Epoch 261/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - loss: 1446.2598 - root_mean_squared_error: 38.0255 - val_loss: 1487.1163 - val_root_mean_squared_error: 38.5602
# Epoch 262/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1438.6147 - root_mean_squared_error: 37.9254 - val_loss: 1488.8064 - val_root_mean_squared_error: 38.5821
# Epoch 263/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step - loss: 1430.5046 - root_mean_squared_error: 37.8176 - val_loss: 1486.1349 - val_root_mean_squared_error: 38.5469
# Epoch 264/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 711us/step - loss: 1425.6774 - root_mean_squared_error: 37.7536 - val_loss: 1486.8506 - val_root_mean_squared_error: 38.5560
# Epoch 265/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1458.8810 - root_mean_squared_error: 38.1897 - val_loss: 1490.8290 - val_root_mean_squared_error: 38.6086
# Epoch 266/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - loss: 1434.7225 - root_mean_squared_error: 37.8741 - val_loss: 1487.1431 - val_root_mean_squared_error: 38.5601
# Epoch 267/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1423.9480 - root_mean_squared_error: 37.7311 - val_loss: 1487.0421 - val_root_mean_squared_error: 38.5594
# Epoch 268/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step - loss: 1448.6682 - root_mean_squared_error: 38.0575 - val_loss: 1488.9878 - val_root_mean_squared_error: 38.5847
# Epoch 269/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 1427.2203 - root_mean_squared_error: 37.7741 - val_loss: 1486.4441 - val_root_mean_squared_error: 38.5509
# Epoch 270/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1433.1731 - root_mean_squared_error: 37.8531 - val_loss: 1487.5522 - val_root_mean_squared_error: 38.5657
# Epoch 271/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1457.9822 - root_mean_squared_error: 38.1790 - val_loss: 1485.8939 - val_root_mean_squared_error: 38.5444
# Epoch 272/500
# ...
# Epoch 409/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1437.0903 - root_mean_squared_error: 37.9038 - val_loss: 1487.8337 - val_root_mean_squared_error: 38.5695
# Epoch 410/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1424.1129 - root_mean_squared_error: 37.7330 - val_loss: 1487.5636 - val_root_mean_squared_error: 38.5640
# Epoch 411/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1449.1298 - root_mean_squared_error: 38.0607 - val_loss: 1492.2323 - val_root_mean_squared_error: 38.6240
# Epoch 412/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1459.3027 - root_mean_squared_error: 38.1931 - val_loss: 1487.3618 - val_root_mean_squared_error: 38.5619
# Epoch 413/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1432.0720 - root_mean_squared_error: 37.8379 - val_loss: 1486.4838 - val_root_mean_squared_error: 38.5511
# Epoch 414/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step - loss: 1426.5594 - root_mean_squared_error: 37.7642 - val_loss: 1487.9512 - val_root_mean_squared_error: 38.5705
# Epoch 415/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1441.0206 - root_mean_squared_error: 37.9565 - val_loss: 1486.6635 - val_root_mean_squared_error: 38.5538
# Epoch 416/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1428.4958 - root_mean_squared_error: 37.7911 - val_loss: 1487.7183 - val_root_mean_squared_error: 38.5675
# Epoch 417/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - loss: 1435.1609 - root_mean_squared_error: 37.8794 - val_loss: 1486.3062 - val_root_mean_squared_error: 38.5484
# Epoch 418/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1454.9489 - root_mean_squared_error: 38.1375 - val_loss: 1486.4546 - val_root_mean_squared_error: 38.5516
# Epoch 419/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1445.3684 - root_mean_squared_error: 38.0140 - val_loss: 1486.3356 - val_root_mean_squared_error: 38.5498
# Epoch 420/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 1464.0476 - root_mean_squared_error: 38.2576 - val_loss: 1486.7798 - val_root_mean_squared_error: 38.5541
# Epoch 421/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 746us/step - loss: 1440.5747 - root_mean_squared_error: 37.9499 - val_loss: 1487.0586 - val_root_mean_squared_error: 38.5570
# Epoch 422/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 735us/step - loss: 1421.5138 - root_mean_squared_error: 37.6960 - val_loss: 1486.5298 - val_root_mean_squared_error: 38.5515
# Epoch 423/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1441.0229 - root_mean_squared_error: 37.9558 - val_loss: 1492.4252 - val_root_mean_squared_error: 38.6279
# Epoch 424/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 765us/step - loss: 1433.8754 - root_mean_squared_error: 37.8613 - val_loss: 1486.7156 - val_root_mean_squared_error: 38.5541
# Epoch 425/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1433.4087 - root_mean_squared_error: 37.8555 - val_loss: 1487.5061 - val_root_mean_squared_error: 38.5646
# Epoch 426/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step - loss: 1434.8976 - root_mean_squared_error: 37.8746 - val_loss: 1486.7540 - val_root_mean_squared_error: 38.5554
# Epoch 427/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1426.5515 - root_mean_squared_error: 37.7653 - val_loss: 1485.7789 - val_root_mean_squared_error: 38.5425
# Epoch 428/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1451.7848 - root_mean_squared_error: 38.0974 - val_loss: 1485.9603 - val_root_mean_squared_error: 38.5449
# Epoch 429/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1451.2863 - root_mean_squared_error: 38.0880 - val_loss: 1486.7601 - val_root_mean_squared_error: 38.5554
# Epoch 430/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 736us/step - loss: 1443.0336 - root_mean_squared_error: 37.9833 - val_loss: 1486.0364 - val_root_mean_squared_error: 38.5458
# Epoch 431/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 731us/step - loss: 1429.9153 - root_mean_squared_error: 37.8089 - val_loss: 1486.2668 - val_root_mean_squared_error: 38.5469
# Epoch 432/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 727us/step - loss: 1438.7242 - root_mean_squared_error: 37.9251 - val_loss: 1486.2321 - val_root_mean_squared_error: 38.5475
# Epoch 433/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1447.4576 - root_mean_squared_error: 38.0409 - val_loss: 1487.3706 - val_root_mean_squared_error: 38.5621
# Epoch 434/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1442.8359 - root_mean_squared_error: 37.9799 - val_loss: 1488.9226 - val_root_mean_squared_error: 38.5825
# Epoch 435/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 727us/step - loss: 1435.0295 - root_mean_squared_error: 37.8770 - val_loss: 1487.7604 - val_root_mean_squared_error: 38.5681
# Epoch 436/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step - loss: 1440.3849 - root_mean_squared_error: 37.9479 - val_loss: 1486.9471 - val_root_mean_squared_error: 38.5573
# Epoch 437/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1438.7788 - root_mean_squared_error: 37.9272 - val_loss: 1487.2803 - val_root_mean_squared_error: 38.5619
# Epoch 438/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1417.8602 - root_mean_squared_error: 37.6498 - val_loss: 1491.3964 - val_root_mean_squared_error: 38.6150
# Epoch 439/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1451.0803 - root_mean_squared_error: 38.0879 - val_loss: 1504.3270 - val_root_mean_squared_error: 38.7794
# Epoch 440/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1431.5833 - root_mean_squared_error: 37.8294 - val_loss: 1488.9674 - val_root_mean_squared_error: 38.5824
# Epoch 441/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1440.4307 - root_mean_squared_error: 37.9470 - val_loss: 1487.6106 - val_root_mean_squared_error: 38.5651
# Epoch 442/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 1434.4589 - root_mean_squared_error: 37.8687 - val_loss: 1486.3601 - val_root_mean_squared_error: 38.5496
# Epoch 443/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1437.5320 - root_mean_squared_error: 37.9103 - val_loss: 1488.0902 - val_root_mean_squared_error: 38.5723
# Epoch 444/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1437.1550 - root_mean_squared_error: 37.9058 - val_loss: 1487.3912 - val_root_mean_squared_error: 38.5639
# Epoch 445/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1433.3597 - root_mean_squared_error: 37.8563 - val_loss: 1489.5615 - val_root_mean_squared_error: 38.5917
# Epoch 446/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 746us/step - loss: 1426.6177 - root_mean_squared_error: 37.7664 - val_loss: 1486.2233 - val_root_mean_squared_error: 38.5474
# Epoch 447/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 1436.2979 - root_mean_squared_error: 37.8937 - val_loss: 1485.7855 - val_root_mean_squared_error: 38.5426
# Epoch 448/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 1423.7007 - root_mean_squared_error: 37.7273 - val_loss: 1488.8171 - val_root_mean_squared_error: 38.5811
# Epoch 449/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 741us/step - loss: 1435.3706 - root_mean_squared_error: 37.8806 - val_loss: 1489.3344 - val_root_mean_squared_error: 38.5882
# Epoch 450/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1432.6473 - root_mean_squared_error: 37.8452 - val_loss: 1487.1028 - val_root_mean_squared_error: 38.5594
# Epoch 451/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 723us/step - loss: 1430.5277 - root_mean_squared_error: 37.8180 - val_loss: 1489.8295 - val_root_mean_squared_error: 38.5954
# Epoch 452/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1426.3425 - root_mean_squared_error: 37.7630 - val_loss: 1490.7456 - val_root_mean_squared_error: 38.6065
# Epoch 453/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step - loss: 1442.1252 - root_mean_squared_error: 37.9702 - val_loss: 1488.6526 - val_root_mean_squared_error: 38.5801
# Epoch 454/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1423.8877 - root_mean_squared_error: 37.7290 - val_loss: 1487.4386 - val_root_mean_squared_error: 38.5647
# Epoch 455/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1441.3915 - root_mean_squared_error: 37.9617 - val_loss: 1489.1235 - val_root_mean_squared_error: 38.5862
# Epoch 456/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - loss: 1431.6785 - root_mean_squared_error: 37.8335 - val_loss: 1496.4678 - val_root_mean_squared_error: 38.6813
# Epoch 457/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1431.2167 - root_mean_squared_error: 37.8278 - val_loss: 1486.9785 - val_root_mean_squared_error: 38.5580
# Epoch 458/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 1436.6331 - root_mean_squared_error: 37.8986 - val_loss: 1486.2627 - val_root_mean_squared_error: 38.5485
# Epoch 459/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1444.4694 - root_mean_squared_error: 38.0021 - val_loss: 1486.7527 - val_root_mean_squared_error: 38.5556
# Epoch 460/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - loss: 1425.3163 - root_mean_squared_error: 37.7496 - val_loss: 1489.4001 - val_root_mean_squared_error: 38.5899
# Epoch 461/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - loss: 1417.8993 - root_mean_squared_error: 37.6504 - val_loss: 1487.0087 - val_root_mean_squared_error: 38.5593
# Epoch 462/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 740us/step - loss: 1437.9326 - root_mean_squared_error: 37.9165 - val_loss: 1489.2457 - val_root_mean_squared_error: 38.5861
# Epoch 463/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 737us/step - loss: 1444.2791 - root_mean_squared_error: 37.9974 - val_loss: 1486.0363 - val_root_mean_squared_error: 38.5461
# Epoch 464/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1437.0165 - root_mean_squared_error: 37.9035 - val_loss: 1488.2098 - val_root_mean_squared_error: 38.5747
# Epoch 465/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 750us/step - loss: 1433.3832 - root_mean_squared_error: 37.8565 - val_loss: 1486.9713 - val_root_mean_squared_error: 38.5583
# Epoch 466/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 726us/step - loss: 1441.1057 - root_mean_squared_error: 37.9586 - val_loss: 1487.3986 - val_root_mean_squared_error: 38.5641
# Epoch 467/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1452.8031 - root_mean_squared_error: 38.1096 - val_loss: 1487.0780 - val_root_mean_squared_error: 38.5591
# Epoch 468/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - loss: 1441.4033 - root_mean_squared_error: 37.9595 - val_loss: 1486.3857 - val_root_mean_squared_error: 38.5496
# Epoch 469/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1437.9808 - root_mean_squared_error: 37.9164 - val_loss: 1489.1332 - val_root_mean_squared_error: 38.5862
# Epoch 470/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1437.5957 - root_mean_squared_error: 37.9116 - val_loss: 1486.2004 - val_root_mean_squared_error: 38.5478
# Epoch 471/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - loss: 1417.9054 - root_mean_squared_error: 37.6492 - val_loss: 1488.1069 - val_root_mean_squared_error: 38.5719
# Epoch 472/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - loss: 1443.5656 - root_mean_squared_error: 37.9889 - val_loss: 1486.6254 - val_root_mean_squared_error: 38.5532
# Epoch 473/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 845us/step - loss: 1439.1997 - root_mean_squared_error: 37.9319 - val_loss: 1489.0875 - val_root_mean_squared_error: 38.5851
# Epoch 474/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 761us/step - loss: 1428.1831 - root_mean_squared_error: 37.7870 - val_loss: 1486.3196 - val_root_mean_squared_error: 38.5490
# Epoch 475/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1437.6782 - root_mean_squared_error: 37.9109 - val_loss: 1486.1600 - val_root_mean_squared_error: 38.5475
# Epoch 476/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step - loss: 1445.5854 - root_mean_squared_error: 38.0165 - val_loss: 1487.2852 - val_root_mean_squared_error: 38.5625
# Epoch 477/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1434.0367 - root_mean_squared_error: 37.8635 - val_loss: 1487.7363 - val_root_mean_squared_error: 38.5683
# Epoch 478/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - loss: 1423.1691 - root_mean_squared_error: 37.7209 - val_loss: 1487.0143 - val_root_mean_squared_error: 38.5587
# Epoch 479/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1423.1642 - root_mean_squared_error: 37.7212 - val_loss: 1485.7197 - val_root_mean_squared_error: 38.5419
# Epoch 480/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1447.8099 - root_mean_squared_error: 38.0450 - val_loss: 1487.1417 - val_root_mean_squared_error: 38.5589
# Epoch 481/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1434.4381 - root_mean_squared_error: 37.8690 - val_loss: 1486.5699 - val_root_mean_squared_error: 38.5518
# Epoch 482/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 837us/step - loss: 1442.3918 - root_mean_squared_error: 37.9737 - val_loss: 1488.0658 - val_root_mean_squared_error: 38.5721
# Epoch 483/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 765us/step - loss: 1432.3398 - root_mean_squared_error: 37.8407 - val_loss: 1487.5537 - val_root_mean_squared_error: 38.5655
# Epoch 484/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 1442.1587 - root_mean_squared_error: 37.9715 - val_loss: 1492.8955 - val_root_mean_squared_error: 38.6346
# Epoch 485/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1444.9443 - root_mean_squared_error: 38.0071 - val_loss: 1485.6278 - val_root_mean_squared_error: 38.5408
# Epoch 486/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 723us/step - loss: 1441.2550 - root_mean_squared_error: 37.9604 - val_loss: 1486.1342 - val_root_mean_squared_error: 38.5473
# Epoch 487/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1443.3099 - root_mean_squared_error: 37.9863 - val_loss: 1492.0875 - val_root_mean_squared_error: 38.6235
# Epoch 488/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 726us/step - loss: 1436.6234 - root_mean_squared_error: 37.8987 - val_loss: 1486.2020 - val_root_mean_squared_error: 38.5478
# Epoch 489/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1421.2971 - root_mean_squared_error: 37.6958 - val_loss: 1487.4690 - val_root_mean_squared_error: 38.5645
# Epoch 490/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - loss: 1437.2245 - root_mean_squared_error: 37.9053 - val_loss: 1487.6936 - val_root_mean_squared_error: 38.5671
# Epoch 491/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1442.6691 - root_mean_squared_error: 37.9785 - val_loss: 1487.3375 - val_root_mean_squared_error: 38.5632
# Epoch 492/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 764us/step - loss: 1444.6979 - root_mean_squared_error: 38.0060 - val_loss: 1486.0042 - val_root_mean_squared_error: 38.5455
# Epoch 493/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 735us/step - loss: 1436.7784 - root_mean_squared_error: 37.9013 - val_loss: 1485.7211 - val_root_mean_squared_error: 38.5428
# Epoch 494/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 731us/step - loss: 1455.0334 - root_mean_squared_error: 38.1413 - val_loss: 1485.4032 - val_root_mean_squared_error: 38.5380
# Epoch 495/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - loss: 1452.7148 - root_mean_squared_error: 38.1101 - val_loss: 1486.5251 - val_root_mean_squared_error: 38.5514
# Epoch 496/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 723us/step - loss: 1441.9972 - root_mean_squared_error: 37.9670 - val_loss: 1491.0889 - val_root_mean_squared_error: 38.6106
# Epoch 497/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - loss: 1435.5125 - root_mean_squared_error: 37.8841 - val_loss: 1488.7046 - val_root_mean_squared_error: 38.5799
# Epoch 498/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - loss: 1444.2625 - root_mean_squared_error: 37.9988 - val_loss: 1486.3650 - val_root_mean_squared_error: 38.5495
# Epoch 499/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step - loss: 1445.7686 - root_mean_squared_error: 38.0189 - val_loss: 1484.0133 - val_root_mean_squared_error: 38.5197
# Epoch 500/500
# 1301/1301 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - loss: 1431.0739 - root_mean_squared_error: 37.8254 - val_loss: 1486.0844 - val_root_mean_squared_error: 38.5470

# %%
# Display RMSE error for Train and Validation set 


epochs = list(range(800, 2000))
plt.figure(figsize=(10, 6))
plt.plot(history.history['root_mean_squared_error'],label='Train RMSE',color='blue')
plt.plot(history.history['val_root_mean_squared_error'],label='Validation RMSE',color='red')
plt.title(f'Root Mean Squared Error')
plt.xlabel('Epochs')
plt.ylabel('Root Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
# evaluation the final model

import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
import tensorflow as tf

y_pred = model1.predict(Xtest_prepared)

# MAE (Mean Absolute Error)
mae = mean_absolute_error(ytest_prepared, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(ytest_prepared, y_pred))

# R² (R-squared)
r2 = r2_score(ytest_prepared, y_pred)

print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step
# MAE: 29.24275652234533
# RMSE: 38.55726137414101
# R²: 0.03995035225664101
