# %% [markdown]
# # Train Gradient Boost

# %%
# Imports
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../')))

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from code_files.train import train, train_in_batches, grid_search, random_search, save_model
from code_files.data_preperation import prepare_for_train
import pandas as pd
import numpy as np

# %%
# Load Dataset
df_amazon = pd.read_csv("../../dataset/eda_amazon_sales_report.csv")
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117123 entries, 0 to 117122
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Unnamed: 0                           117123 non-null  int64
#  1   Size                                 117123 non-null  int64
#  2   Qty                                  117123 non-null  int64
#  3   Amount                               117123 non-null  float64
#  4   promotion-ids                        117123 non-null  int64
#  5   B2B                                  117123 non-null  int64
#  6   Status_Cancelled                     117123 non-null  bool
#  7   Status_Shipped                       117123 non-null  bool
#  8   Status_Shipped - Delivered to Buyer  117123 non-null  bool
#  9   Fulfilment_Amazon                    117123 non-null  bool
#  10  Fulfilment_Merchant                  117123 non-null  bool
#  11  ship-service-level_Expedited         117123 non-null  bool
#  12  ship-service-level_Standard          117123 non-null  bool
#  13  Category_Blouse                      117123 non-null  bool
#  14  Category_Bottom                      117123 non-null  bool
#  15  Category_Dupatta                     117123 non-null  bool
#  16  Category_Ethnic Dress                117123 non-null  bool
#  17  Category_Saree                       117123 non-null  bool
#  18  Category_Set                         117123 non-null  bool
#  19  Category_Top                         117123 non-null  bool
#  20  Category_Western Dress               117123 non-null  bool
#  21  Category_kurta                       117123 non-null  bool
#  22  Month                                117123 non-null  int64
#  23  Day                                  117123 non-null  int64
# dtypes: bool(16), float64(1), int64(7)
# memory usage: 8.9 MB

# %%
# Split and Prepare for train
dftrain, dftest = train_test_split(df_amazon, test_size=0.1, random_state=42)
Xtrain_prepared, ytrain_prepared, Xtest_prepared, ytest_prepared = prepare_for_train(dftrain, dftest)

# %%
# Grid Search
search = random_search(
    Xtrain_prepared,
    ytrain_prepared,
    GradientBoostingRegressor(),
    params={
        "loss": [
            "squared_error",
            "absolute_error",
            "huber",
            "quantile",
        ],  # Different loss functions
        "learning_rate": [0.01, 0.05, 0.1, 0.2, 0.3],  # Shrinkage rate
        "n_estimators": [50, 100, 200, 300, 500],  # Number of boosting stages
        "subsample": [0.6, 0.8, 1.0],  # Fraction of samples used for training
        "criterion": [
            "friedman_mse",
            "squared_error",
        ],  # Function to measure split quality
        "min_samples_split": [
            2,
            5,
            10,
            20,
        ],  # Minimum samples required to split an internal node
        "min_samples_leaf": [1, 2, 5, 10],  # Minimum samples required to be a leaf node
        "min_weight_fraction_leaf": [
            0.0,
            0.01,
            0.05,
        ],  # Minimum fraction of weight in a leaf node
        "max_depth": [3, 5, 7, 10],  # Maximum depth of individual trees
        "min_impurity_decrease": [
            0.0,
            0.01,
            0.1,
        ],  # Minimum impurity decrease to split a node
        "max_features": [
            None,
            "sqrt",
            "log2",
            0.6,
            0.8,
        ],  # Number of features to consider at each split
        "alpha": [
            0.7,
            0.85,
            0.9,
            0.95,
        ],  # Quantile loss parameter (relevant for `loss="quantile"`)
        "max_leaf_nodes": [None, 10, 20, 50],  # Maximum number of leaf nodes in a tree
        "warm_start": [False, True],  # Reuse previous solution to add more estimators
        "validation_fraction": [
            0.1,
            0.2,
            0.3,
        ],  # Fraction of data for validation (used with early stopping)
        "n_iter_no_change": [None, 5, 10, 20],  # Early stopping rounds
        "tol": [1e-4, 1e-3, 1e-2],  # Tolerance for stopping criteria
        "ccp_alpha": [
            0.0,
            0.01,
            0.1,
        ],  # Complexity parameter for Minimal Cost-Complexity Pruning
    },
    cv=2,
)

save_model(search.best_estimator_)
# Out:
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [CV] END alpha=0.7, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.3, loss=absolute_error, max_depth=5, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=5, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=False; total time=   2.5s
# [CV] END alpha=0.7, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.3, loss=absolute_error, max_depth=5, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=5, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=False; total time=   3.6s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=   5.4s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=  13.4s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=huber, max_depth=7, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=20, subsample=1.0, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=  22.7s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.2, loss=huber, max_depth=10, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=50, n_iter_no_change=None, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=False; total time=  15.3s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=huber, max_depth=7, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=20, subsample=1.0, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=  29.1s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.2, loss=quantile, max_depth=7, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=10, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=   2.1s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_depth=10, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=50, n_iter_no_change=10, subsample=0.6, tol=0.0001, validation_fraction=0.2, warm_start=True; total time=   8.5s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.2, loss=quantile, max_depth=7, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=10, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=   1.5s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_depth=10, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=50, n_iter_no_change=10, subsample=0.6, tol=0.0001, validation_fraction=0.2, warm_start=True; total time=   8.1s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.2, loss=huber, max_depth=10, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=50, n_iter_no_change=None, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=False; total time=  17.0s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=10, max_features=None, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=True; total time=   0.6s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=10, max_features=None, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=True; total time=   0.5s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_depth=10, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=10, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=  12.5s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_depth=10, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=10, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=  16.8s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=huber, max_depth=5, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=  17.9s
# [CV] END alpha=0.95, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=quantile, max_depth=5, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=5, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=False; total time=   0.4s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=huber, max_depth=5, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=  20.1s
# [CV] END alpha=0.95, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=quantile, max_depth=5, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=5, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=False; total time=   0.3s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.3, loss=huber, max_depth=7, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=10, subsample=0.6, tol=0.01, validation_fraction=0.1, warm_start=True; total time=   4.1s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.3, loss=huber, max_depth=7, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=10, subsample=0.6, tol=0.01, validation_fraction=0.1, warm_start=True; total time=   4.5s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.2, loss=absolute_error, max_depth=10, max_features=None, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=10, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=False; total time=   5.1s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.2, loss=absolute_error, max_depth=10, max_features=None, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=10, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=False; total time=   5.5s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.05, loss=huber, max_depth=10, max_features=log2, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=None, subsample=0.6, tol=0.001, validation_fraction=0.3, warm_start=False; total time=  19.5s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.05, loss=huber, max_depth=10, max_features=log2, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=None, subsample=0.6, tol=0.001, validation_fraction=0.3, warm_start=False; total time=  21.8s
# [CV] END alpha=0.95, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.1, loss=huber, max_depth=7, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=20, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=  21.3s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.2, loss=quantile, max_depth=3, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=10, subsample=1.0, tol=0.0001, validation_fraction=0.1, warm_start=False; total time=   1.3s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.2, loss=quantile, max_depth=3, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=10, subsample=1.0, tol=0.0001, validation_fraction=0.1, warm_start=False; total time=   1.1s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=squared_error, max_depth=3, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=10, subsample=0.6, tol=0.0001, validation_fraction=0.3, warm_start=False; total time=  19.4s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=squared_error, max_depth=3, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=10, subsample=0.6, tol=0.0001, validation_fraction=0.3, warm_start=False; total time=  14.1s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.2, loss=squared_error, max_depth=7, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=100, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=True; total time=   8.9s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.2, loss=squared_error, max_depth=7, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=100, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=True; total time=  11.3s
# [CV] END alpha=0.95, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.1, loss=huber, max_depth=7, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=20, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=  47.5s
# [CV] END alpha=0.7, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=0.6, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   2.4s
# [CV] END alpha=0.7, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=0.6, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   4.2s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=squared_error, max_depth=10, max_features=0.6, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=50, n_iter_no_change=5, subsample=0.8, tol=0.001, validation_fraction=0.3, warm_start=True; total time=   3.3s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=quantile, max_depth=3, max_features=log2, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=20, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=True; total time=   1.6s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=squared_error, max_depth=10, max_features=0.6, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=50, n_iter_no_change=5, subsample=0.8, tol=0.001, validation_fraction=0.3, warm_start=True; total time=   5.3s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=quantile, max_depth=3, max_features=log2, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=20, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=True; total time=   1.8s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.3, loss=quantile, max_depth=7, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=100, n_iter_no_change=20, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=True; total time=   8.1s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.3, loss=quantile, max_depth=7, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=100, n_iter_no_change=20, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=True; total time=   7.6s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=huber, max_depth=10, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=None, subsample=0.6, tol=0.0001, validation_fraction=0.1, warm_start=False; total time= 1.1min
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=huber, max_depth=10, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=None, subsample=0.6, tol=0.0001, validation_fraction=0.1, warm_start=False; total time= 1.1min
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.3, loss=quantile, max_depth=3, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=20, subsample=1.0, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   1.8s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.3, loss=quantile, max_depth=3, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=20, subsample=1.0, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   1.9s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_depth=10, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=None, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=True; total time=  11.8s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_depth=10, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=None, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=True; total time=  11.9s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=3, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   1.2s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=3, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   1.1s
# [CV] END alpha=0.7, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=squared_error, max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=10, subsample=0.6, tol=0.0001, validation_fraction=0.1, warm_start=False; total time=   5.9s
# [CV] END alpha=0.7, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=squared_error, max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=10, subsample=0.6, tol=0.0001, validation_fraction=0.1, warm_start=False; total time=   9.0s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_depth=3, max_features=0.8, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=10, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=  19.5s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_depth=3, max_features=0.8, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=10, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=  16.8s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=quantile, max_depth=7, max_features=None, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=None, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=False; total time= 1.2min
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=quantile, max_depth=7, max_features=None, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=None, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=False; total time= 1.2min
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=huber, max_depth=10, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=50, n_iter_no_change=10, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=True; total time=   8.7s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=huber, max_depth=10, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=50, n_iter_no_change=10, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=True; total time=   9.6s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.3, loss=absolute_error, max_depth=7, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=5, subsample=1.0, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   3.6s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.2, loss=absolute_error, max_depth=3, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=500, n_iter_no_change=10, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=True; total time=   1.4s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.3, loss=absolute_error, max_depth=7, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=5, subsample=1.0, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   4.7s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.2, loss=absolute_error, max_depth=3, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=500, n_iter_no_change=10, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=True; total time=   0.7s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_depth=10, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=200, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   8.9s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=10, max_features=0.6, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=   0.7s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=10, max_features=0.6, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=   1.1s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_depth=10, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=200, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=  14.3s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=huber, max_depth=5, max_features=0.8, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=False; total time=   5.1s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.2, loss=huber, max_depth=10, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=None, subsample=0.6, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=  38.5s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.2, loss=huber, max_depth=10, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=None, subsample=0.6, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=  39.7s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.05, loss=quantile, max_depth=3, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=200, n_iter_no_change=10, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   1.3s
# [CV] END alpha=0.95, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.3, loss=quantile, max_depth=5, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=20, subsample=0.6, tol=0.001, validation_fraction=0.1, warm_start=True; total time=   5.5s
# [CV] END alpha=0.95, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.3, loss=quantile, max_depth=5, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=20, subsample=0.6, tol=0.001, validation_fraction=0.1, warm_start=True; total time=   5.8s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.05, loss=quantile, max_depth=3, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=200, n_iter_no_change=10, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   1.6s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=huber, max_depth=5, max_features=0.8, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=False; total time=  15.4s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_depth=7, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=5, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=None, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=  20.7s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=squared_error, max_depth=5, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=   0.6s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=squared_error, max_depth=5, max_features=log2, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=   2.0s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_depth=7, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=5, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=None, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=  18.0s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.2, loss=huber, max_depth=7, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=10, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=   2.2s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.2, loss=huber, max_depth=7, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=10, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=   3.9s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_depth=7, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=False; total time=  14.3s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_depth=7, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=False; total time=  11.5s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.2, loss=squared_error, max_depth=7, max_features=0.6, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=False; total time=   3.3s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_depth=3, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=None, subsample=1.0, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=  45.8s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.3, loss=absolute_error, max_depth=3, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=5, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=True; total time=   0.5s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.3, loss=absolute_error, max_depth=3, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=5, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=True; total time=   0.5s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_depth=3, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=None, subsample=1.0, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=  45.7s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.2, loss=squared_error, max_depth=7, max_features=0.6, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=False; total time=   5.4s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=10, subsample=0.6, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   1.7s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=10, subsample=0.6, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   4.7s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.3, loss=absolute_error, max_depth=5, max_features=0.8, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=100, n_iter_no_change=None, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=   8.3s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.3, loss=absolute_error, max_depth=5, max_features=0.8, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=100, n_iter_no_change=None, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=   9.6s
# [CV] END alpha=0.9, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.05, loss=huber, max_depth=3, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=10, subsample=1.0, tol=0.01, validation_fraction=0.1, warm_start=False; total time=  13.1s
# [CV] END alpha=0.9, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.05, loss=huber, max_depth=3, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=10, subsample=1.0, tol=0.01, validation_fraction=0.1, warm_start=False; total time=  12.5s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=squared_error, max_depth=3, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=True; total time=  20.3s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=squared_error, max_depth=3, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=True; total time=  18.9s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.3, loss=huber, max_depth=5, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=5, subsample=0.6, tol=0.01, validation_fraction=0.1, warm_start=True; total time=   1.9s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.3, loss=huber, max_depth=5, max_features=sqrt, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=5, subsample=0.6, tol=0.01, validation_fraction=0.1, warm_start=True; total time=   1.7s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.05, loss=huber, max_depth=7, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=20, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=  10.9s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.05, loss=huber, max_depth=7, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=20, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=  10.8s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=huber, max_depth=5, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=0.6, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   8.4s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=huber, max_depth=5, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=0.6, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   9.4s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.2, loss=absolute_error, max_depth=10, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=500, n_iter_no_change=10, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=False; total time=   2.1s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.2, loss=absolute_error, max_depth=10, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=500, n_iter_no_change=10, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=False; total time=   1.3s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.05, loss=squared_error, max_depth=3, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=500, n_iter_no_change=None, subsample=1.0, tol=0.01, validation_fraction=0.3, warm_start=True; total time=  53.8s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.3, loss=squared_error, max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=5, subsample=0.6, tol=0.01, validation_fraction=0.2, warm_start=True; total time=   1.1s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.05, loss=squared_error, max_depth=3, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=500, n_iter_no_change=None, subsample=1.0, tol=0.01, validation_fraction=0.3, warm_start=True; total time=  53.6s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=squared_error, max_depth=10, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=5, subsample=0.6, tol=0.001, validation_fraction=0.1, warm_start=True; total time=   5.6s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.3, loss=squared_error, max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=5, subsample=0.6, tol=0.01, validation_fraction=0.2, warm_start=True; total time=   2.4s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=absolute_error, max_depth=3, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=1.0, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   0.8s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=absolute_error, max_depth=3, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=5, subsample=1.0, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   0.6s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=3, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=50, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   0.3s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=3, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=50, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   0.4s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=squared_error, max_depth=10, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=5, subsample=0.6, tol=0.001, validation_fraction=0.1, warm_start=True; total time=   8.1s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_depth=3, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=20, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=False; total time=  10.4s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_depth=3, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=20, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=False; total time=  10.0s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_depth=3, max_features=0.6, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=20, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=True; total time=   2.0s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_depth=5, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=500, n_iter_no_change=5, subsample=0.6, tol=0.001, validation_fraction=0.3, warm_start=True; total time=   0.6s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_depth=3, max_features=0.6, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=20, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=True; total time=   2.1s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_depth=5, max_features=0.8, max_leaf_nodes=20, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=500, n_iter_no_change=5, subsample=0.6, tol=0.001, validation_fraction=0.3, warm_start=True; total time=   0.9s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=quantile, max_depth=10, max_features=0.6, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=50, n_iter_no_change=10, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   1.9s
# [CV] END alpha=0.85, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=quantile, max_depth=10, max_features=0.6, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=50, n_iter_no_change=10, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   3.0s
# [CV] END alpha=0.9, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_depth=5, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   1.1s
# [CV] END alpha=0.9, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_depth=5, max_features=0.6, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   0.9s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.3, loss=huber, max_depth=7, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200, n_iter_no_change=5, subsample=0.6, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   3.5s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=absolute_error, max_depth=3, max_features=sqrt, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=True; total time=   0.9s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.3, loss=huber, max_depth=7, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200, n_iter_no_change=5, subsample=0.6, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   5.6s
# [CV] END alpha=0.9, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=absolute_error, max_depth=3, max_features=sqrt, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.2, warm_start=True; total time=   1.0s
# ...
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.3, loss=squared_error, max_depth=7, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=20, subsample=0.8, tol=0.001, validation_fraction=0.1, warm_start=False; total time=  13.1s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.3, loss=squared_error, max_depth=7, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=20, subsample=0.8, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   3.6s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=quantile, max_depth=5, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=20, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=True; total time=   5.2s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=quantile, max_depth=5, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=20, subsample=1.0, tol=0.01, validation_fraction=0.2, warm_start=True; total time=   5.3s
# [CV] END alpha=0.7, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.2, loss=absolute_error, max_depth=3, max_features=0.8, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=10, subsample=1.0, tol=0.01, validation_fraction=0.3, warm_start=True; total time=   0.4s
# [CV] END alpha=0.7, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.2, loss=absolute_error, max_depth=3, max_features=0.8, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=10, subsample=1.0, tol=0.01, validation_fraction=0.3, warm_start=True; total time=   0.8s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.01, loss=squared_error, max_depth=10, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=None, subsample=0.6, tol=0.01, validation_fraction=0.3, warm_start=False; total time=  34.7s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.01, loss=squared_error, max_depth=10, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=None, subsample=0.6, tol=0.01, validation_fraction=0.3, warm_start=False; total time=  34.9s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=huber, max_depth=7, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=10, subsample=0.6, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   9.3s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=huber, max_depth=7, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=10, subsample=0.6, tol=0.0001, validation_fraction=0.2, warm_start=False; total time=   4.9s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=quantile, max_depth=10, max_features=sqrt, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=5, subsample=0.8, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   0.3s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=quantile, max_depth=10, max_features=sqrt, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=300, n_iter_no_change=5, subsample=0.8, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   0.8s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=huber, max_depth=7, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=100, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=   4.1s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=huber, max_depth=7, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=100, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=   1.7s
# [CV] END alpha=0.95, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=squared_error, max_depth=7, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.2, warm_start=True; total time= 1.6min
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.1, loss=huber, max_depth=7, max_features=0.8, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=20, subsample=0.8, tol=0.001, validation_fraction=0.2, warm_start=False; total time=  10.3s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.1, loss=huber, max_depth=7, max_features=0.8, max_leaf_nodes=None, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.05, n_estimators=200, n_iter_no_change=20, subsample=0.8, tol=0.001, validation_fraction=0.2, warm_start=False; total time=  10.8s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.2, loss=huber, max_depth=7, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=20, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=   8.7s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_depth=5, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=10, subsample=0.8, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   0.4s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_depth=5, max_features=log2, max_leaf_nodes=10, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=10, subsample=0.8, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   1.1s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_depth=3, max_features=0.6, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=50, n_iter_no_change=5, subsample=0.6, tol=0.01, validation_fraction=0.3, warm_start=True; total time=   2.1s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_depth=3, max_features=0.6, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=50, n_iter_no_change=5, subsample=0.6, tol=0.01, validation_fraction=0.3, warm_start=True; total time=   1.4s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.2, loss=absolute_error, max_depth=7, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=5, subsample=0.8, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   0.6s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.2, loss=absolute_error, max_depth=7, max_features=None, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=20, min_weight_fraction_leaf=0.05, n_estimators=50, n_iter_no_change=5, subsample=0.8, tol=0.001, validation_fraction=0.1, warm_start=False; total time=   0.9s
# [CV] END alpha=0.85, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.2, loss=huber, max_depth=7, max_features=0.8, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=300, n_iter_no_change=20, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=False; total time=   8.7s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=10, max_features=0.6, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=None, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=  17.6s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=squared_error, learning_rate=0.01, loss=quantile, max_depth=10, max_features=0.6, max_leaf_nodes=50, min_impurity_decrease=0.1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=300, n_iter_no_change=None, subsample=1.0, tol=0.0001, validation_fraction=0.3, warm_start=True; total time=  17.2s
# [CV] END alpha=0.9, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=huber, max_depth=3, max_features=None, max_leaf_nodes=50, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=False; total time= 1.2min
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=squared_error, max_depth=10, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=True; total time=   2.1s
# [CV] END alpha=0.7, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=squared_error, max_depth=10, max_features=0.6, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=2, min_samples_split=20, min_weight_fraction_leaf=0.0, n_estimators=100, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.3, warm_start=True; total time=   1.9s
# [CV] END alpha=0.9, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=huber, max_depth=3, max_features=None, max_leaf_nodes=50, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=20, subsample=0.8, tol=0.01, validation_fraction=0.3, warm_start=False; total time= 1.2min
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.3, loss=huber, max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=500, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   1.5s
# [CV] END alpha=0.7, ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.3, loss=huber, max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=0.01, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.05, n_estimators=500, n_iter_no_change=5, subsample=0.8, tol=0.01, validation_fraction=0.1, warm_start=False; total time=   1.2s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.2, loss=absolute_error, max_depth=10, max_features=sqrt, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=True; total time=   0.3s
# [CV] END alpha=0.95, ccp_alpha=0.01, criterion=squared_error, learning_rate=0.2, loss=absolute_error, max_depth=10, max_features=sqrt, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=10, subsample=1.0, tol=0.001, validation_fraction=0.2, warm_start=True; total time=   0.4s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=quantile, max_depth=5, max_features=0.6, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=None, subsample=0.6, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=  11.1s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=quantile, max_depth=5, max_features=0.6, max_leaf_nodes=50, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=200, n_iter_no_change=None, subsample=0.6, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=  10.8s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=absolute_error, max_depth=10, max_features=0.8, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=   1.2s
# [CV] END alpha=0.85, ccp_alpha=0.1, criterion=squared_error, learning_rate=0.3, loss=absolute_error, max_depth=10, max_features=0.8, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=5, min_samples_split=20, min_weight_fraction_leaf=0.01, n_estimators=100, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=True; total time=   1.3s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.01, loss=huber, max_depth=7, max_features=log2, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=False; total time=  27.7s
# [CV] END alpha=0.9, ccp_alpha=0.0, criterion=friedman_mse, learning_rate=0.01, loss=huber, max_depth=7, max_features=log2, max_leaf_nodes=20, min_impurity_decrease=0.01, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.01, n_estimators=500, n_iter_no_change=5, subsample=0.8, tol=0.0001, validation_fraction=0.1, warm_start=False; total time=  31.7s
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 69
#       1 # Grid Search
#       2 grid = random_search(
#       3     Xtrain_prepared,
#       4     ytrain_prepared,
#    (...)
#      66     cv=2,
#      67 )
# ---> 69 save_model(grid.best_estimator_)
#
# AttributeError: 'function' object has no attribute 'best_estimator_'

# %%
# Show results
df_grid_results = pd.DataFrame(search.cv_results_)
columns_to_show = ["params", "rank_test_score", "mean_train_score", "mean_test_score"]
df_shown_results = df_grid_results[columns_to_show]

print(search.best_params_)
df_shown_results.sort_values("rank_test_score", ascending = True)
# Out:
# {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#                                                params  rank_test_score  \
# 1   {'bootstrap': True, 'max_depth': 10, 'min_samp...                1
# 3   {'bootstrap': True, 'max_depth': 10, 'min_samp...                2
# 5   {'bootstrap': True, 'max_depth': 10, 'min_samp...                3
# 0   {'bootstrap': True, 'max_depth': 10, 'min_samp...                4
# 2   {'bootstrap': True, 'max_depth': 10, 'min_samp...                5
# 7   {'bootstrap': True, 'max_depth': 10, 'min_samp...                6
# 4   {'bootstrap': True, 'max_depth': 10, 'min_samp...                7
# 6   {'bootstrap': True, 'max_depth': 10, 'min_samp...                8
# 31  {'bootstrap': False, 'max_depth': 10, 'min_sam...                9
# 30  {'bootstrap': False, 'max_depth': 10, 'min_sam...               10
# 29  {'bootstrap': False, 'max_depth': 10, 'min_sam...               11
# 28  {'bootstrap': False, 'max_depth': 10, 'min_sam...               12
# 27  {'bootstrap': False, 'max_depth': 10, 'min_sam...               13
# 26  {'bootstrap': False, 'max_depth': 10, 'min_sam...               14
# 25  {'bootstrap': False, 'max_depth': 10, 'min_sam...               15
# 24  {'bootstrap': False, 'max_depth': 10, 'min_sam...               16
# 11  {'bootstrap': True, 'max_depth': 20, 'min_samp...               17
# 14  {'bootstrap': True, 'max_depth': 20, 'min_samp...               18
# 13  {'bootstrap': True, 'max_depth': 20, 'min_samp...               19
# 15  {'bootstrap': True, 'max_depth': 20, 'min_samp...               20
# 10  {'bootstrap': True, 'max_depth': 20, 'min_samp...               21
# 12  {'bootstrap': True, 'max_depth': 20, 'min_samp...               22
# 9   {'bootstrap': True, 'max_depth': 20, 'min_samp...               23
# 8   {'bootstrap': True, 'max_depth': 20, 'min_samp...               24
# 23  {'bootstrap': True, 'max_depth': 30, 'min_samp...               25
# 22  {'bootstrap': True, 'max_depth': 30, 'min_samp...               26
# 21  {'bootstrap': True, 'max_depth': 30, 'min_samp...               27
# 20  {'bootstrap': True, 'max_depth': 30, 'min_samp...               28
# 19  {'bootstrap': True, 'max_depth': 30, 'min_samp...               29
# 18  {'bootstrap': True, 'max_depth': 30, 'min_samp...               30
# 17  {'bootstrap': True, 'max_depth': 30, 'min_samp...               31
# 16  {'bootstrap': True, 'max_depth': 30, 'min_samp...               32
# 39  {'bootstrap': False, 'max_depth': 20, 'min_sam...               33
# 38  {'bootstrap': False, 'max_depth': 20, 'min_sam...               34
# 37  {'bootstrap': False, 'max_depth': 20, 'min_sam...               35
# 36  {'bootstrap': False, 'max_depth': 20, 'min_sam...               36
# 35  {'bootstrap': False, 'max_depth': 20, 'min_sam...               37
# 34  {'bootstrap': False, 'max_depth': 20, 'min_sam...               38
# 33  {'bootstrap': False, 'max_depth': 20, 'min_sam...               39
# 32  {'bootstrap': False, 'max_depth': 20, 'min_sam...               40
# 47  {'bootstrap': False, 'max_depth': 30, 'min_sam...               41
# 46  {'bootstrap': False, 'max_depth': 30, 'min_sam...               42
# 45  {'bootstrap': False, 'max_depth': 30, 'min_sam...               43
# 44  {'bootstrap': False, 'max_depth': 30, 'min_sam...               44
# 42  {'bootstrap': False, 'max_depth': 30, 'min_sam...               45
# 43  {'bootstrap': False, 'max_depth': 30, 'min_sam...               46
# 40  {'bootstrap': False, 'max_depth': 30, 'min_sam...               47
# 41  {'bootstrap': False, 'max_depth': 30, 'min_sam...               48
#
#     mean_train_score  mean_test_score
# 1        -194.972173      -200.131273
# 3        -195.226022      -200.134551
# 5        -195.513447      -200.145811
# 0        -195.015079      -200.146579
# 2        -195.286946      -200.149347
# 7        -195.503966      -200.159432
# 4        -195.490744      -200.201737
# 6        -195.559578      -200.204320
# 31       -197.073748      -202.058976
# 30       -197.073800      -202.063383
# 29       -197.006057      -202.206183
# 28       -197.005935      -202.206748
# 27       -196.832582      -202.525876
# 26       -196.832627      -202.534149
# 25       -196.551573      -202.608459
# 24       -196.551682      -202.609975
# 11       -154.437167      -204.047148
# 14       -159.911804      -204.149029
# 13       -157.853015      -204.163623
# 15       -159.125770      -204.195039
# 10       -154.512590      -204.243213
# 12       -158.008919      -204.534375
# 9        -145.654542      -205.103218
# 8        -146.504479      -205.110628
# 23       -134.909482      -210.264952
# 22       -135.279253      -210.539836
# 21       -131.661647      -211.003479
# 20       -132.133407      -211.210103
# 19       -121.119209      -211.493079
# 18       -121.600766      -211.792639
# 17        -96.834564      -216.130411
# 16        -96.908689      -216.526239
# 39       -162.361332      -227.305250
# 38       -162.361406      -227.308575
# 37       -160.969726      -228.338322
# 36       -160.969817      -228.344589
# 35       -158.686640      -230.310923
# 34       -158.686324      -230.328153
# 33       -150.746455      -234.642054
# 32       -150.746707      -234.672956
# 47       -127.738260      -246.580316
# 46       -127.738743      -246.591103
# 45       -123.296999      -248.584691
# 44       -123.297745      -248.591938
# 42       -112.383539      -253.937629
# 43       -112.382409      -253.940635
# 40        -76.641643      -264.623484
# 41        -76.641755      -264.624703

# %%
# Train
model, scores = train(search.best_estimator_, Xtrain_prepared, ytrain_prepared, Xtest_prepared, ytest_prepared)
print(f"mae: {scores[0]}, rmse: {scores[1]}, r2: {scores[2]}")
# Out:
# mae: 202.62332578391408, rmse: 248.49653493418916, r2: 248.49653493418916

# %% [markdown]
# Best Param:
# {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
